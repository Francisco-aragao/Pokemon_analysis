# %% [markdown]
# Com o Resultado do `Apriori`, descobrimos que a carta `jirachi` é uma carta amplamante utilizadas entre os jogadores nos torneios de 2019.
# Iremos utilizar um algoritmo SD como alvo o ranking dos jogadores variando de 0 para ranks piores que `RANK_ANALISAR` e 1 o contrario, nos torneios do ano de 2019 para encontrar informacoes do que precisamos para criar um deck ideal e ver se o algoritmo recomendara a carta `jirachi`.

# %% [markdown]
# ## Variaveis para definir

# %%
CONSIDERAR_TREINADORES = True
ANO_ANALISAR = 2019
RANK_ANALISAR = 5

# quantidade de cartas de 1 tipo que deve exitir no dataset para ser considerado evitando outliers 
CARTAS_MINIMAS = 20

# %% [markdown]
# ## Bibliotecas utilizadas e carregando dataset

# %%
import numpy as np
import pandas as pd
import pysubgroup as ps

df_original = pd.read_csv('./Data/tournaments.csv')
df = df_original.copy()

# %% [markdown]
# ## Eliminar cartas de treinador se quiser

# %%
if not CONSIDERAR_TREINADORES:
    df = df[df['type_card'] != 'Trainer']

# %% [markdown]
# ## Filtragem de colunas no dataset e limpeza de linhas com coluna regiao do torneio vazias

# %%
columns_to_remove = [
    'id_card', 'amount_card', 'price_card', 'combo_type_id', 'name_tournament',
    'combo_type_name', 'name_player', 'category_tournament', 'type_card',
    'month_tournament', 'day_tournament', 'valid_rotation_at_tournament', 
    'rotation_name', 'year_begin', 'all_time_score', 'country_tournament', 'country_player',
    'month_begin', 'day_begin',
]
df.drop(columns=columns_to_remove, inplace=True)
df = df[df['region_tournament'].notna()]

df.head(1)
# Out:
#        name_card energy_type_card  id_player  ranking_player_tournament  \
# 7462  Charmander             Fire        649                          1
#
#       id_tournament region_tournament  year_tournament
# 7462            385                SA             2023

# %% [markdown]
# ## Adaptando dados para pordermos usar SD
#
# Como somente `ranking_player` do tipo numerico, vamos transformalo em binario em que menor que `RANK_ANALISAR` seria 1, estamos buscando cartas que aumentem a probabilidade de um jogador subir de rank acima de `RANK_ANALISAR`

# %%
# todos os ranking players acima de 15 sao 1
df['ranking_player_tournament'] = df['ranking_player_tournament'].apply(lambda x: 1 if x < RANK_ANALISAR else 0)

df.head(1)
# Out:
#        name_card energy_type_card  id_player  ranking_player_tournament  \
# 7462  Charmander             Fire        649                          1
#
#       id_tournament region_tournament  year_tournament
# 7462            385                SA             2023

# %% [markdown]
# ## Separando por regiao e verificando a qualidade dos subgrupos de cartas que aumentem a probabilidade de um jogador subir no rank

# %%
def elimina_cards_menos_usados(df):
    cartas = df['name_card'].unique()
    for carta in cartas:
        if len(df[df['name_card'] == carta]) < CARTAS_MINIMAS:
            df = df[df['name_card'] != carta]
    return df

def agrupa_deck_rank(df_region):
    #filtra torneios da regiao
    torneios = df_region['id_tournament'].unique()

    lista_decks_rank = []
    for torneio in torneios:
        df_torneio = df_region[df_region['id_tournament'] == torneio]
        jogadores = df_torneio['id_player'].unique()
        for jogador in jogadores:
            df_jogador = df_torneio[df_torneio['id_player'] == jogador]
            cartas_jogador_rank = df_jogador['name_card'].unique().tolist()
            cartas_jogador_rank.append(df_jogador['ranking_player_tournament'].iloc[0])
            lista_decks_rank.append(cartas_jogador_rank)
    return lista_decks_rank

def subgrupo_dataset_region(df_region):
    lista_decks_rank = agrupa_deck_rank(df_region)
    cartas = df_region['name_card'].unique()
    data = []
    for deck_rank in lista_decks_rank:
        pokemons_no_deck_rank = {carta: (carta in deck_rank[:len(deck_rank)-1]) for carta in cartas}
        pokemons_no_deck_rank['ranking_player_tournament'] = deck_rank[-1]
        data.append(pokemons_no_deck_rank)
    # Converte a lista de dicionários em um DataFrame
    df_decks_cartas = pd.DataFrame(data)

    return df_decks_cartas

def calcula_subgrupo(df):
    target = ps.BinaryTarget('ranking_player_tournament',1)
    search_space = ps.create_selectors(df, ignore=['ranking_player_tournament'])
    task = ps.SubgroupDiscoveryTask(
        df,
        target, 
        search_space, 
        result_set_size=20, 
        depth=5, 
        qf=ps.WRAccQF()  # Quality function to evaluate subgroups
    )
    result = ps.BeamSearch().execute(task)
    return result

# %% [markdown]
# ### Por regiao

# %%
regions = df['region_tournament'].unique()
for region in regions:
    print(f"Região: {region}\n")
    df_region = df[(df['region_tournament'] == region) & (df['year_tournament'] == ANO_ANALISAR)]

    # verifica se tem torneios na regiao
    if len(df_region) == 0:
        print(f'Sem torneios na região {region} no ano {ANO_ANALISAR}\n')
        print("-------------------------------------------"*3)
        continue

    # calcula subgrupo
    df_region = elimina_cards_menos_usados(df_region)
    dataset = subgrupo_dataset_region(df_region)
    result = calcula_subgrupo(dataset)

    # imprime resultados
    for row in result.to_dataframe().itertuples():
        print(f"Subgrupo: {row.subgroup}")
    print()
    print(result.to_dataframe(), "\n")
    print("-------------------------------------------"*3)
# Out:
# Região: SA
#
# Subgrupo: Acro Bike==False AND Chaotic Swell==False AND Custom Catcher==False AND Mallow & Lana==True AND Reset Stamp==True
# Subgrupo: Acro Bike==False AND Custom Catcher==False AND Mallow & Lana==True AND Reset Stamp==True
# Subgrupo: Acro Bike==False AND Custom Catcher==False AND Great Catcher==True AND Mallow & Lana==True AND Reset Stamp==True
# Subgrupo: Acro Bike==False AND Chaotic Swell==False AND Custom Catcher==False AND Mallow & Lana==True
# Subgrupo: Acro Bike==False AND Chaotic Swell==False AND Custom Catcher==False AND Great Catcher==True AND Mallow & Lana==True
# Subgrupo: Acro Bike==False AND Arceus & Dialga & Palkia-GX==False AND Chaotic Swell==False AND Custom Catcher==False AND Mallow & Lana==True
# Subgrupo: Acro Bike==False AND Custom Catcher==False AND Mallow & Lana==True
# Subgrupo: Acro Bike==False AND Custom Catcher==False AND Great Catcher==True AND Mallow & Lana==True
# Subgrupo: Acro Bike==False AND Arceus & Dialga & Palkia-GX==False AND Custom Catcher==False AND Mallow & Lana==True AND Reset Stamp==True
# Subgrupo: Acro Bike==False AND Arceus & Dialga & Palkia-GX==False AND Custom Catcher==False AND Mallow & Lana==True
# Subgrupo: Acro Bike==False AND Arceus & Dialga & Palkia-GX==False AND Custom Catcher==False AND Great Catcher==True AND Mallow & Lana==True
# Subgrupo: Acro Bike==False AND Custom Catcher==False AND Dedenne-GX==True
# Subgrupo: Acro Bike==False AND Jirachi==True AND Mega Lopunny & Jigglypuff-GX==True
# Subgrupo: Acro Bike==False AND Jirachi==True AND Mega Lopunny & Jigglypuff-GX==True AND Switch==True
# Subgrupo: Acro Bike==False AND Escape Board==True AND Mega Lopunny & Jigglypuff-GX==True
# Subgrupo: Acro Bike==False AND Escape Board==True AND Mega Lopunny & Jigglypuff-GX==True AND Switch==True
# Subgrupo: Acro Bike==False AND Escape Board==True AND Jirachi==True AND Mega Lopunny & Jigglypuff-GX==True
# Subgrupo: Acro Bike==False AND Dedenne-GX==True AND Mega Lopunny & Jigglypuff-GX==True AND Switch==True
# Subgrupo: Acro Bike==False AND Dedenne-GX==True AND Jirachi==True AND Mega Lopunny & Jigglypuff-GX==True
# Subgrupo: Acro Bike==False AND Dedenne-GX==True AND Escape Board==True AND Mega Lopunny & Jigglypuff-GX==True
#
#      quality                                           subgroup  size_sg  \
# 0   0.059298  Acro Bike==False AND Chaotic Swell==False AND ...        7
# 1   0.058548  Acro Bike==False AND Custom Catcher==False AND...       18
# 2   0.058548  Acro Bike==False AND Custom Catcher==False AND...       18
# 3   0.057985  Acro Bike==False AND Chaotic Swell==False AND ...        8
# 4   0.057985  Acro Bike==False AND Chaotic Swell==False AND ...        8
# 5   0.057985  Acro Bike==False AND Arceus & Dialga & Palkia-...        8
# 6   0.057234  Acro Bike==False AND Custom Catcher==False AND...       19
# 7   0.057234  Acro Bike==False AND Custom Catcher==False AND...       19
# 8   0.056671  Acro Bike==False AND Arceus & Dialga & Palkia-...        9
# 9   0.055357  Acro Bike==False AND Arceus & Dialga & Palkia-...       10
# 10  0.055357  Acro Bike==False AND Arceus & Dialga & Palkia-...       10
# 11  0.054607  Acro Bike==False AND Custom Catcher==False AND...       21
# 12  0.054044  Acro Bike==False AND Jirachi==True AND Mega Lo...       11
# 13  0.054044  Acro Bike==False AND Jirachi==True AND Mega Lo...       11
# 14  0.054044  Acro Bike==False AND Escape Board==True AND Me...       11
# 15  0.054044  Acro Bike==False AND Escape Board==True AND Me...       11
# 16  0.054044  Acro Bike==False AND Escape Board==True AND Ji...       11
# 17  0.054044  Acro Bike==False AND Dedenne-GX==True AND Mega...       11
# 18  0.054044  Acro Bike==False AND Dedenne-GX==True AND Jira...       11
# 19  0.054044  Acro Bike==False AND Dedenne-GX==True AND Esca...       11
#
#     size_dataset  positives_sg  positives_dataset  size_complement  \
# 0             73             5                  7               66
# 1             73             6                  7               55
# 2             73             6                  7               55
# 3             73             5                  7               65
# 4             73             5                  7               65
# 5             73             5                  7               65
# 6             73             6                  7               54
# 7             73             6                  7               54
# 8             73             5                  7               64
# 9             73             5                  7               63
# 10            73             5                  7               63
# 11            73             6                  7               52
# 12            73             5                  7               62
# 13            73             5                  7               62
# 14            73             5                  7               62
# 15            73             5                  7               62
# 16            73             5                  7               62
# 17            73             5                  7               62
# 18            73             5                  7               62
# 19            73             5                  7               62
#
#     relative_size_sg  relative_size_complement  coverage_sg  \
# 0           0.095890                  0.904110     0.714286
# 1           0.246575                  0.753425     0.857143
# 2           0.246575                  0.753425     0.857143
# 3           0.109589                  0.890411     0.714286
# 4           0.109589                  0.890411     0.714286
# 5           0.109589                  0.890411     0.714286
# 6           0.260274                  0.739726     0.857143
# 7           0.260274                  0.739726     0.857143
# 8           0.123288                  0.876712     0.714286
# 9           0.136986                  0.863014     0.714286
# 10          0.136986                  0.863014     0.714286
# 11          0.287671                  0.712329     0.857143
# 12          0.150685                  0.849315     0.714286
# 13          0.150685                  0.849315     0.714286
# 14          0.150685                  0.849315     0.714286
# 15          0.150685                  0.849315     0.714286
# 16          0.150685                  0.849315     0.714286
# 17          0.150685                  0.849315     0.714286
# 18          0.150685                  0.849315     0.714286
# 19          0.150685                  0.849315     0.714286
#
#     coverage_complement  target_share_sg  target_share_complement  \
# 0              0.285714         0.714286                 0.030303
# 1              0.142857         0.333333                 0.018182
# 2              0.142857         0.333333                 0.018182
# 3              0.285714         0.625000                 0.030769
# 4              0.285714         0.625000                 0.030769
# 5              0.285714         0.625000                 0.030769
# 6              0.142857         0.315789                 0.018519
# 7              0.142857         0.315789                 0.018519
# 8              0.285714         0.555556                 0.031250
# 9              0.285714         0.500000                 0.031746
# 10             0.285714         0.500000                 0.031746
# 11             0.142857         0.285714                 0.019231
# 12             0.285714         0.454545                 0.032258
# 13             0.285714         0.454545                 0.032258
# 14             0.285714         0.454545                 0.032258
# 15             0.285714         0.454545                 0.032258
# 16             0.285714         0.454545                 0.032258
# 17             0.285714         0.454545                 0.032258
# 18             0.285714         0.454545                 0.032258
# 19             0.285714         0.454545                 0.032258
#
#     target_share_dataset      lift
# 0                0.09589  7.448980
# 1                0.09589  3.476190
# 2                0.09589  3.476190
# 3                0.09589  6.517857
# 4                0.09589  6.517857
# 5                0.09589  6.517857
# 6                0.09589  3.293233
# 7                0.09589  3.293233
# 8                0.09589  5.793651
# 9                0.09589  5.214286
# 10               0.09589  5.214286
# 11               0.09589  2.979592
# 12               0.09589  4.740260
# 13               0.09589  4.740260
# 14               0.09589  4.740260
# 15               0.09589  4.740260
# 16               0.09589  4.740260
# 17               0.09589  4.740260
# 18               0.09589  4.740260
# 19               0.09589  4.740260
#
# ---------------------------------------------------------------------------------------------------------------------------------
# Região: EU
#
# Subgrupo: Jirachi==True AND Rescue Stretcher==False AND Switch==True AND Zeraora-GX==True
# Subgrupo: Jirachi==True AND Rescue Stretcher==False AND Switch==True AND Thunder Mountain ♢==True
# Subgrupo: Jirachi==True AND Rescue Stretcher==False AND Switch==True AND Tapu Koko ♢==True
# Subgrupo: Jirachi==True AND Pikachu & Zekrom-GX==True AND Rescue Stretcher==False AND Switch==True
# Subgrupo: Escape Board==True AND Rescue Stretcher==False AND Zeraora-GX==True
# Subgrupo: Escape Board==True AND Rescue Stretcher==False AND Thunder Mountain ♢==True
# Subgrupo: Escape Board==True AND Rescue Stretcher==False AND Tapu Koko ♢==True
# Subgrupo: Escape Board==True AND Rescue Stretcher==False AND Switch==True AND Zeraora-GX==True
# Subgrupo: Escape Board==True AND Rescue Stretcher==False AND Switch==True AND Thunder Mountain ♢==True
# Subgrupo: Escape Board==True AND Rescue Stretcher==False AND Switch==True AND Tapu Koko ♢==True
# Subgrupo: Escape Board==True AND Pikachu & Zekrom-GX==True AND Rescue Stretcher==False
# Subgrupo: Escape Board==True AND Pikachu & Zekrom-GX==True AND Rescue Stretcher==False AND Switch==True
# Subgrupo: Escape Board==True AND Jirachi==True AND Pikachu & Zekrom-GX==True AND Rescue Stretcher==False
# Subgrupo: Energy Switch==True AND Jirachi==True AND Rescue Stretcher==False AND Switch==True
# Subgrupo: Energy Switch==True AND Escape Board==True AND Rescue Stretcher==False
# Subgrupo: Energy Switch==True AND Escape Board==True AND Rescue Stretcher==False AND Switch==True
# Subgrupo: Electropower==True AND Jirachi==True AND Rescue Stretcher==False AND Switch==True
# Subgrupo: Electropower==True AND Escape Board==True AND Rescue Stretcher==False
# Subgrupo: Electropower==True AND Escape Board==True AND Rescue Stretcher==False AND Switch==True
# Subgrupo: Electropower==True AND Escape Board==True AND Jirachi==True AND Rescue Stretcher==False
#
#     quality                                           subgroup  size_sg  \
# 0   0.04526  Jirachi==True AND Rescue Stretcher==False AND ...       14
# 1   0.04526  Jirachi==True AND Rescue Stretcher==False AND ...       14
# 2   0.04526  Jirachi==True AND Rescue Stretcher==False AND ...       14
# 3   0.04526  Jirachi==True AND Pikachu & Zekrom-GX==True AN...       14
# 4   0.04526  Escape Board==True AND Rescue Stretcher==False...       14
# 5   0.04526  Escape Board==True AND Rescue Stretcher==False...       14
# 6   0.04526  Escape Board==True AND Rescue Stretcher==False...       14
# 7   0.04526  Escape Board==True AND Rescue Stretcher==False...       14
# 8   0.04526  Escape Board==True AND Rescue Stretcher==False...       14
# 9   0.04526  Escape Board==True AND Rescue Stretcher==False...       14
# 10  0.04526  Escape Board==True AND Pikachu & Zekrom-GX==Tr...       14
# 11  0.04526  Escape Board==True AND Pikachu & Zekrom-GX==Tr...       14
# 12  0.04526  Escape Board==True AND Jirachi==True AND Pikac...       14
# 13  0.04526  Energy Switch==True AND Jirachi==True AND Resc...       14
# 14  0.04526  Energy Switch==True AND Escape Board==True AND...       14
# 15  0.04526  Energy Switch==True AND Escape Board==True AND...       14
# 16  0.04526  Electropower==True AND Jirachi==True AND Rescu...       14
# 17  0.04526  Electropower==True AND Escape Board==True AND ...       14
# 18  0.04526  Electropower==True AND Escape Board==True AND ...       14
# 19  0.04526  Electropower==True AND Escape Board==True AND ...       14
#
#     size_dataset  positives_sg  positives_dataset  size_complement  \
# 0             85             5                  7               71
# 1             85             5                  7               71
# 2             85             5                  7               71
# 3             85             5                  7               71
# 4             85             5                  7               71
# 5             85             5                  7               71
# 6             85             5                  7               71
# 7             85             5                  7               71
# 8             85             5                  7               71
# 9             85             5                  7               71
# 10            85             5                  7               71
# 11            85             5                  7               71
# 12            85             5                  7               71
# 13            85             5                  7               71
# 14            85             5                  7               71
# 15            85             5                  7               71
# 16            85             5                  7               71
# 17            85             5                  7               71
# 18            85             5                  7               71
# 19            85             5                  7               71
#
#     relative_size_sg  relative_size_complement  coverage_sg  \
# 0           0.164706                  0.835294     0.714286
# 1           0.164706                  0.835294     0.714286
# 2           0.164706                  0.835294     0.714286
# 3           0.164706                  0.835294     0.714286
# 4           0.164706                  0.835294     0.714286
# 5           0.164706                  0.835294     0.714286
# 6           0.164706                  0.835294     0.714286
# 7           0.164706                  0.835294     0.714286
# 8           0.164706                  0.835294     0.714286
# 9           0.164706                  0.835294     0.714286
# 10          0.164706                  0.835294     0.714286
# 11          0.164706                  0.835294     0.714286
# 12          0.164706                  0.835294     0.714286
# 13          0.164706                  0.835294     0.714286
# 14          0.164706                  0.835294     0.714286
# 15          0.164706                  0.835294     0.714286
# 16          0.164706                  0.835294     0.714286
# 17          0.164706                  0.835294     0.714286
# 18          0.164706                  0.835294     0.714286
# 19          0.164706                  0.835294     0.714286
#
#     coverage_complement  target_share_sg  target_share_complement  \
# 0              0.285714         0.357143                 0.028169
# 1              0.285714         0.357143                 0.028169
# 2              0.285714         0.357143                 0.028169
# 3              0.285714         0.357143                 0.028169
# 4              0.285714         0.357143                 0.028169
# 5              0.285714         0.357143                 0.028169
# 6              0.285714         0.357143                 0.028169
# 7              0.285714         0.357143                 0.028169
# 8              0.285714         0.357143                 0.028169
# 9              0.285714         0.357143                 0.028169
# 10             0.285714         0.357143                 0.028169
# 11             0.285714         0.357143                 0.028169
# 12             0.285714         0.357143                 0.028169
# 13             0.285714         0.357143                 0.028169
# 14             0.285714         0.357143                 0.028169
# 15             0.285714         0.357143                 0.028169
# 16             0.285714         0.357143                 0.028169
# 17             0.285714         0.357143                 0.028169
# 18             0.285714         0.357143                 0.028169
# 19             0.285714         0.357143                 0.028169
#
#     target_share_dataset      lift
# 0               0.082353  4.336735
# 1               0.082353  4.336735
# 2               0.082353  4.336735
# 3               0.082353  4.336735
# 4               0.082353  4.336735
# 5               0.082353  4.336735
# 6               0.082353  4.336735
# 7               0.082353  4.336735
# 8               0.082353  4.336735
# 9               0.082353  4.336735
# 10              0.082353  4.336735
# 11              0.082353  4.336735
# 12              0.082353  4.336735
# 13              0.082353  4.336735
# 14              0.082353  4.336735
# 15              0.082353  4.336735
# 16              0.082353  4.336735
# 17              0.082353  4.336735
# 18              0.082353  4.336735
# 19              0.082353  4.336735
#
# ---------------------------------------------------------------------------------------------------------------------------------
# Região: AS-OC
#
# Subgrupo: Acerola==False AND Marshadow-GX==False AND Marshadow==True AND Professor Kukui==False AND Zeraora-GX==False
# Subgrupo: Lycanroc-GX==False AND Marshadow-GX==False AND Marshadow==True AND Professor Kukui==False AND Zeraora-GX==False
# Subgrupo: Acerola==False AND Lycanroc-GX==False AND Marshadow-GX==False AND Marshadow==True AND Zeraora-GX==False
# Subgrupo: Acerola==False AND Erika's Hospitality==False AND Marshadow==True AND Professor Kukui==False AND Zeraora-GX==False
# Subgrupo: Marshadow-GX==False AND Marshadow==True AND Professor Kukui==False AND Zeraora-GX==False
# Subgrupo: Erika's Hospitality==False AND Marshadow-GX==False AND Marshadow==True AND Professor Kukui==False AND Zeraora-GX==False
# Subgrupo: Acerola==False AND Erika's Hospitality==False AND Marshadow-GX==False AND Marshadow==True AND Zeraora-GX==False
# Subgrupo: Acerola==False AND Erika's Hospitality==False AND Lycanroc-GX==False AND Marshadow==True AND Zeraora-GX==False
# Subgrupo: Lycanroc-GX==False AND Marshadow-GX==False AND Marshadow==True AND Zeraora-GX==False
# Subgrupo: Acerola==False AND Marshadow-GX==False AND Marshadow==True AND Zeraora-GX==False
# Subgrupo: Acerola==False AND Erika's Hospitality==False AND Marshadow-GX==False AND Marshadow==True AND Professor Kukui==False
# Subgrupo: Erika's Hospitality==False AND Lycanroc-GX==False AND Marshadow==True AND Professor Kukui==False AND Zeraora-GX==False
# Subgrupo: Erika's Hospitality==False AND Lycanroc-GX==False AND Marshadow-GX==False AND Marshadow==True AND Zeraora-GX==False
# Subgrupo: Acerola==False AND Erika's Hospitality==False AND Marshadow==True AND Zeraora-GX==False
# Subgrupo: Acerola==False AND Energy Switch==False AND Marshadow-GX==False AND Marshadow==True AND Professor Kukui==False
# Subgrupo: Acerola==False AND Lycanroc-GX==False AND Marshadow-GX==False AND Marshadow==True AND Professor Kukui==False
# Subgrupo: Erika's Hospitality==False AND Marshadow==True AND Professor Kukui==False AND Zeraora-GX==False
# Subgrupo: Acerola==False AND Lycanroc-GX==False AND Marshadow==True AND Professor Kukui==False AND Zeraora-GX==False
# Subgrupo: Acerola==False AND Erika's Hospitality==False AND Lycanroc-GX==False AND Marshadow==True AND Professor Kukui==False
# Subgrupo: Acerola==False AND Erika's Hospitality==False AND Lycanroc-GX==False AND Marshadow-GX==False AND Marshadow==True
#
#      quality                                           subgroup  size_sg  \
# 0   0.061604  Acerola==False AND Marshadow-GX==False AND Mar...       29
# 1   0.060083  Lycanroc-GX==False AND Marshadow-GX==False AND...       30
# 2   0.060083  Acerola==False AND Lycanroc-GX==False AND Mars...       30
# 3   0.059554  Acerola==False AND Erika's Hospitality==False ...       25
# 4   0.059092  Marshadow-GX==False AND Marshadow==True AND Pr...       36
# 5   0.058563  Erika's Hospitality==False AND Marshadow-GX==F...       31
# 6   0.058034  Acerola==False AND Erika's Hospitality==False ...       26
# 7   0.058034  Acerola==False AND Erika's Hospitality==False ...       26
# 8   0.057043  Lycanroc-GX==False AND Marshadow-GX==False AND...       32
# 9   0.057043  Acerola==False AND Marshadow-GX==False AND Mar...       32
# 10  0.057043  Acerola==False AND Erika's Hospitality==False ...       32
# 11  0.056514  Erika's Hospitality==False AND Lycanroc-GX==Fa...       27
# 12  0.056514  Erika's Hospitality==False AND Lycanroc-GX==Fa...       27
# 13  0.056514  Acerola==False AND Erika's Hospitality==False ...       27
# 14  0.056514  Acerola==False AND Energy Switch==False AND Ma...       27
# 15  0.056051  Acerola==False AND Lycanroc-GX==False AND Mars...       38
# 16  0.055523  Erika's Hospitality==False AND Marshadow==True...       33
# 17  0.055523  Acerola==False AND Lycanroc-GX==False AND Mars...       33
# 18  0.055523  Acerola==False AND Erika's Hospitality==False ...       33
# 19  0.055523  Acerola==False AND Erika's Hospitality==False ...       33
#
#     size_dataset  positives_sg  positives_dataset  size_complement  \
# 0            123            13                 23               94
# 1            123            13                 23               93
# 2            123            13                 23               93
# 3            123            12                 23               98
# 4            123            14                 23               87
# 5            123            13                 23               92
# 6            123            12                 23               97
# 7            123            12                 23               97
# 8            123            13                 23               91
# 9            123            13                 23               91
# 10           123            13                 23               91
# 11           123            12                 23               96
# 12           123            12                 23               96
# 13           123            12                 23               96
# 14           123            12                 23               96
# 15           123            14                 23               85
# 16           123            13                 23               90
# 17           123            13                 23               90
# 18           123            13                 23               90
# 19           123            13                 23               90
#
#     relative_size_sg  relative_size_complement  coverage_sg  \
# 0           0.235772                  0.764228     0.565217
# 1           0.243902                  0.756098     0.565217
# 2           0.243902                  0.756098     0.565217
# 3           0.203252                  0.796748     0.521739
# 4           0.292683                  0.707317     0.608696
# 5           0.252033                  0.747967     0.565217
# 6           0.211382                  0.788618     0.521739
# 7           0.211382                  0.788618     0.521739
# 8           0.260163                  0.739837     0.565217
# 9           0.260163                  0.739837     0.565217
# 10          0.260163                  0.739837     0.565217
# 11          0.219512                  0.780488     0.521739
# 12          0.219512                  0.780488     0.521739
# 13          0.219512                  0.780488     0.521739
# 14          0.219512                  0.780488     0.521739
# 15          0.308943                  0.691057     0.608696
# 16          0.268293                  0.731707     0.565217
# 17          0.268293                  0.731707     0.565217
# 18          0.268293                  0.731707     0.565217
# 19          0.268293                  0.731707     0.565217
#
#     coverage_complement  target_share_sg  target_share_complement  \
# 0              0.434783         0.448276                 0.106383
# 1              0.434783         0.433333                 0.107527
# 2              0.434783         0.433333                 0.107527
# 3              0.478261         0.480000                 0.112245
# 4              0.391304         0.388889                 0.103448
# 5              0.434783         0.419355                 0.108696
# 6              0.478261         0.461538                 0.113402
# 7              0.478261         0.461538                 0.113402
# 8              0.434783         0.406250                 0.109890
# 9              0.434783         0.406250                 0.109890
# 10             0.434783         0.406250                 0.109890
# 11             0.478261         0.444444                 0.114583
# 12             0.478261         0.444444                 0.114583
# 13             0.478261         0.444444                 0.114583
# 14             0.478261         0.444444                 0.114583
# 15             0.391304         0.368421                 0.105882
# 16             0.434783         0.393939                 0.111111
# 17             0.434783         0.393939                 0.111111
# 18             0.434783         0.393939                 0.111111
# 19             0.434783         0.393939                 0.111111
#
#     target_share_dataset      lift
# 0               0.186992  2.397301
# 1               0.186992  2.317391
# 2               0.186992  2.317391
# 3               0.186992  2.566957
# 4               0.186992  2.079710
# 5               0.186992  2.242637
# 6               0.186992  2.468227
# 7               0.186992  2.468227
# 8               0.186992  2.172554
# 9               0.186992  2.172554
# 10              0.186992  2.172554
# 11              0.186992  2.376812
# 12              0.186992  2.376812
# 13              0.186992  2.376812
# 14              0.186992  2.376812
# 15              0.186992  1.970252
# 16              0.186992  2.106719
# 17              0.186992  2.106719
# 18              0.186992  2.106719
# 19              0.186992  2.106719
#
# ---------------------------------------------------------------------------------------------------------------------------------
# Região: JP
#
# Subgrupo: Cynthia==False AND Lillie==False AND Reset Stamp==True AND Switch==True
# Subgrupo: Cynthia==False AND Erika's Hospitality==False AND Lillie==False AND Reset Stamp==True AND Switch==True
# Subgrupo: Cynthia==False AND Reset Stamp==True AND Switch==True
# Subgrupo: Cynthia==False AND Lillie==False AND Reset Stamp==True
# Subgrupo: Cynthia==False AND Erika's Hospitality==False AND Reset Stamp==True AND Switch==True
# Subgrupo: Cynthia==False AND Erika's Hospitality==False AND Lillie==False AND Reset Stamp==True
# Subgrupo: Lillie==False AND Reset Stamp==True
# Subgrupo: Erika's Hospitality==False AND Lillie==False AND Reset Stamp==True
# Subgrupo: Reset Stamp==True AND Switch==True
# Subgrupo: Erika's Hospitality==False AND Reset Stamp==True AND Switch==True
# Subgrupo: Lillie==False AND Reset Stamp==True AND Switch==True
# Subgrupo: Erika's Hospitality==False AND Lillie==False AND Reset Stamp==True AND Switch==True
# Subgrupo: Erika's Hospitality==False AND Reset Stamp==True
# Subgrupo: Cynthia==False AND Rescue Stretcher==False AND Reset Stamp==True AND Switch==True
# Subgrupo: Cynthia==False AND Lillie==False AND Rescue Stretcher==False AND Reset Stamp==True AND Switch==True
# Subgrupo: Cynthia==False AND Erika's Hospitality==False AND Rescue Stretcher==False AND Reset Stamp==True AND Switch==True
# Subgrupo: Acerola==False AND Cynthia==False AND Lillie==False AND Reset Stamp==True AND Switch==True
# Subgrupo: Cynthia==False AND Rescue Stretcher==False AND Switch==True
# Subgrupo: Cynthia==False AND Lillie==False AND Switch==True
# Subgrupo: Rescue Stretcher==False AND Reset Stamp==True AND Switch==True
#
#      quality                                           subgroup  size_sg  \
# 0   0.076528  Cynthia==False AND Lillie==False AND Reset Sta...       13
# 1   0.076528  Cynthia==False AND Erika's Hospitality==False ...       13
# 2   0.074365  Cynthia==False AND Reset Stamp==True AND Switc...       14
# 3   0.074365  Cynthia==False AND Lillie==False AND Reset Sta...       14
# 4   0.074365  Cynthia==False AND Erika's Hospitality==False ...       14
# 5   0.074365  Cynthia==False AND Erika's Hospitality==False ...       14
# 6   0.073012                Lillie==False AND Reset Stamp==True       20
# 7   0.073012  Erika's Hospitality==False AND Lillie==False A...       20
# 8   0.070849                 Reset Stamp==True AND Switch==True       21
# 9   0.070849  Erika's Hospitality==False AND Reset Stamp==Tr...       21
# 10  0.067875  Lillie==False AND Reset Stamp==True AND Switch...       17
# 11  0.067875  Erika's Hospitality==False AND Lillie==False A...       17
# 12  0.067334   Erika's Hospitality==False AND Reset Stamp==True       28
# 13  0.067063  Cynthia==False AND Rescue Stretcher==False AND...       12
# 14  0.067063  Cynthia==False AND Lillie==False AND Rescue St...       12
# 15  0.067063  Cynthia==False AND Erika's Hospitality==False ...       12
# 16  0.067063  Acerola==False AND Cynthia==False AND Lillie==...       12
# 17  0.066522  Cynthia==False AND Rescue Stretcher==False AND...       23
# 18  0.066522  Cynthia==False AND Lillie==False AND Switch==True       23
# 19  0.065711  Rescue Stretcher==False AND Reset Stamp==True ...       18
#
#     size_dataset  positives_sg  positives_dataset  size_complement  \
# 0             86             9                 16               73
# 1             86             9                 16               73
# 2             86             9                 16               72
# 3             86             9                 16               72
# 4             86             9                 16               72
# 5             86             9                 16               72
# 6             86            10                 16               66
# 7             86            10                 16               66
# 8             86            10                 16               65
# 9             86            10                 16               65
# 10            86             9                 16               69
# 11            86             9                 16               69
# 12            86            11                 16               58
# 13            86             8                 16               74
# 14            86             8                 16               74
# 15            86             8                 16               74
# 16            86             8                 16               74
# 17            86            10                 16               63
# 18            86            10                 16               63
# 19            86             9                 16               68
#
#     relative_size_sg  relative_size_complement  coverage_sg  \
# 0           0.151163                  0.848837       0.5625
# 1           0.151163                  0.848837       0.5625
# 2           0.162791                  0.837209       0.5625
# 3           0.162791                  0.837209       0.5625
# 4           0.162791                  0.837209       0.5625
# 5           0.162791                  0.837209       0.5625
# 6           0.232558                  0.767442       0.6250
# 7           0.232558                  0.767442       0.6250
# 8           0.244186                  0.755814       0.6250
# 9           0.244186                  0.755814       0.6250
# 10          0.197674                  0.802326       0.5625
# 11          0.197674                  0.802326       0.5625
# 12          0.325581                  0.674419       0.6875
# 13          0.139535                  0.860465       0.5000
# 14          0.139535                  0.860465       0.5000
# 15          0.139535                  0.860465       0.5000
# 16          0.139535                  0.860465       0.5000
# 17          0.267442                  0.732558       0.6250
# 18          0.267442                  0.732558       0.6250
# 19          0.209302                  0.790698       0.5625
#
#     coverage_complement  target_share_sg  target_share_complement  \
# 0                0.4375         0.692308                 0.095890
# 1                0.4375         0.692308                 0.095890
# 2                0.4375         0.642857                 0.097222
# 3                0.4375         0.642857                 0.097222
# 4                0.4375         0.642857                 0.097222
# 5                0.4375         0.642857                 0.097222
# 6                0.3750         0.500000                 0.090909
# 7                0.3750         0.500000                 0.090909
# 8                0.3750         0.476190                 0.092308
# 9                0.3750         0.476190                 0.092308
# 10               0.4375         0.529412                 0.101449
# 11               0.4375         0.529412                 0.101449
# 12               0.3125         0.392857                 0.086207
# 13               0.5000         0.666667                 0.108108
# 14               0.5000         0.666667                 0.108108
# 15               0.5000         0.666667                 0.108108
# 16               0.5000         0.666667                 0.108108
# 17               0.3750         0.434783                 0.095238
# 18               0.3750         0.434783                 0.095238
# 19               0.4375         0.500000                 0.102941
#
#     target_share_dataset      lift
# 0               0.186047  3.721154
# 1               0.186047  3.721154
# 2               0.186047  3.455357
# 3               0.186047  3.455357
# 4               0.186047  3.455357
# 5               0.186047  3.455357
# 6               0.186047  2.687500
# 7               0.186047  2.687500
# 8               0.186047  2.559524
# 9               0.186047  2.559524
# 10              0.186047  2.845588
# 11              0.186047  2.845588
# 12              0.186047  2.111607
# 13              0.186047  3.583333
# 14              0.186047  3.583333
# 15              0.186047  3.583333
# 16              0.186047  3.583333
# 17              0.186047  2.336957
# 18              0.186047  2.336957
# 19              0.186047  2.687500
#
# ---------------------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# ### Ignorando Regioes

# %%
df_all = df[(df['year_tournament'] == ANO_ANALISAR)]

# verifica se tem torneios
if len(df_all) == 0:
    print(f'Sem torneios no ano {ANO_ANALISAR}')
    print("-------------------------------------------"*3)
    exit()

# calcula subgrupo
df_all = elimina_cards_menos_usados(df_all)
dataset = subgrupo_dataset_region(df_all)
result = calcula_subgrupo(dataset)

# imprime resultados
for row in result.to_dataframe().itertuples():
    print(f"Subgrupo: {row.subgroup}")
print()
print(result.to_dataframe(), "\n")
print("-------------------------------------------"*3)
# Out:
# Subgrupo: Acro Bike==False AND Energy Spinner==False AND Malamar==False AND Rescue Stretcher==False AND Switch==True
# Subgrupo: Acro Bike==False AND Energy Spinner==False AND Inkay==False AND Rescue Stretcher==False AND Switch==True
# Subgrupo: Acro Bike==False AND Energy Spinner==False AND Keldeo-GX==False AND Rescue Stretcher==False AND Switch==True
# Subgrupo: Acro Bike==False AND Ditto ♢==False AND Energy Spinner==False AND Rescue Stretcher==False AND Switch==True
# Subgrupo: Acro Bike==False AND Energy Spinner==False AND Rescue Stretcher==False AND Switch==True AND Tate & Liza==False
# Subgrupo: Acro Bike==False AND Energy Spinner==False AND Giratina==False AND Rescue Stretcher==False AND Switch==True
# Subgrupo: Acro Bike==False AND Energy Spinner==False AND Gengar & Mimikyu-GX==False AND Rescue Stretcher==False AND Switch==True
# Subgrupo: Acro Bike==False AND Arceus & Dialga & Palkia-GX==False AND Beast Ring==False AND Rescue Stretcher==False AND Switch==True
# Subgrupo: Acro Bike==False AND Beast Ring==False AND Energy Spinner==False AND Rescue Stretcher==False AND Switch==True
# Subgrupo: Acro Bike==False AND Arceus & Dialga & Palkia-GX==False AND Rescue Stretcher==False AND Switch==True AND Tate & Liza==False
# Subgrupo: Acro Bike==False AND Arceus & Dialga & Palkia-GX==False AND Giratina==False AND Rescue Stretcher==False AND Switch==True
# Subgrupo: Acro Bike==False AND Chaotic Swell==False AND Energy Spinner==False AND Rescue Stretcher==False AND Switch==True
# Subgrupo: Acro Bike==False AND Arceus & Dialga & Palkia-GX==False AND Energy Spinner==False AND Rescue Stretcher==False AND Switch==True
# Subgrupo: Acro Bike==False AND Arceus & Dialga & Palkia-GX==False AND Max Potion==False AND Rescue Stretcher==False AND Switch==True
# Subgrupo: Acro Bike==False AND Energy Spinner==False AND Rescue Stretcher==False AND Switch==True AND Ultra Necrozma-GX==False
# Subgrupo: Acro Bike==False AND Energy Spinner==False AND Professor Elm's Lecture==False AND Rescue Stretcher==False AND Switch==True
# Subgrupo: Acro Bike==False AND Energy Spinner==False AND Marshadow-GX==False AND Rescue Stretcher==False AND Switch==True
# Subgrupo: Acro Bike==False AND Buzzwole==False AND Energy Spinner==False AND Rescue Stretcher==False AND Switch==True
# Subgrupo: Acro Bike==False AND Arceus & Dialga & Palkia-GX==False AND Rescue Stretcher==False AND Shrine of Punishment==False AND Switch==True
# Subgrupo: Acro Bike==False AND Energy Spinner==False AND Max Potion==False AND Rescue Stretcher==False AND Switch==True
#
#      quality                                           subgroup  size_sg  \
# 0   0.040628  Acro Bike==False AND Energy Spinner==False AND...       82
# 1   0.040628  Acro Bike==False AND Energy Spinner==False AND...       82
# 2   0.040292  Acro Bike==False AND Energy Spinner==False AND...       76
# 3   0.040292  Acro Bike==False AND Ditto ♢==False AND Energy...       76
# 4   0.039839  Acro Bike==False AND Energy Spinner==False AND...       84
# 5   0.039839  Acro Bike==False AND Energy Spinner==False AND...       84
# 6   0.039839  Acro Bike==False AND Energy Spinner==False AND...       84
# 7   0.039839  Acro Bike==False AND Arceus & Dialga & Palkia-...       84
# 8   0.039445  Acro Bike==False AND Beast Ring==False AND Ene...       85
# 9   0.039445  Acro Bike==False AND Arceus & Dialga & Palkia-...       85
# 10  0.039445  Acro Bike==False AND Arceus & Dialga & Palkia-...       85
# 11  0.039167  Acro Bike==False AND Chaotic Swell==False AND ...       72
# 12  0.039167  Acro Bike==False AND Arceus & Dialga & Palkia-...       72
# 13  0.039109  Acro Bike==False AND Arceus & Dialga & Palkia-...       79
# 14  0.039050  Acro Bike==False AND Energy Spinner==False AND...       86
# 15  0.039050  Acro Bike==False AND Energy Spinner==False AND...       86
# 16  0.039050  Acro Bike==False AND Energy Spinner==False AND...       86
# 17  0.039050  Acro Bike==False AND Buzzwole==False AND Energ...       86
# 18  0.039050  Acro Bike==False AND Arceus & Dialga & Palkia-...       86
# 19  0.038714  Acro Bike==False AND Energy Spinner==False AND...       80
#
#     size_dataset  positives_sg  positives_dataset  size_complement  \
# 0            370            27                 54              288
# 1            370            27                 54              288
# 2            370            26                 54              294
# 3            370            26                 54              294
# 4            370            27                 54              286
# 5            370            27                 54              286
# 6            370            27                 54              286
# 7            370            27                 54              286
# 8            370            27                 54              285
# 9            370            27                 54              285
# 10           370            27                 54              285
# 11           370            25                 54              298
# 12           370            25                 54              298
# 13           370            26                 54              291
# 14           370            27                 54              284
# 15           370            27                 54              284
# 16           370            27                 54              284
# 17           370            27                 54              284
# 18           370            27                 54              284
# 19           370            26                 54              290
#
#     relative_size_sg  relative_size_complement  coverage_sg  \
# 0           0.221622                  0.778378     0.500000
# 1           0.221622                  0.778378     0.500000
# 2           0.205405                  0.794595     0.481481
# 3           0.205405                  0.794595     0.481481
# 4           0.227027                  0.772973     0.500000
# 5           0.227027                  0.772973     0.500000
# 6           0.227027                  0.772973     0.500000
# 7           0.227027                  0.772973     0.500000
# 8           0.229730                  0.770270     0.500000
# 9           0.229730                  0.770270     0.500000
# 10          0.229730                  0.770270     0.500000
# 11          0.194595                  0.805405     0.462963
# 12          0.194595                  0.805405     0.462963
# 13          0.213514                  0.786486     0.481481
# 14          0.232432                  0.767568     0.500000
# 15          0.232432                  0.767568     0.500000
# 16          0.232432                  0.767568     0.500000
# 17          0.232432                  0.767568     0.500000
# 18          0.232432                  0.767568     0.500000
# 19          0.216216                  0.783784     0.481481
#
#     coverage_complement  target_share_sg  target_share_complement  \
# 0              0.500000         0.329268                 0.093750
# 1              0.500000         0.329268                 0.093750
# 2              0.518519         0.342105                 0.095238
# 3              0.518519         0.342105                 0.095238
# 4              0.500000         0.321429                 0.094406
# 5              0.500000         0.321429                 0.094406
# 6              0.500000         0.321429                 0.094406
# 7              0.500000         0.321429                 0.094406
# 8              0.500000         0.317647                 0.094737
# 9              0.500000         0.317647                 0.094737
# 10             0.500000         0.317647                 0.094737
# 11             0.537037         0.347222                 0.097315
# 12             0.537037         0.347222                 0.097315
# 13             0.518519         0.329114                 0.096220
# 14             0.500000         0.313953                 0.095070
# 15             0.500000         0.313953                 0.095070
# 16             0.500000         0.313953                 0.095070
# 17             0.500000         0.313953                 0.095070
# 18             0.500000         0.313953                 0.095070
# 19             0.518519         0.325000                 0.096552
#
#     target_share_dataset      lift
# 0               0.145946  2.256098
# 1               0.145946  2.256098
# 2               0.145946  2.344055
# 3               0.145946  2.344055
# 4               0.145946  2.202381
# 5               0.145946  2.202381
# 6               0.145946  2.202381
# 7               0.145946  2.202381
# 8               0.145946  2.176471
# 9               0.145946  2.176471
# 10              0.145946  2.176471
# 11              0.145946  2.379115
# 12              0.145946  2.379115
# 13              0.145946  2.255040
# 14              0.145946  2.151163
# 15              0.145946  2.151163
# 16              0.145946  2.151163
# 17              0.145946  2.151163
# 18              0.145946  2.151163
# 19              0.145946  2.226852
#
# ---------------------------------------------------------------------------------------------------------------------------------
