# %% [markdown]
# Agora vamos tentar identificar o que seria ideal em um deck que possui como alvo a carta `jirachi`

# %%
POKEMON_ALVO = 'Jirachi'
CONSIDERAR_TREINADORES = True
ANO_ANALISAR = 2019

# quantidade de cartas de 1 tipo que deve exitir no dataset para ser considerado evitando outliers 
CARTAS_MINIMAS = 10

# %% [markdown]
# ## Bibliotecas utilizadas e carregando dataset

# %%
import numpy as np
import pandas as pd
import pysubgroup as ps

df_original = pd.read_csv('./Data/tournaments.csv')
df = df_original.copy()

# %% [markdown]
# ## Eliminar cartas de treinador se quiser

# %%
if not CONSIDERAR_TREINADORES:
    df = df[df['type_card'] != 'Trainer']

# %% [markdown]
# ## Filtragem de colunas no dataset e limpeza de linhas com coluna regiao do torneio vazias

# %%
columns_to_remove = [
    'id_card', 'amount_card', 'price_card', 'combo_type_id', 'name_tournament',
    'combo_type_name', 'name_player', 'category_tournament', 'type_card',
    'month_tournament', 'day_tournament', 'valid_rotation_at_tournament', 
    'rotation_name', 'year_begin', 'all_time_score', 'country_tournament', 'country_player',
    'month_begin', 'day_begin',
]
df.drop(columns=columns_to_remove, inplace=True)
df = df[df['region_tournament'].notna()]

df.head(1)
# Out:
#        name_card energy_type_card  id_player  ranking_player_tournament
# 7462  Charmander             Fire        649                          1  \
#
#       id_tournament region_tournament  year_tournament
# 7462            385                SA             2023

# %% [markdown]
# ## Separando por regiao para ver oque sera recomendado nos decks para montar um deck com o `POKEMON_ALVO`

# %%
def elimina_cards_menos_usados(df):
    cartas = df['name_card'].unique()
    for carta in cartas:
        if len(df[df['name_card'] == carta]) < CARTAS_MINIMAS:
            df = df[df['name_card'] != carta]
    return df

def agrupa_deck(df_region):
    #filtra torneios da regiao
    torneios = df_region['id_tournament'].unique()

    lista_decks = []
    for torneio in torneios:
        df_torneio = df_region[df_region['id_tournament'] == torneio]
        jogadores = df_torneio['id_player'].unique()
        for jogador in jogadores:
            df_jogador = df_torneio[df_torneio['id_player'] == jogador]
            cartas_jogador = df_jogador['name_card'].unique().tolist()
            lista_decks.append(cartas_jogador)
    return lista_decks

def subgrupo_dataset_region(df_region):
    lista_decks = agrupa_deck(df_region)
    cartas = df_region['name_card'].unique()
    data = []
    for deck_rank in lista_decks:
        pokemons_no_deck = {carta: (carta in deck_rank[:len(deck_rank)-1]) for carta in cartas}
        data.append(pokemons_no_deck)
    # Converte a lista de dicionários em um DataFrame
    df_decks_cartas = pd.DataFrame(data)

    return df_decks_cartas

def calcula_subgrupo(df):
    target = ps.BinaryTarget(POKEMON_ALVO, True)
    search_space = ps.create_selectors(df, ignore=[POKEMON_ALVO])
    task = ps.SubgroupDiscoveryTask(
        df,
        target, 
        search_space, 
        result_set_size=20, 
        depth=5, 
        qf=ps.WRAccQF()  # Quality function to evaluate subgroups
    )
    result = ps.BeamSearch().execute(task)
    return result

# %% [markdown]
# ### Por regiao

# %%
regions = df['region_tournament'].unique()
for region in regions:
    print(f"Região: {region}\n")
    df_region = df[(df['region_tournament'] == region) & (df['year_tournament'] == ANO_ANALISAR)]

    # verifica se tem torneios na regiao
    if len(df_region) == 0:
        print(f'Sem torneios na região {region} no ano {ANO_ANALISAR}\n')
        print("-------------------------------------------"*3)
        continue

    # verifica se tem a carta POKEMON_ALVO na regiao
    if POKEMON_ALVO not in df_region['name_card'].unique():
        print(f'Sem a carta {POKEMON_ALVO} na região {region}\n')
        print("-------------------------------------------"*3)
        continue

    df_region = elimina_cards_menos_usados(df_region)
    dataset = subgrupo_dataset_region(df_region)
    result = calcula_subgrupo(dataset)

    # imprime resultados
    for row in result.to_dataframe().itertuples():
        print(f"Subgrupo: {row.subgroup}")
    print()
    print(result.to_dataframe(), "\n")
    print("-------------------------------------------"*3)
# Out:
# Região: SA
#
# Subgrupo: Escape Board==True AND Viridian Forest==False
# Subgrupo: Escape Board==True AND Power Plant==False AND Viridian Forest==False
# Subgrupo: Escape Board==True AND Heat Factory ♢==False AND Viridian Forest==False
# Subgrupo: Escape Board==True AND Heat Factory ♢==False AND Power Plant==False AND Viridian Forest==False
# Subgrupo: Escape Board==True AND Green's Exploration==False AND Viridian Forest==False
# Subgrupo: Escape Board==True AND Green's Exploration==False AND Power Plant==False AND Viridian Forest==False
# Subgrupo: Escape Board==True AND Green's Exploration==False AND Heat Factory ♢==False AND Viridian Forest==False
# Subgrupo: Escape Board==True AND Green's Exploration==False AND Heat Factory ♢==False AND Power Plant==False AND Viridian Forest==False
# Subgrupo: Chaotic Swell==False AND Escape Board==True AND Viridian Forest==False
# Subgrupo: Chaotic Swell==False AND Escape Board==True AND Power Plant==False AND Viridian Forest==False
# Subgrupo: Chaotic Swell==False AND Escape Board==True AND Heat Factory ♢==False AND Viridian Forest==False
# Subgrupo: Chaotic Swell==False AND Escape Board==True AND Heat Factory ♢==False AND Power Plant==False AND Viridian Forest==False
# Subgrupo: Chaotic Swell==False AND Escape Board==True AND Green's Exploration==False AND Viridian Forest==False
# Subgrupo: Chaotic Swell==False AND Escape Board==True AND Green's Exploration==False AND Power Plant==False AND Viridian Forest==False
# Subgrupo: Chaotic Swell==False AND Escape Board==True AND Green's Exploration==False AND Heat Factory ♢==False AND Viridian Forest==False
# Subgrupo: Escape Board==True
# Subgrupo: Escape Board==True AND Power Plant==False
# Subgrupo: Escape Board==True AND Heat Factory ♢==False
# Subgrupo: Escape Board==True AND Heat Factory ♢==False AND Power Plant==False
# Subgrupo: Escape Board==True AND Green's Exploration==False
#
#      quality                                           subgroup  size_sg
# 0   0.219553      Escape Board==True AND Viridian Forest==False       39  \
# 1   0.219553  Escape Board==True AND Power Plant==False AND ...       39
# 2   0.219553  Escape Board==True AND Heat Factory ♢==False A...       39
# 3   0.219553  Escape Board==True AND Heat Factory ♢==False A...       39
# 4   0.219553  Escape Board==True AND Green's Exploration==Fa...       39
# 5   0.219553  Escape Board==True AND Green's Exploration==Fa...       39
# 6   0.219553  Escape Board==True AND Green's Exploration==Fa...       39
# 7   0.219553  Escape Board==True AND Green's Exploration==Fa...       39
# 8   0.219553  Chaotic Swell==False AND Escape Board==True AN...       39
# 9   0.219553  Chaotic Swell==False AND Escape Board==True AN...       39
# 10  0.219553  Chaotic Swell==False AND Escape Board==True AN...       39
# 11  0.219553  Chaotic Swell==False AND Escape Board==True AN...       39
# 12  0.219553  Chaotic Swell==False AND Escape Board==True AN...       39
# 13  0.219553  Chaotic Swell==False AND Escape Board==True AN...       39
# 14  0.219553  Chaotic Swell==False AND Escape Board==True AN...       39
# 15  0.211484                                 Escape Board==True       40
# 16  0.211484          Escape Board==True AND Power Plant==False       40
# 17  0.211484       Escape Board==True AND Heat Factory ♢==False       40
# 18  0.211484  Escape Board==True AND Heat Factory ♢==False A...       40
# 19  0.211484  Escape Board==True AND Green's Exploration==False       40
#
#     size_dataset  positives_sg  positives_dataset  size_complement
# 0             73            39                 43               34  \
# 1             73            39                 43               34
# 2             73            39                 43               34
# 3             73            39                 43               34
# 4             73            39                 43               34
# 5             73            39                 43               34
# 6             73            39                 43               34
# 7             73            39                 43               34
# 8             73            39                 43               34
# 9             73            39                 43               34
# 10            73            39                 43               34
# 11            73            39                 43               34
# 12            73            39                 43               34
# 13            73            39                 43               34
# 14            73            39                 43               34
# 15            73            39                 43               33
# 16            73            39                 43               33
# 17            73            39                 43               33
# 18            73            39                 43               33
# 19            73            39                 43               33
#
#     relative_size_sg  relative_size_complement  coverage_sg
# 0           0.534247                  0.465753     0.906977  \
# 1           0.534247                  0.465753     0.906977
# 2           0.534247                  0.465753     0.906977
# 3           0.534247                  0.465753     0.906977
# 4           0.534247                  0.465753     0.906977
# 5           0.534247                  0.465753     0.906977
# 6           0.534247                  0.465753     0.906977
# 7           0.534247                  0.465753     0.906977
# 8           0.534247                  0.465753     0.906977
# 9           0.534247                  0.465753     0.906977
# 10          0.534247                  0.465753     0.906977
# 11          0.534247                  0.465753     0.906977
# 12          0.534247                  0.465753     0.906977
# 13          0.534247                  0.465753     0.906977
# 14          0.534247                  0.465753     0.906977
# 15          0.547945                  0.452055     0.906977
# 16          0.547945                  0.452055     0.906977
# 17          0.547945                  0.452055     0.906977
# 18          0.547945                  0.452055     0.906977
# 19          0.547945                  0.452055     0.906977
#
#     coverage_complement  target_share_sg  target_share_complement
# 0              0.093023            1.000                 0.117647  \
# 1              0.093023            1.000                 0.117647
# 2              0.093023            1.000                 0.117647
# 3              0.093023            1.000                 0.117647
# 4              0.093023            1.000                 0.117647
# 5              0.093023            1.000                 0.117647
# 6              0.093023            1.000                 0.117647
# 7              0.093023            1.000                 0.117647
# 8              0.093023            1.000                 0.117647
# 9              0.093023            1.000                 0.117647
# 10             0.093023            1.000                 0.117647
# 11             0.093023            1.000                 0.117647
# 12             0.093023            1.000                 0.117647
# 13             0.093023            1.000                 0.117647
# 14             0.093023            1.000                 0.117647
# 15             0.093023            0.975                 0.121212
# 16             0.093023            0.975                 0.121212
# 17             0.093023            0.975                 0.121212
# 18             0.093023            0.975                 0.121212
# 19             0.093023            0.975                 0.121212
#
#     target_share_dataset      lift
# 0               0.589041  1.697674
# 1               0.589041  1.697674
# 2               0.589041  1.697674
# 3               0.589041  1.697674
# 4               0.589041  1.697674
# 5               0.589041  1.697674
# 6               0.589041  1.697674
# 7               0.589041  1.697674
# 8               0.589041  1.697674
# 9               0.589041  1.697674
# 10              0.589041  1.697674
# 11              0.589041  1.697674
# 12              0.589041  1.697674
# 13              0.589041  1.697674
# 14              0.589041  1.697674
# 15              0.589041  1.655233
# 16              0.589041  1.655233
# 17              0.589041  1.655233
# 18              0.589041  1.655233
# 19              0.589041  1.655233
#
# ---------------------------------------------------------------------------------------------------------------------------------
# Região: EU
#
# Subgrupo: Acro Bike==False AND Oranguru==False AND Switch==True AND Tate & Liza==False
# Subgrupo: Acro Bike==False AND Oranguru==False AND Switch==True AND Tate & Liza==False AND Thunder Mountain ♢==False
# Subgrupo: Acro Bike==False AND Oranguru==False AND Poipole==False AND Switch==True AND Tate & Liza==False
# Subgrupo: Acro Bike==False AND Rockruff==False AND Switch==True AND Tate & Liza==False
# Subgrupo: Acro Bike==False AND Rockruff==False AND Switch==True AND Tate & Liza==False AND Thunder Mountain ♢==False
# Subgrupo: Acro Bike==False AND Poipole==False AND Rockruff==False AND Switch==True AND Tate & Liza==False
# Subgrupo: Acro Bike==False AND Pal Pad==False AND Switch==True AND Tate & Liza==False
# Subgrupo: Acro Bike==False AND Pal Pad==False AND Switch==True AND Tate & Liza==False AND Thunder Mountain ♢==False
# Subgrupo: Acro Bike==False AND Pal Pad==False AND Poipole==False AND Switch==True AND Tate & Liza==False
# Subgrupo: Acro Bike==False AND Oranguru==False AND Rockruff==False AND Switch==True AND Tate & Liza==False
# Subgrupo: Acro Bike==False AND Lycanroc-GX==False AND Switch==True AND Tate & Liza==False
# Subgrupo: Acro Bike==False AND Lycanroc-GX==False AND Switch==True AND Tate & Liza==False AND Thunder Mountain ♢==False
# Subgrupo: Acro Bike==False AND Lycanroc-GX==False AND Rockruff==False AND Switch==True AND Tate & Liza==False
# Subgrupo: Acro Bike==False AND Lycanroc-GX==False AND Poipole==False AND Switch==True AND Tate & Liza==False
# Subgrupo: Acro Bike==False AND Judge==False AND Switch==True AND Tate & Liza==False
# Subgrupo: Acro Bike==False AND Judge==False AND Switch==True AND Tate & Liza==False AND Thunder Mountain ♢==False
# Subgrupo: Acro Bike==False AND Judge==False AND Poipole==False AND Switch==True AND Tate & Liza==False
# Subgrupo: Acro Bike==False AND Ditto ♢==False AND Switch==True AND Tate & Liza==False
# Subgrupo: Acro Bike==False AND Ditto ♢==False AND Switch==True AND Tate & Liza==False AND Thunder Mountain ♢==False
# Subgrupo: Acro Bike==False AND Ditto ♢==False AND Poipole==False AND Switch==True AND Tate & Liza==False
#
#      quality                                           subgroup  size_sg
# 0   0.232438  Acro Bike==False AND Oranguru==False AND Switc...       50  \
# 1   0.232438  Acro Bike==False AND Oranguru==False AND Switc...       50
# 2   0.232438  Acro Bike==False AND Oranguru==False AND Poipo...       50
# 3   0.227789  Acro Bike==False AND Rockruff==False AND Switc...       49
# 4   0.227789  Acro Bike==False AND Rockruff==False AND Switc...       49
# 5   0.227789  Acro Bike==False AND Poipole==False AND Rockru...       49
# 6   0.227789  Acro Bike==False AND Pal Pad==False AND Switch...       49
# 7   0.227789  Acro Bike==False AND Pal Pad==False AND Switch...       49
# 8   0.227789  Acro Bike==False AND Pal Pad==False AND Poipol...       49
# 9   0.227789  Acro Bike==False AND Oranguru==False AND Rockr...       49
# 10  0.227789  Acro Bike==False AND Lycanroc-GX==False AND Sw...       49
# 11  0.227789  Acro Bike==False AND Lycanroc-GX==False AND Sw...       49
# 12  0.227789  Acro Bike==False AND Lycanroc-GX==False AND Ro...       49
# 13  0.227789  Acro Bike==False AND Lycanroc-GX==False AND Po...       49
# 14  0.227789  Acro Bike==False AND Judge==False AND Switch==...       49
# 15  0.227789  Acro Bike==False AND Judge==False AND Switch==...       49
# 16  0.227789  Acro Bike==False AND Judge==False AND Poipole=...       49
# 17  0.227789  Acro Bike==False AND Ditto ♢==False AND Switch...       49
# 18  0.227789  Acro Bike==False AND Ditto ♢==False AND Switch...       49
# 19  0.227789  Acro Bike==False AND Ditto ♢==False AND Poipol...       49
#
#     size_dataset  positives_sg  positives_dataset  size_complement
# 0             88            50                 52               38  \
# 1             88            50                 52               38
# 2             88            50                 52               38
# 3             88            49                 52               39
# 4             88            49                 52               39
# 5             88            49                 52               39
# 6             88            49                 52               39
# 7             88            49                 52               39
# 8             88            49                 52               39
# 9             88            49                 52               39
# 10            88            49                 52               39
# 11            88            49                 52               39
# 12            88            49                 52               39
# 13            88            49                 52               39
# 14            88            49                 52               39
# 15            88            49                 52               39
# 16            88            49                 52               39
# 17            88            49                 52               39
# 18            88            49                 52               39
# 19            88            49                 52               39
#
#     relative_size_sg  relative_size_complement  coverage_sg
# 0           0.568182                  0.431818     0.961538  \
# 1           0.568182                  0.431818     0.961538
# 2           0.568182                  0.431818     0.961538
# 3           0.556818                  0.443182     0.942308
# 4           0.556818                  0.443182     0.942308
# 5           0.556818                  0.443182     0.942308
# 6           0.556818                  0.443182     0.942308
# 7           0.556818                  0.443182     0.942308
# 8           0.556818                  0.443182     0.942308
# 9           0.556818                  0.443182     0.942308
# 10          0.556818                  0.443182     0.942308
# 11          0.556818                  0.443182     0.942308
# 12          0.556818                  0.443182     0.942308
# 13          0.556818                  0.443182     0.942308
# 14          0.556818                  0.443182     0.942308
# 15          0.556818                  0.443182     0.942308
# 16          0.556818                  0.443182     0.942308
# 17          0.556818                  0.443182     0.942308
# 18          0.556818                  0.443182     0.942308
# 19          0.556818                  0.443182     0.942308
#
#     coverage_complement  target_share_sg  target_share_complement
# 0              0.038462              1.0                 0.052632  \
# 1              0.038462              1.0                 0.052632
# 2              0.038462              1.0                 0.052632
# 3              0.057692              1.0                 0.076923
# 4              0.057692              1.0                 0.076923
# 5              0.057692              1.0                 0.076923
# 6              0.057692              1.0                 0.076923
# 7              0.057692              1.0                 0.076923
# 8              0.057692              1.0                 0.076923
# 9              0.057692              1.0                 0.076923
# 10             0.057692              1.0                 0.076923
# 11             0.057692              1.0                 0.076923
# 12             0.057692              1.0                 0.076923
# 13             0.057692              1.0                 0.076923
# 14             0.057692              1.0                 0.076923
# 15             0.057692              1.0                 0.076923
# 16             0.057692              1.0                 0.076923
# 17             0.057692              1.0                 0.076923
# 18             0.057692              1.0                 0.076923
# 19             0.057692              1.0                 0.076923
#
#     target_share_dataset      lift
# 0               0.590909  1.692308
# 1               0.590909  1.692308
# 2               0.590909  1.692308
# 3               0.590909  1.692308
# 4               0.590909  1.692308
# 5               0.590909  1.692308
# 6               0.590909  1.692308
# 7               0.590909  1.692308
# 8               0.590909  1.692308
# 9               0.590909  1.692308
# 10              0.590909  1.692308
# 11              0.590909  1.692308
# 12              0.590909  1.692308
# 13              0.590909  1.692308
# 14              0.590909  1.692308
# 15              0.590909  1.692308
# 16              0.590909  1.692308
# 17              0.590909  1.692308
# 18              0.590909  1.692308
# 19              0.590909  1.692308
#
# ---------------------------------------------------------------------------------------------------------------------------------
# Região: AS-OC
#
# Subgrupo: Escape Board==True
# Subgrupo: Escape Board==True AND Zorua==False
# Subgrupo: Escape Board==True AND Zoroark-GX==False
# Subgrupo: Escape Board==True AND Zoroark-GX==False AND Zorua==False
# Subgrupo: Escape Board==True AND Professor Elm's Lecture==False
# Subgrupo: Escape Board==True AND Professor Elm's Lecture==False AND Zorua==False
# Subgrupo: Escape Board==True AND Power Plant==False
# Subgrupo: Escape Board==True AND Pokémon Communication==False
# Subgrupo: Escape Board==True AND Pokégear 3.0==False
# Subgrupo: Escape Board==True AND Guzma==True
# Subgrupo: Escape Board==True AND Guzma==True AND Zorua==False
# Subgrupo: Escape Board==True AND Guzma==True AND Zoroark-GX==False
# Subgrupo: Escape Board==True AND Guzma==True AND Pokémon Communication==False
# Subgrupo: Counter Gain==False AND Escape Board==True
# Subgrupo: Alolan Muk==False AND Escape Board==True
# Subgrupo: Alolan Grimer==False AND Escape Board==True
# Subgrupo: Alolan Grimer==False AND Escape Board==True AND Zorua==False
# Subgrupo: Alolan Grimer==False AND Escape Board==True AND Zoroark-GX==False
# Subgrupo: Alolan Grimer==False AND Escape Board==True AND Professor Elm's Lecture==False
# Subgrupo: Alolan Grimer==False AND Escape Board==True AND Pokégear 3.0==False
#
#      quality                                           subgroup  size_sg
# 0   0.222090                                 Escape Board==True       70  \
# 1   0.222090                Escape Board==True AND Zorua==False       70
# 2   0.222090           Escape Board==True AND Zoroark-GX==False       70
# 3   0.222090  Escape Board==True AND Zoroark-GX==False AND Z...       70
# 4   0.218917  Escape Board==True AND Professor Elm's Lecture...       69
# 5   0.218917  Escape Board==True AND Professor Elm's Lecture...       69
# 6   0.218917          Escape Board==True AND Power Plant==False       69
# 7   0.218917  Escape Board==True AND Pokémon Communication==...       69
# 8   0.218917         Escape Board==True AND Pokégear 3.0==False       69
# 9   0.218917                 Escape Board==True AND Guzma==True       69
# 10  0.218917  Escape Board==True AND Guzma==True AND Zorua==...       69
# 11  0.218917  Escape Board==True AND Guzma==True AND Zoroark...       69
# 12  0.218917  Escape Board==True AND Guzma==True AND Pokémon...       69
# 13  0.218917         Counter Gain==False AND Escape Board==True       69
# 14  0.218917           Alolan Muk==False AND Escape Board==True       69
# 15  0.218917        Alolan Grimer==False AND Escape Board==True       69
# 16  0.218917  Alolan Grimer==False AND Escape Board==True AN...       69
# 17  0.218917  Alolan Grimer==False AND Escape Board==True AN...       69
# 18  0.218917  Alolan Grimer==False AND Escape Board==True AN...       69
# 19  0.218917  Alolan Grimer==False AND Escape Board==True AN...       69
#
#     size_dataset  positives_sg  positives_dataset  size_complement
# 0            123            70                 75               53  \
# 1            123            70                 75               53
# 2            123            70                 75               53
# 3            123            70                 75               53
# 4            123            69                 75               54
# 5            123            69                 75               54
# 6            123            69                 75               54
# 7            123            69                 75               54
# 8            123            69                 75               54
# 9            123            69                 75               54
# 10           123            69                 75               54
# 11           123            69                 75               54
# 12           123            69                 75               54
# 13           123            69                 75               54
# 14           123            69                 75               54
# 15           123            69                 75               54
# 16           123            69                 75               54
# 17           123            69                 75               54
# 18           123            69                 75               54
# 19           123            69                 75               54
#
#     relative_size_sg  relative_size_complement  coverage_sg
# 0           0.569106                  0.430894     0.933333  \
# 1           0.569106                  0.430894     0.933333
# 2           0.569106                  0.430894     0.933333
# 3           0.569106                  0.430894     0.933333
# 4           0.560976                  0.439024     0.920000
# 5           0.560976                  0.439024     0.920000
# 6           0.560976                  0.439024     0.920000
# 7           0.560976                  0.439024     0.920000
# 8           0.560976                  0.439024     0.920000
# 9           0.560976                  0.439024     0.920000
# 10          0.560976                  0.439024     0.920000
# 11          0.560976                  0.439024     0.920000
# 12          0.560976                  0.439024     0.920000
# 13          0.560976                  0.439024     0.920000
# 14          0.560976                  0.439024     0.920000
# 15          0.560976                  0.439024     0.920000
# 16          0.560976                  0.439024     0.920000
# 17          0.560976                  0.439024     0.920000
# 18          0.560976                  0.439024     0.920000
# 19          0.560976                  0.439024     0.920000
#
#     coverage_complement  target_share_sg  target_share_complement
# 0              0.066667              1.0                 0.094340  \
# 1              0.066667              1.0                 0.094340
# 2              0.066667              1.0                 0.094340
# 3              0.066667              1.0                 0.094340
# 4              0.080000              1.0                 0.111111
# 5              0.080000              1.0                 0.111111
# 6              0.080000              1.0                 0.111111
# 7              0.080000              1.0                 0.111111
# 8              0.080000              1.0                 0.111111
# 9              0.080000              1.0                 0.111111
# 10             0.080000              1.0                 0.111111
# 11             0.080000              1.0                 0.111111
# 12             0.080000              1.0                 0.111111
# 13             0.080000              1.0                 0.111111
# 14             0.080000              1.0                 0.111111
# 15             0.080000              1.0                 0.111111
# 16             0.080000              1.0                 0.111111
# 17             0.080000              1.0                 0.111111
# 18             0.080000              1.0                 0.111111
# 19             0.080000              1.0                 0.111111
#
#     target_share_dataset  lift
# 0               0.609756  1.64
# 1               0.609756  1.64
# 2               0.609756  1.64
# 3               0.609756  1.64
# 4               0.609756  1.64
# 5               0.609756  1.64
# 6               0.609756  1.64
# 7               0.609756  1.64
# 8               0.609756  1.64
# 9               0.609756  1.64
# 10              0.609756  1.64
# 11              0.609756  1.64
# 12              0.609756  1.64
# 13              0.609756  1.64
# 14              0.609756  1.64
# 15              0.609756  1.64
# 16              0.609756  1.64
# 17              0.609756  1.64
# 18              0.609756  1.64
# 19              0.609756  1.64
#
# ---------------------------------------------------------------------------------------------------------------------------------
# Região: JP
#
# Subgrupo: Escape Board==True AND Pokégear 3.0==False
# Subgrupo: Escape Board==True AND Green's Exploration==False
# Subgrupo: Escape Board==True AND Green's Exploration==False AND Pokégear 3.0==False
# Subgrupo: Ditto ♢==False AND Escape Board==True AND Pokégear 3.0==False
# Subgrupo: Ditto ♢==False AND Escape Board==True AND Green's Exploration==False
# Subgrupo: Ditto ♢==False AND Escape Board==True AND Green's Exploration==False AND Pokégear 3.0==False
# Subgrupo: Escape Board==True AND Switch==True
# Subgrupo: Escape Board==True AND Pokégear 3.0==False AND Switch==True
# Subgrupo: Escape Board==True AND Green's Exploration==False AND Switch==True
# Subgrupo: Escape Board==True AND Green's Exploration==False AND Pokégear 3.0==False AND Switch==True
# Subgrupo: Ditto ♢==False AND Escape Board==True AND Switch==True
# Subgrupo: Ditto ♢==False AND Escape Board==True AND Pokégear 3.0==False AND Switch==True
# Subgrupo: Ditto ♢==False AND Escape Board==True AND Green's Exploration==False AND Switch==True
# Subgrupo: Ditto ♢==False AND Escape Board==True AND Green's Exploration==False AND Pokégear 3.0==False AND Switch==True
# Subgrupo: Escape Board==True
# Subgrupo: Ditto ♢==False AND Escape Board==True
# Subgrupo: Escape Board==True AND Lt. Surge's Strategy==False
# Subgrupo: Escape Board==True AND Lt. Surge's Strategy==False AND Pokégear 3.0==False
# Subgrupo: Escape Board==True AND Green's Exploration==False AND Lt. Surge's Strategy==False
# Subgrupo: Escape Board==True AND Green's Exploration==False AND Lt. Surge's Strategy==False AND Pokégear 3.0==False
#
#      quality                                           subgroup  size_sg
# 0   0.231747         Escape Board==True AND Pokégear 3.0==False       36  \
# 1   0.231747  Escape Board==True AND Green's Exploration==False       36
# 2   0.231747  Escape Board==True AND Green's Exploration==Fa...       36
# 3   0.231747  Ditto ♢==False AND Escape Board==True AND Poké...       36
# 4   0.231747  Ditto ♢==False AND Escape Board==True AND Gree...       36
# 5   0.231747  Ditto ♢==False AND Escape Board==True AND Gree...       36
# 6   0.229854                Escape Board==True AND Switch==True       34
# 7   0.229854  Escape Board==True AND Pokégear 3.0==False AND...       34
# 8   0.229854  Escape Board==True AND Green's Exploration==Fa...       34
# 9   0.229854  Escape Board==True AND Green's Exploration==Fa...       34
# 10  0.229854  Ditto ♢==False AND Escape Board==True AND Swit...       34
# 11  0.229854  Ditto ♢==False AND Escape Board==True AND Poké...       34
# 12  0.229854  Ditto ♢==False AND Escape Board==True AND Gree...       34
# 13  0.229854  Ditto ♢==False AND Escape Board==True AND Gree...       34
# 14  0.226879                                 Escape Board==True       37
# 15  0.226879              Ditto ♢==False AND Escape Board==True       37
# 16  0.224986  Escape Board==True AND Lt. Surge's Strategy==F...       35
# 17  0.224986  Escape Board==True AND Lt. Surge's Strategy==F...       35
# 18  0.224986  Escape Board==True AND Green's Exploration==Fa...       35
# 19  0.224986  Escape Board==True AND Green's Exploration==Fa...       35
#
#     size_dataset  positives_sg  positives_dataset  size_complement
# 0             86            35                 36               50  \
# 1             86            35                 36               50
# 2             86            35                 36               50
# 3             86            35                 36               50
# 4             86            35                 36               50
# 5             86            35                 36               50
# 6             86            34                 36               52
# 7             86            34                 36               52
# 8             86            34                 36               52
# 9             86            34                 36               52
# 10            86            34                 36               52
# 11            86            34                 36               52
# 12            86            34                 36               52
# 13            86            34                 36               52
# 14            86            35                 36               49
# 15            86            35                 36               49
# 16            86            34                 36               51
# 17            86            34                 36               51
# 18            86            34                 36               51
# 19            86            34                 36               51
#
#     relative_size_sg  relative_size_complement  coverage_sg
# 0           0.418605                  0.581395     0.972222  \
# 1           0.418605                  0.581395     0.972222
# 2           0.418605                  0.581395     0.972222
# 3           0.418605                  0.581395     0.972222
# 4           0.418605                  0.581395     0.972222
# 5           0.418605                  0.581395     0.972222
# 6           0.395349                  0.604651     0.944444
# 7           0.395349                  0.604651     0.944444
# 8           0.395349                  0.604651     0.944444
# 9           0.395349                  0.604651     0.944444
# 10          0.395349                  0.604651     0.944444
# 11          0.395349                  0.604651     0.944444
# 12          0.395349                  0.604651     0.944444
# 13          0.395349                  0.604651     0.944444
# 14          0.430233                  0.569767     0.972222
# 15          0.430233                  0.569767     0.972222
# 16          0.406977                  0.593023     0.944444
# 17          0.406977                  0.593023     0.944444
# 18          0.406977                  0.593023     0.944444
# 19          0.406977                  0.593023     0.944444
#
#     coverage_complement  target_share_sg  target_share_complement
# 0              0.027778         0.972222                 0.020000  \
# 1              0.027778         0.972222                 0.020000
# 2              0.027778         0.972222                 0.020000
# 3              0.027778         0.972222                 0.020000
# 4              0.027778         0.972222                 0.020000
# 5              0.027778         0.972222                 0.020000
# 6              0.055556         1.000000                 0.038462
# 7              0.055556         1.000000                 0.038462
# 8              0.055556         1.000000                 0.038462
# 9              0.055556         1.000000                 0.038462
# 10             0.055556         1.000000                 0.038462
# 11             0.055556         1.000000                 0.038462
# 12             0.055556         1.000000                 0.038462
# 13             0.055556         1.000000                 0.038462
# 14             0.027778         0.945946                 0.020408
# 15             0.027778         0.945946                 0.020408
# 16             0.055556         0.971429                 0.039216
# 17             0.055556         0.971429                 0.039216
# 18             0.055556         0.971429                 0.039216
# 19             0.055556         0.971429                 0.039216
#
#     target_share_dataset      lift
# 0               0.418605  2.322531
# 1               0.418605  2.322531
# 2               0.418605  2.322531
# 3               0.418605  2.322531
# 4               0.418605  2.322531
# 5               0.418605  2.322531
# 6               0.418605  2.388889
# 7               0.418605  2.388889
# 8               0.418605  2.388889
# 9               0.418605  2.388889
# 10              0.418605  2.388889
# 11              0.418605  2.388889
# 12              0.418605  2.388889
# 13              0.418605  2.388889
# 14              0.418605  2.259760
# 15              0.418605  2.259760
# 16              0.418605  2.320635
# 17              0.418605  2.320635
# 18              0.418605  2.320635
# 19              0.418605  2.320635
#
# ---------------------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# ### Ignorando Regioes

# %%
df_all = df[(df['year_tournament'] == ANO_ANALISAR)]

# verifica se tem torneios
if len(df_all) == 0:
    print(f'Sem torneios no ano {ANO_ANALISAR}')
    print("-------------------------------------------"*3)
    exit()

# verifica se tem a carta POKEMON_ALVO
if POKEMON_ALVO not in df_all['name_card'].unique():
    print(f'Sem a carta {POKEMON_ALVO} no ano {ANO_ANALISAR}')
    print("-------------------------------------------"*3)
    exit()

# calcula subgrupo
df_all = elimina_cards_menos_usados(df_all)
dataset = subgrupo_dataset_region(df_all)
result = calcula_subgrupo(dataset)

# imprime resultados
for row in result.to_dataframe().itertuples():
    print(f"Subgrupo: {row.subgroup}")
print()
print(result.to_dataframe(), "\n")
print("-------------------------------------------"*3)
# Out:
# Subgrupo: Escape Board==True AND Green's Exploration==False AND Net Ball==False AND Poipole==False
# Subgrupo: Escape Board==True AND Green's Exploration==False AND Net Ball==False AND Poipole==False AND Zorua==False
# Subgrupo: Escape Board==True AND Green's Exploration==False AND Net Ball==False AND Poipole==False AND Zoroark-GX==False
# Subgrupo: Escape Board==True AND Green's Exploration==False AND Net Ball==False AND Poipole==False AND U-Turn Board==False
# Subgrupo: Escape Board==True AND Green's Exploration==False AND Net Ball==False AND Poipole==False AND Rayquaza-GX==False
# Subgrupo: Escape Board==True AND Green's Exploration==False AND Naganadel==False AND Net Ball==False
# Subgrupo: Escape Board==True AND Green's Exploration==False AND Naganadel==False AND Net Ball==False AND Zorua==False
# Subgrupo: Escape Board==True AND Green's Exploration==False AND Naganadel==False AND Net Ball==False AND Zoroark-GX==False
# Subgrupo: Escape Board==True AND Green's Exploration==False AND Naganadel==False AND Net Ball==False AND U-Turn Board==False
# Subgrupo: Escape Board==True AND Green's Exploration==False AND Naganadel==False AND Net Ball==False AND Rayquaza-GX==False
# Subgrupo: Escape Board==True AND Green's Exploration==False AND Naganadel==False AND Net Ball==False AND Poipole==False
# Subgrupo: Escape Board==True AND Green's Exploration==False AND Multi Switch==False AND Net Ball==False AND Poipole==False
# Subgrupo: Escape Board==True AND Green's Exploration==False AND Multi Switch==False AND Naganadel==False AND Net Ball==False
# Subgrupo: Escape Board==True AND Green's Exploration==False AND Mallow==False AND Naganadel==False AND Net Ball==False
# Subgrupo: Devoured Field==False AND Escape Board==True AND Green's Exploration==False AND Net Ball==False AND Poipole==False
# Subgrupo: Devoured Field==False AND Escape Board==True AND Green's Exploration==False AND Naganadel==False AND Net Ball==False
# Subgrupo: Chaotic Swell==False AND Escape Board==True AND Green's Exploration==False AND Net Ball==False AND Poipole==False
# Subgrupo: Chaotic Swell==False AND Escape Board==True AND Green's Exploration==False AND Naganadel==False AND Net Ball==False
# Subgrupo: Alolan Vulpix==False AND Escape Board==True AND Green's Exploration==False AND Naganadel==False AND Net Ball==False
# Subgrupo: Alolan Ninetales-GX==False AND Escape Board==True AND Green's Exploration==False AND Naganadel==False AND Net Ball==False
#
#      quality                                           subgroup  size_sg
# 0   0.239284  Escape Board==True AND Green's Exploration==Fa...      202  \
# 1   0.239284  Escape Board==True AND Green's Exploration==Fa...      202
# 2   0.239284  Escape Board==True AND Green's Exploration==Fa...      202
# 3   0.239284  Escape Board==True AND Green's Exploration==Fa...      202
# 4   0.239284  Escape Board==True AND Green's Exploration==Fa...      202
# 5   0.239284  Escape Board==True AND Green's Exploration==Fa...      202
# 6   0.239284  Escape Board==True AND Green's Exploration==Fa...      202
# 7   0.239284  Escape Board==True AND Green's Exploration==Fa...      202
# 8   0.239284  Escape Board==True AND Green's Exploration==Fa...      202
# 9   0.239284  Escape Board==True AND Green's Exploration==Fa...      202
# 10  0.239284  Escape Board==True AND Green's Exploration==Fa...      202
# 11  0.239284  Escape Board==True AND Green's Exploration==Fa...      202
# 12  0.239284  Escape Board==True AND Green's Exploration==Fa...      202
# 13  0.239284  Escape Board==True AND Green's Exploration==Fa...      202
# 14  0.239284  Devoured Field==False AND Escape Board==True A...      202
# 15  0.239284  Devoured Field==False AND Escape Board==True A...      202
# 16  0.239284  Chaotic Swell==False AND Escape Board==True AN...      202
# 17  0.239284  Chaotic Swell==False AND Escape Board==True AN...      202
# 18  0.239284  Alolan Vulpix==False AND Escape Board==True AN...      202
# 19  0.239284  Alolan Ninetales-GX==False AND Escape Board==T...      202
#
#     size_dataset  positives_sg  positives_dataset  size_complement
# 0            370           201                206              168  \
# 1            370           201                206              168
# 2            370           201                206              168
# 3            370           201                206              168
# 4            370           201                206              168
# 5            370           201                206              168
# 6            370           201                206              168
# 7            370           201                206              168
# 8            370           201                206              168
# 9            370           201                206              168
# 10           370           201                206              168
# 11           370           201                206              168
# 12           370           201                206              168
# 13           370           201                206              168
# 14           370           201                206              168
# 15           370           201                206              168
# 16           370           201                206              168
# 17           370           201                206              168
# 18           370           201                206              168
# 19           370           201                206              168
#
#     relative_size_sg  relative_size_complement  coverage_sg
# 0           0.545946                  0.454054     0.975728  \
# 1           0.545946                  0.454054     0.975728
# 2           0.545946                  0.454054     0.975728
# 3           0.545946                  0.454054     0.975728
# 4           0.545946                  0.454054     0.975728
# 5           0.545946                  0.454054     0.975728
# 6           0.545946                  0.454054     0.975728
# 7           0.545946                  0.454054     0.975728
# 8           0.545946                  0.454054     0.975728
# 9           0.545946                  0.454054     0.975728
# 10          0.545946                  0.454054     0.975728
# 11          0.545946                  0.454054     0.975728
# 12          0.545946                  0.454054     0.975728
# 13          0.545946                  0.454054     0.975728
# 14          0.545946                  0.454054     0.975728
# 15          0.545946                  0.454054     0.975728
# 16          0.545946                  0.454054     0.975728
# 17          0.545946                  0.454054     0.975728
# 18          0.545946                  0.454054     0.975728
# 19          0.545946                  0.454054     0.975728
#
#     coverage_complement  target_share_sg  target_share_complement
# 0              0.024272          0.99505                 0.029762  \
# 1              0.024272          0.99505                 0.029762
# 2              0.024272          0.99505                 0.029762
# 3              0.024272          0.99505                 0.029762
# 4              0.024272          0.99505                 0.029762
# 5              0.024272          0.99505                 0.029762
# 6              0.024272          0.99505                 0.029762
# 7              0.024272          0.99505                 0.029762
# 8              0.024272          0.99505                 0.029762
# 9              0.024272          0.99505                 0.029762
# 10             0.024272          0.99505                 0.029762
# 11             0.024272          0.99505                 0.029762
# 12             0.024272          0.99505                 0.029762
# 13             0.024272          0.99505                 0.029762
# 14             0.024272          0.99505                 0.029762
# 15             0.024272          0.99505                 0.029762
# 16             0.024272          0.99505                 0.029762
# 17             0.024272          0.99505                 0.029762
# 18             0.024272          0.99505                 0.029762
# 19             0.024272          0.99505                 0.029762
#
#     target_share_dataset      lift
# 0               0.556757  1.787225
# 1               0.556757  1.787225
# 2               0.556757  1.787225
# 3               0.556757  1.787225
# 4               0.556757  1.787225
# 5               0.556757  1.787225
# 6               0.556757  1.787225
# 7               0.556757  1.787225
# 8               0.556757  1.787225
# 9               0.556757  1.787225
# 10              0.556757  1.787225
# 11              0.556757  1.787225
# 12              0.556757  1.787225
# 13              0.556757  1.787225
# 14              0.556757  1.787225
# 15              0.556757  1.787225
# 16              0.556757  1.787225
# 17              0.556757  1.787225
# 18              0.556757  1.787225
# 19              0.556757  1.787225
#
# ---------------------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# ## Conclusao
#
# Ao analisar somente cartas do tipo `pokemon`, podemos perceber que as cartas `Tapu Koko ♢` em regioes de `EU` e `Dedenne-GX` na regiao de `SA` seriam cartas com alta sinergia com a carta `Jirachi`, sendo bem relevantes em decks no ano de 2019 que podemos tambem notar no `fpgrowth` quando analisamos cartas recorrentes utilizadas.
# Quando analisamos para todos os tipos de cartas tanto `pokemon` quanto `treinador`, vemos que as cartas `Escape Board`, `Switch` e `Guzma`  seriam cartas que estao quase sempre presentes em decks com a carta `Jirachi` ao ponto de ofuscar regras que dizem a cartas `Tapu Koko ♢` e `Dedenne-GX` serem uteis no deck.
#
# De curiosidade foi pesquisado na internet e foi descoberto as seguintes caracteristicas nas 6 cartas muito utilizadas na época:
# 1. `Jirachi`:
# - Habilidade: Stellar Wish: Olhe as cinco cartas do topo do seu baralho, escolha uma carta de Treinador que encontrar ali e coloque-a na sua mão. Depois, Jirachi é colocado no banco e fica adormecido.
#
# 2. `Tapu Koko ♢`:
# - Habilidade: Dance of the Ancients: Uma vez durante o turno do jogador, se Tapu Koko estiver no banco, pode-se mover duas Energias Elétricas da pilha de descarte para dois Pokémon no banco. Depois, Tapu Koko é removido do jogo.
# - Sinergia com Jirachi: Tapu Koko ajuda a energizar rapidamente os Pokémon no banco, permitindo que Jirachi encontre cartas de Treinador essenciais para manter o fluxo do jogo.
#
# 3. `Dedenne-GX`:
# - Habilidade: Dedechange: Quando o jogador joga Dedenne-GX da mão para o banco, pode descartar a mão atual e comprar seis novas cartas.
# - Sinergia com Jirachi: Dedenne-GX ajuda a renovar a mão do jogador, garantindo que ele sempre tenha acesso a cartas de Treinador úteis que Jirachi pode buscar e jogar. Isso aumenta a consistência e a velocidade do baralho.
#
# 4. `Escape Board`:
# - Efeito: O Pokémon ao qual esta carta está ligada tem seu custo de recuo reduzido em uma Energia Incolor e pode recuar mesmo se estiver Adormecido ou Paralisado.
# - Sinergia com Jirachi: Permite que Jirachi, após usar Stellar Wish e ficar Adormecido, recue para o banco sem custo, permitindo a entrada de outro Pokémon Ativo para continuar a estratégia.
#
# 5. `Switch`:
# - Efeito: Troque o seu Pokémon Ativo por um dos seus Pokémon no banco.
# - Sinergia com Jirachi: Permite que Jirachi recue para o banco sem necessidade de energia, mesmo se não houver um Escape Board disponível. Isso mantém a habilidade Stellar Wish ativa em múltiplos turnos, proporcionando uma busca constante de cartas de Treinador.
#
# 6. `Guzma`:
# - Efeito: Escolha um dos Pokémon no banco do seu oponente e traga-o para a posição de Pokémon Ativo. Em seguida, troque seu Pokémon Ativo por um dos seus Pokémon no banco.
# - Sinergia com Jirachi: Além de permitir a manipulação do campo do oponente, Guzma permite que Jirachi recue para o banco e outro Pokémon ative seus ataques ou habilidades. Isso é especialmente útil quando você precisa retirar Jirachi do campo sem gastar energia ou cartas adicionais.
#
# Assim, essas cartas juntas formavam uma combinação muito eficiente:
# - Jirachi fornece busca e consistência com sua habilidade Stellar Wish.
# - Tapu Koko acelera a energização dos Pokémon no banco.
# - Escape Board e Switch garantem que Jirachi possa recuar facilmente após usar sua habilidade.
# - Dedenne-GX renova a mão do jogador, garantindo um fluxo constante de cartas de Treinador.
# - Guzma permite controle do campo adversário e facilita a troca de Pokémon para manter a pressão ou se defender.
#
# Essa combinação cria um baralho fluido e versátil, capaz de responder a diversas situações e manter um fluxo constante de recursos.
