# %% [markdown]
# # Identificação de Cartas Ideais em um Deck com Jirachi como Alvo
#
# Esse notebook analisa as cartas ideais em um deck que contém a carta `Jirachi` como alvo.

# %% [markdown]
# ### Bibliotecas utilizadas e carregando dataset

# %%
import numpy as np
import pandas as pd
import pysubgroup as ps


df_original = pd.read_csv('./Data/tournaments.csv')
df = df_original.copy()

# %%
POKEMON_ALVO = 'Jirachi'
CONSIDERAR_TREINADORES = True
ANO_ANALISAR = 2019
 
CARTAS_MINIMAS = 20

# %% [markdown]
# ### Eliminar Cartas de Treinador (se necessário)

# %%
if not CONSIDERAR_TREINADORES:
    df = df[df['type_card'] != 'Trainer']

df.head()
# Out:
#   id_card    name_card  amount_card  price_card energy_type_card type_card  \
# 0  SSP272     Archeops            4        0.70        Colorless   Pokémon
# 1  SIT138      Lugia V            3        6.20        Colorless   Pokémon
# 2  SIT139  Lugia VSTAR            3        8.71        Colorless   Pokémon
# 3  LOR143      Snorlax            3        0.93        Colorless   Pokémon
# 4  SSP250   Lumineon V            2        1.90            Water   Pokémon
#
#    combo_type_id combo_type_name  id_player       name_player  ...  \
# 0          247.0  Lugia Archeops       5101  Alexander Flatos  ...
# 1          247.0  Lugia Archeops       5101  Alexander Flatos  ...
# 2          247.0  Lugia Archeops       5101  Alexander Flatos  ...
# 3          247.0  Lugia Archeops       5101  Alexander Flatos  ...
# 4          247.0  Lugia Archeops       5101  Alexander Flatos  ...
#
#   region_tournament  country_tournament  year_tournament  month_tournament  \
# 0               NaN       United States             2023                10
# 1               NaN       United States             2023                10
# 2               NaN       United States             2023                10
# 3               NaN       United States             2023                10
# 4               NaN       United States             2023                10
#
#   day_tournament valid_rotation_at_tournament  rotation_name year_begin  \
# 0             14                      BST-OBF  standard_2023       2023
# 1             14                      BST-OBF  standard_2023       2023
# 2             14                      BST-OBF  standard_2023       2023
# 3             14                      BST-OBF  standard_2023       2023
# 4             14                      BST-OBF  standard_2023       2023
#
#    month_begin  day_begin
# 0            4         14
# 1            4         14
# 2            4         14
# 3            4         14
# 4            4         14
#
# [5 rows x 26 columns]

# %% [markdown]
# ### Filtragem de Colunas no Dataset e Limpeza de Linhas com Coluna Região do Torneio Vazias

# %%
columns_to_remove = [
    'id_card', 'amount_card', 'price_card', 'combo_type_id', 'name_tournament',
    'combo_type_name', 'name_player', 'category_tournament', 'type_card',
    'month_tournament', 'day_tournament', 'valid_rotation_at_tournament', 
    'rotation_name', 'year_begin', 'all_time_score', 'country_tournament', 'country_player',
    'month_begin', 'day_begin',
]
df.drop(columns=columns_to_remove, inplace=True)
df = df[df['region_tournament'].notna()]

df.head(5)
# Out:
#          name_card energy_type_card  id_player  ranking_player_tournament  \
# 7462    Charmander             Fire        649                          1
# 7463    Charmeleon             Fire        649                          1
# 7464  Charizard ex         Darkness        649                          1
# 7465        Pidgey        Colorless        649                          1
# 7466    Pidgeot ex        Colorless        649                          1
#
#       id_tournament region_tournament  year_tournament
# 7462            385                SA             2023
# 7463            385                SA             2023
# 7464            385                SA             2023
# 7465            385                SA             2023
# 7466            385                SA             2023

# %% [markdown]
# ### Separando por Região para Verificar Recomendações de Cartas para o Deck com `Jirachi`

# %%
def elimina_cards_menos_usados(df):
    cartas = df['name_card'].unique()
    for carta in cartas:
        if len(df[df['name_card'] == carta]) < CARTAS_MINIMAS:
            df = df[df['name_card'] != carta]
    return df

def agrupa_deck(df_region):
    #filtra torneios da regiao
    torneios = df_region['id_tournament'].unique()

    lista_decks = []
    for torneio in torneios:
        df_torneio = df_region[df_region['id_tournament'] == torneio]
        jogadores = df_torneio['id_player'].unique()
        for jogador in jogadores:
            df_jogador = df_torneio[df_torneio['id_player'] == jogador]
            cartas_jogador = df_jogador['name_card'].unique().tolist()
            lista_decks.append(cartas_jogador)
    return lista_decks

def subgrupo_dataset_region(df_region):
    lista_decks = agrupa_deck(df_region)
    cartas = df_region['name_card'].unique()
    data = []
    for deck_rank in lista_decks:
        pokemons_no_deck = {carta: (carta in deck_rank[:len(deck_rank)-1]) for carta in cartas}
        data.append(pokemons_no_deck)
    # Converte a lista de dicionários em um DataFrame
    df_decks_cartas = pd.DataFrame(data)

    return df_decks_cartas

def calcula_subgrupo(df):
    target = ps.BinaryTarget(POKEMON_ALVO, True)
    search_space = ps.create_selectors(df, ignore=[POKEMON_ALVO])
    task = ps.SubgroupDiscoveryTask(
        df,
        target, 
        search_space, 
        result_set_size=20, 
        depth=5, 
        qf=ps.WRAccQF()  # Quality function to evaluate subgroups
    )
    result = ps.BeamSearch().execute(task)
    return result

# %% [markdown]
# ### Por regiao

# %%
regions = df['region_tournament'].unique()
for region in regions:
    print(f"Região: {region}\n")
    df_region = df[(df['region_tournament'] == region) & (df['year_tournament'] == ANO_ANALISAR)]

    # Verifica se há torneios na região
    if len(df_region) == 0:
        print(f'Sem torneios na região {region} no ano {ANO_ANALISAR}\n')
        print("-------------------------------------------"*3)
        continue

    # Verifica se há a carta POKEMON_ALVO na região
    if POKEMON_ALVO not in df_region['name_card'].unique():
        print(f'Sem a carta {POKEMON_ALVO} na região {region}\n')
        print("-------------------------------------------"*3)
        continue

    df_region = elimina_cards_menos_usados(df_region)
    dataset = subgrupo_dataset_region(df_region)
    result = calcula_subgrupo(dataset)

    for row in result.to_dataframe().itertuples():
        print(f"Subgrupo: {row.subgroup}")
    print()
    print(result.to_dataframe(), "\n")
    print("-------------------------------------------"*3)
# Out:
# Região: SA
#
# Subgrupo: Pokégear 3.0==False AND Switch==True
# Subgrupo: Chaotic Swell==False AND Pokégear 3.0==False AND Switch==True
# Subgrupo: Custom Catcher==False AND Pokégear 3.0==False AND Switch==True
# Subgrupo: Chaotic Swell==False AND Custom Catcher==False AND Pokégear 3.0==False AND Switch==True
# Subgrupo: Custom Catcher==False AND Switch==True
# Subgrupo: Chaotic Swell==False AND Custom Catcher==False AND Switch==True
# Subgrupo: Pokégear 3.0==False AND Reset Stamp==True AND Switch==True
# Subgrupo: Great Catcher==True AND Pokégear 3.0==False AND Switch==True
# Subgrupo: Chaotic Swell==False AND Pokégear 3.0==False AND Reset Stamp==True AND Switch==True
# Subgrupo: Chaotic Swell==False AND Great Catcher==True AND Pokégear 3.0==False AND Switch==True
# Subgrupo: Acro Bike==False AND Custom Catcher==False AND Switch==True
# Subgrupo: Acro Bike==False AND Chaotic Swell==False AND Custom Catcher==False AND Switch==True
# Subgrupo: Acro Bike==False AND Pokégear 3.0==False AND Switch==True
# Subgrupo: Acro Bike==False AND Chaotic Swell==False AND Pokégear 3.0==False AND Switch==True
# Subgrupo: Custom Catcher==False AND Great Catcher==True AND Pokégear 3.0==False AND Switch==True
# Subgrupo: Chaotic Swell==False AND Custom Catcher==False AND Great Catcher==True AND Pokégear 3.0==False AND Switch==True
# Subgrupo: Custom Catcher==False AND Reset Stamp==True AND Switch==True
# Subgrupo: Chaotic Swell==False AND Custom Catcher==False AND Reset Stamp==True AND Switch==True
# Subgrupo: Great Catcher==True AND Pokégear 3.0==False AND Reset Stamp==True AND Switch==True
# Subgrupo: Chaotic Swell==False AND Great Catcher==True AND Pokégear 3.0==False AND Reset Stamp==True AND Switch==True
#
#      quality                                           subgroup  size_sg  \
# 0   0.160818               Pokégear 3.0==False AND Switch==True       31
# 1   0.160818  Chaotic Swell==False AND Pokégear 3.0==False A...       31
# 2   0.146369  Custom Catcher==False AND Pokégear 3.0==False ...       26
# 3   0.146369  Chaotic Swell==False AND Custom Catcher==False...       26
# 4   0.139801             Custom Catcher==False AND Switch==True       37
# 5   0.139801  Chaotic Swell==False AND Custom Catcher==False...       37
# 6   0.138300  Pokégear 3.0==False AND Reset Stamp==True AND ...       27
# 7   0.138300  Great Catcher==True AND Pokégear 3.0==False AN...       27
# 8   0.138300  Chaotic Swell==False AND Pokégear 3.0==False A...       27
# 9   0.138300  Chaotic Swell==False AND Great Catcher==True A...       27
# 10  0.138300  Acro Bike==False AND Custom Catcher==False AND...       27
# 11  0.138300  Acro Bike==False AND Chaotic Swell==False AND ...       27
# 12  0.132670  Acro Bike==False AND Pokégear 3.0==False AND S...       26
# 13  0.132670  Acro Bike==False AND Chaotic Swell==False AND ...       26
# 14  0.129480  Custom Catcher==False AND Great Catcher==True ...       23
# 15  0.129480  Chaotic Swell==False AND Custom Catcher==False...       23
# 16  0.127791  Custom Catcher==False AND Reset Stamp==True AN...       30
# 17  0.127791  Chaotic Swell==False AND Custom Catcher==False...       30
# 18  0.127041  Great Catcher==True AND Pokégear 3.0==False AN...       25
# 19  0.127041  Chaotic Swell==False AND Great Catcher==True A...       25
#
#     size_dataset  positives_sg  positives_dataset  size_complement  \
# 0             73            30                 43               42
# 1             73            30                 43               42
# 2             73            26                 43               47
# 3             73            26                 43               47
# 4             73            32                 43               36
# 5             73            32                 43               36
# 6             73            26                 43               46
# 7             73            26                 43               46
# 8             73            26                 43               46
# 9             73            26                 43               46
# 10            73            26                 43               46
# 11            73            26                 43               46
# 12            73            25                 43               47
# 13            73            25                 43               47
# 14            73            23                 43               50
# 15            73            23                 43               50
# 16            73            27                 43               43
# 17            73            27                 43               43
# 18            73            24                 43               48
# 19            73            24                 43               48
#
#     relative_size_sg  relative_size_complement  coverage_sg  \
# 0           0.424658                  0.575342     0.697674
# 1           0.424658                  0.575342     0.697674
# 2           0.356164                  0.643836     0.604651
# 3           0.356164                  0.643836     0.604651
# 4           0.506849                  0.493151     0.744186
# 5           0.506849                  0.493151     0.744186
# 6           0.369863                  0.630137     0.604651
# 7           0.369863                  0.630137     0.604651
# 8           0.369863                  0.630137     0.604651
# 9           0.369863                  0.630137     0.604651
# 10          0.369863                  0.630137     0.604651
# 11          0.369863                  0.630137     0.604651
# 12          0.356164                  0.643836     0.581395
# 13          0.356164                  0.643836     0.581395
# 14          0.315068                  0.684932     0.534884
# 15          0.315068                  0.684932     0.534884
# 16          0.410959                  0.589041     0.627907
# 17          0.410959                  0.589041     0.627907
# 18          0.342466                  0.657534     0.558140
# 19          0.342466                  0.657534     0.558140
#
#     coverage_complement  target_share_sg  target_share_complement  \
# 0              0.302326         0.967742                 0.309524
# 1              0.302326         0.967742                 0.309524
# 2              0.395349         1.000000                 0.361702
# 3              0.395349         1.000000                 0.361702
# 4              0.255814         0.864865                 0.305556
# 5              0.255814         0.864865                 0.305556
# 6              0.395349         0.962963                 0.369565
# 7              0.395349         0.962963                 0.369565
# 8              0.395349         0.962963                 0.369565
# 9              0.395349         0.962963                 0.369565
# 10             0.395349         0.962963                 0.369565
# 11             0.395349         0.962963                 0.369565
# 12             0.418605         0.961538                 0.382979
# 13             0.418605         0.961538                 0.382979
# 14             0.465116         1.000000                 0.400000
# 15             0.465116         1.000000                 0.400000
# 16             0.372093         0.900000                 0.372093
# 17             0.372093         0.900000                 0.372093
# 18             0.441860         0.960000                 0.395833
# 19             0.441860         0.960000                 0.395833
#
#     target_share_dataset      lift
# 0               0.589041  1.642911
# 1               0.589041  1.642911
# 2               0.589041  1.697674
# 3               0.589041  1.697674
# 4               0.589041  1.468259
# 5               0.589041  1.468259
# 6               0.589041  1.634798
# 7               0.589041  1.634798
# 8               0.589041  1.634798
# 9               0.589041  1.634798
# 10              0.589041  1.634798
# 11              0.589041  1.634798
# 12              0.589041  1.632379
# 13              0.589041  1.632379
# 14              0.589041  1.697674
# 15              0.589041  1.697674
# 16              0.589041  1.527907
# 17              0.589041  1.527907
# 18              0.589041  1.629767
# 19              0.589041  1.629767
#
# ---------------------------------------------------------------------------------------------------------------------------------
# Região: EU
#
# Subgrupo: Switch==True
# Subgrupo: Switch==True AND Thunder Mountain ♢==False
# Subgrupo: Electropower==True AND Switch==True
# Subgrupo: Electropower==True AND Switch==True AND Thunder Mountain ♢==False
# Subgrupo: Escape Board==True
# Subgrupo: Escape Board==True AND Thunder Mountain ♢==False
# Subgrupo: Escape Board==True AND Switch==True
# Subgrupo: Escape Board==True AND Switch==True AND Thunder Mountain ♢==False
# Subgrupo: Switch==True AND Tapu Koko ♢==True
# Subgrupo: Switch==True AND Tapu Koko ♢==True AND Thunder Mountain ♢==False
# Subgrupo: Electropower==True AND Switch==True AND Tapu Koko ♢==True
# Subgrupo: Electropower==True AND Switch==True AND Tapu Koko ♢==True AND Thunder Mountain ♢==False
# Subgrupo: Erika's Hospitality==False AND Switch==True
# Subgrupo: Erika's Hospitality==False AND Switch==True AND Thunder Mountain ♢==False
# Subgrupo: Electropower==True AND Escape Board==True
# Subgrupo: Electropower==True AND Escape Board==True AND Thunder Mountain ♢==False
# Subgrupo: Electropower==True AND Escape Board==True AND Switch==True
# Subgrupo: Electropower==True AND Escape Board==True AND Switch==True AND Thunder Mountain ♢==False
# Subgrupo: Mysterious Treasure==False AND Switch==True
# Subgrupo: Mysterious Treasure==False AND Switch==True AND Thunder Mountain ♢==False
#
#      quality                                           subgroup  size_sg  \
# 0   0.206782                                       Switch==True       53
# 1   0.206782         Switch==True AND Thunder Mountain ♢==False       53
# 2   0.198339                Electropower==True AND Switch==True       46
# 3   0.198339  Electropower==True AND Switch==True AND Thunde...       46
# 4   0.196401                                 Escape Board==True       43
# 5   0.196401   Escape Board==True AND Thunder Mountain ♢==False       43
# 6   0.196401                Escape Board==True AND Switch==True       43
# 7   0.196401  Escape Board==True AND Switch==True AND Thunde...       43
# 8   0.184637                 Switch==True AND Tapu Koko ♢==True       43
# 9   0.184637  Switch==True AND Tapu Koko ♢==True AND Thunder...       43
# 10  0.184637  Electropower==True AND Switch==True AND Tapu K...       43
# 11  0.184637  Electropower==True AND Switch==True AND Tapu K...       43
# 12  0.182699        Erika's Hospitality==False AND Switch==True       40
# 13  0.182699  Erika's Hospitality==False AND Switch==True AN...       40
# 14  0.182699          Electropower==True AND Escape Board==True       40
# 15  0.182699  Electropower==True AND Escape Board==True AND ...       40
# 16  0.182699  Electropower==True AND Escape Board==True AND ...       40
# 17  0.182699  Electropower==True AND Escape Board==True AND ...       40
# 18  0.180069        Mysterious Treasure==False AND Switch==True       42
# 19  0.180069  Mysterious Treasure==False AND Switch==True AN...       42
#
#     size_dataset  positives_sg  positives_dataset  size_complement  \
# 0             85            50                 52               32
# 1             85            50                 52               32
# 2             85            45                 52               39
# 3             85            45                 52               39
# 4             85            43                 52               42
# 5             85            43                 52               42
# 6             85            43                 52               42
# 7             85            43                 52               42
# 8             85            42                 52               42
# 9             85            42                 52               42
# 10            85            42                 52               42
# 11            85            42                 52               42
# 12            85            40                 52               45
# 13            85            40                 52               45
# 14            85            40                 52               45
# 15            85            40                 52               45
# 16            85            40                 52               45
# 17            85            40                 52               45
# 18            85            41                 52               43
# 19            85            41                 52               43
#
#     relative_size_sg  relative_size_complement  coverage_sg  \
# 0           0.623529                  0.376471     0.961538
# 1           0.623529                  0.376471     0.961538
# 2           0.541176                  0.458824     0.865385
# 3           0.541176                  0.458824     0.865385
# 4           0.505882                  0.494118     0.826923
# 5           0.505882                  0.494118     0.826923
# 6           0.505882                  0.494118     0.826923
# 7           0.505882                  0.494118     0.826923
# 8           0.505882                  0.494118     0.807692
# 9           0.505882                  0.494118     0.807692
# 10          0.505882                  0.494118     0.807692
# 11          0.505882                  0.494118     0.807692
# 12          0.470588                  0.529412     0.769231
# 13          0.470588                  0.529412     0.769231
# 14          0.470588                  0.529412     0.769231
# 15          0.470588                  0.529412     0.769231
# 16          0.470588                  0.529412     0.769231
# 17          0.470588                  0.529412     0.769231
# 18          0.494118                  0.505882     0.788462
# 19          0.494118                  0.505882     0.788462
#
#     coverage_complement  target_share_sg  target_share_complement  \
# 0              0.038462         0.943396                 0.062500
# 1              0.038462         0.943396                 0.062500
# 2              0.134615         0.978261                 0.179487
# 3              0.134615         0.978261                 0.179487
# 4              0.173077         1.000000                 0.214286
# 5              0.173077         1.000000                 0.214286
# 6              0.173077         1.000000                 0.214286
# 7              0.173077         1.000000                 0.214286
# 8              0.192308         0.976744                 0.238095
# 9              0.192308         0.976744                 0.238095
# 10             0.192308         0.976744                 0.238095
# 11             0.192308         0.976744                 0.238095
# 12             0.230769         1.000000                 0.266667
# 13             0.230769         1.000000                 0.266667
# 14             0.230769         1.000000                 0.266667
# 15             0.230769         1.000000                 0.266667
# 16             0.230769         1.000000                 0.266667
# 17             0.230769         1.000000                 0.266667
# 18             0.211538         0.976190                 0.255814
# 19             0.211538         0.976190                 0.255814
#
#     target_share_dataset      lift
# 0               0.611765  1.542090
# 1               0.611765  1.542090
# 2               0.611765  1.599080
# 3               0.611765  1.599080
# 4               0.611765  1.634615
# 5               0.611765  1.634615
# 6               0.611765  1.634615
# 7               0.611765  1.634615
# 8               0.611765  1.596601
# 9               0.611765  1.596601
# 10              0.611765  1.596601
# 11              0.611765  1.596601
# 12              0.611765  1.634615
# 13              0.611765  1.634615
# 14              0.611765  1.634615
# 15              0.611765  1.634615
# 16              0.611765  1.634615
# 17              0.611765  1.634615
# 18              0.611765  1.595696
# 19              0.611765  1.595696
#
# ---------------------------------------------------------------------------------------------------------------------------------
# Região: AS-OC
#
# Subgrupo: Escape Board==True
# Subgrupo: Alolan Muk==False AND Escape Board==True
# Subgrupo: Escape Board==True AND Guzma==True
# Subgrupo: Ditto ♢==False AND Escape Board==True
# Subgrupo: Ditto ♢==False AND Escape Board==True AND Guzma==True
# Subgrupo: Alolan Muk==False AND Escape Board==True AND Guzma==True
# Subgrupo: Alolan Muk==False AND Ditto ♢==False AND Escape Board==True
# Subgrupo: Alolan Muk==False AND Ditto ♢==False AND Escape Board==True AND Guzma==True
# Subgrupo: Escape Board==True AND Switch==True
# Subgrupo: Escape Board==True AND Nest Ball==True
# Subgrupo: Escape Board==True AND Lycanroc-GX==False
# Subgrupo: Escape Board==True AND Guzma==True AND Nest Ball==True
# Subgrupo: Ditto ♢==False AND Escape Board==True AND Nest Ball==True
# Subgrupo: Ditto ♢==False AND Escape Board==True AND Guzma==True AND Nest Ball==True
# Subgrupo: Alolan Muk==False AND Escape Board==True AND Switch==True
# Subgrupo: Alolan Muk==False AND Escape Board==True AND Nest Ball==True
# Subgrupo: Alolan Muk==False AND Escape Board==True AND Lycanroc-GX==False
# Subgrupo: Alolan Muk==False AND Escape Board==True AND Guzma==True AND Nest Ball==True
# Subgrupo: Alolan Muk==False AND Ditto ♢==False AND Escape Board==True AND Nest Ball==True
# Subgrupo: Alolan Muk==False AND Ditto ♢==False AND Escape Board==True AND Guzma==True AND Nest Ball==True
#
#      quality                                           subgroup  size_sg  \
# 0   0.215745                                 Escape Board==True       68
# 1   0.215745           Alolan Muk==False AND Escape Board==True       68
# 2   0.212572                 Escape Board==True AND Guzma==True       67
# 3   0.212572              Ditto ♢==False AND Escape Board==True       67
# 4   0.212572  Ditto ♢==False AND Escape Board==True AND Guzm...       67
# 5   0.212572  Alolan Muk==False AND Escape Board==True AND G...       67
# 6   0.212572  Alolan Muk==False AND Ditto ♢==False AND Escap...       67
# 7   0.212572  Alolan Muk==False AND Ditto ♢==False AND Escap...       67
# 8   0.209399                Escape Board==True AND Switch==True       66
# 9   0.209399             Escape Board==True AND Nest Ball==True       66
# 10  0.209399          Escape Board==True AND Lycanroc-GX==False       66
# 11  0.209399  Escape Board==True AND Guzma==True AND Nest Ba...       66
# 12  0.209399  Ditto ♢==False AND Escape Board==True AND Nest...       66
# 13  0.209399  Ditto ♢==False AND Escape Board==True AND Guzm...       66
# 14  0.209399  Alolan Muk==False AND Escape Board==True AND S...       66
# 15  0.209399  Alolan Muk==False AND Escape Board==True AND N...       66
# 16  0.209399  Alolan Muk==False AND Escape Board==True AND L...       66
# 17  0.209399  Alolan Muk==False AND Escape Board==True AND G...       66
# 18  0.209399  Alolan Muk==False AND Ditto ♢==False AND Escap...       66
# 19  0.209399  Alolan Muk==False AND Ditto ♢==False AND Escap...       66
#
#     size_dataset  positives_sg  positives_dataset  size_complement  \
# 0            123            68                 75               55
# 1            123            68                 75               55
# 2            123            67                 75               56
# 3            123            67                 75               56
# 4            123            67                 75               56
# 5            123            67                 75               56
# 6            123            67                 75               56
# 7            123            67                 75               56
# 8            123            66                 75               57
# 9            123            66                 75               57
# 10           123            66                 75               57
# 11           123            66                 75               57
# 12           123            66                 75               57
# 13           123            66                 75               57
# 14           123            66                 75               57
# 15           123            66                 75               57
# 16           123            66                 75               57
# 17           123            66                 75               57
# 18           123            66                 75               57
# 19           123            66                 75               57
#
#     relative_size_sg  relative_size_complement  coverage_sg  \
# 0           0.552846                  0.447154     0.906667
# 1           0.552846                  0.447154     0.906667
# 2           0.544715                  0.455285     0.893333
# 3           0.544715                  0.455285     0.893333
# 4           0.544715                  0.455285     0.893333
# 5           0.544715                  0.455285     0.893333
# 6           0.544715                  0.455285     0.893333
# 7           0.544715                  0.455285     0.893333
# 8           0.536585                  0.463415     0.880000
# 9           0.536585                  0.463415     0.880000
# 10          0.536585                  0.463415     0.880000
# 11          0.536585                  0.463415     0.880000
# 12          0.536585                  0.463415     0.880000
# 13          0.536585                  0.463415     0.880000
# 14          0.536585                  0.463415     0.880000
# 15          0.536585                  0.463415     0.880000
# 16          0.536585                  0.463415     0.880000
# 17          0.536585                  0.463415     0.880000
# 18          0.536585                  0.463415     0.880000
# 19          0.536585                  0.463415     0.880000
#
#     coverage_complement  target_share_sg  target_share_complement  \
# 0              0.093333              1.0                 0.127273
# 1              0.093333              1.0                 0.127273
# 2              0.106667              1.0                 0.142857
# 3              0.106667              1.0                 0.142857
# 4              0.106667              1.0                 0.142857
# 5              0.106667              1.0                 0.142857
# 6              0.106667              1.0                 0.142857
# 7              0.106667              1.0                 0.142857
# 8              0.120000              1.0                 0.157895
# 9              0.120000              1.0                 0.157895
# 10             0.120000              1.0                 0.157895
# 11             0.120000              1.0                 0.157895
# 12             0.120000              1.0                 0.157895
# 13             0.120000              1.0                 0.157895
# 14             0.120000              1.0                 0.157895
# 15             0.120000              1.0                 0.157895
# 16             0.120000              1.0                 0.157895
# 17             0.120000              1.0                 0.157895
# 18             0.120000              1.0                 0.157895
# 19             0.120000              1.0                 0.157895
#
#     target_share_dataset  lift
# 0               0.609756  1.64
# 1               0.609756  1.64
# 2               0.609756  1.64
# 3               0.609756  1.64
# 4               0.609756  1.64
# 5               0.609756  1.64
# 6               0.609756  1.64
# 7               0.609756  1.64
# 8               0.609756  1.64
# 9               0.609756  1.64
# 10              0.609756  1.64
# 11              0.609756  1.64
# 12              0.609756  1.64
# 13              0.609756  1.64
# 14              0.609756  1.64
# 15              0.609756  1.64
# 16              0.609756  1.64
# 17              0.609756  1.64
# 18              0.609756  1.64
# 19              0.609756  1.64
#
# ---------------------------------------------------------------------------------------------------------------------------------
# Região: JP
#
# Subgrupo: Pokégear 3.0==False AND Switch==True
# Subgrupo: Pokégear 3.0==False AND Power Plant==False AND Switch==True
# Subgrupo: Pokégear 3.0==False AND Switch==True AND Thunder Mountain ♢==False
# Subgrupo: Pokégear 3.0==False AND Power Plant==False AND Switch==True AND Thunder Mountain ♢==False
# Subgrupo: Escape Board==True AND Switch==True
# Subgrupo: Escape Board==True AND Power Plant==False AND Switch==True
# Subgrupo: Escape Board==True AND Pokégear 3.0==False
# Subgrupo: Escape Board==True AND Pokégear 3.0==False AND Switch==True
# Subgrupo: Escape Board==True AND Pokégear 3.0==False AND Power Plant==False
# Subgrupo: Escape Board==True AND Pokégear 3.0==False AND Power Plant==False AND Switch==True
# Subgrupo: Nest Ball==True AND Pokégear 3.0==False AND Switch==True
# Subgrupo: Nest Ball==True AND Pokégear 3.0==False AND Power Plant==False AND Switch==True
# Subgrupo: Guzma==True AND Nest Ball==True AND Pokégear 3.0==False AND Switch==True
# Subgrupo: Guzma==True AND Nest Ball==True AND Pokégear 3.0==False AND Power Plant==False AND Switch==True
# Subgrupo: Escape Board==True
# Subgrupo: Escape Board==True AND Power Plant==False
# Subgrupo: Escape Board==True AND Switch==True AND Thunder Mountain ♢==False
# Subgrupo: Escape Board==True AND Power Plant==False AND Switch==True AND Thunder Mountain ♢==False
# Subgrupo: Escape Board==True AND Pokégear 3.0==False AND Thunder Mountain ♢==False
# Subgrupo: Escape Board==True AND Pokégear 3.0==False AND Switch==True AND Thunder Mountain ♢==False
#
#      quality                                           subgroup  size_sg  \
# 0   0.210384               Pokégear 3.0==False AND Switch==True       38
# 1   0.210384  Pokégear 3.0==False AND Power Plant==False AND...       38
# 2   0.203624  Pokégear 3.0==False AND Switch==True AND Thund...       37
# 3   0.203624  Pokégear 3.0==False AND Power Plant==False AND...       37
# 4   0.175771                Escape Board==True AND Switch==True       26
# 5   0.175771  Escape Board==True AND Power Plant==False AND ...       26
# 6   0.175771         Escape Board==True AND Pokégear 3.0==False       26
# 7   0.175771  Escape Board==True AND Pokégear 3.0==False AND...       26
# 8   0.175771  Escape Board==True AND Pokégear 3.0==False AND...       26
# 9   0.175771  Escape Board==True AND Pokégear 3.0==False AND...       26
# 10  0.170903  Nest Ball==True AND Pokégear 3.0==False AND Sw...       27
# 11  0.170903  Nest Ball==True AND Pokégear 3.0==False AND Po...       27
# 12  0.170903  Guzma==True AND Nest Ball==True AND Pokégear 3...       27
# 13  0.170903  Guzma==True AND Nest Ball==True AND Pokégear 3...       27
# 14  0.170903                                 Escape Board==True       27
# 15  0.170903          Escape Board==True AND Power Plant==False       27
# 16  0.169010  Escape Board==True AND Switch==True AND Thunde...       25
# 17  0.169010  Escape Board==True AND Power Plant==False AND ...       25
# 18  0.169010  Escape Board==True AND Pokégear 3.0==False AND...       25
# 19  0.169010  Escape Board==True AND Pokégear 3.0==False AND...       25
#
#     size_dataset  positives_sg  positives_dataset  size_complement  \
# 0             86            34                 36               48
# 1             86            34                 36               48
# 2             86            33                 36               49
# 3             86            33                 36               49
# 4             86            26                 36               60
# 5             86            26                 36               60
# 6             86            26                 36               60
# 7             86            26                 36               60
# 8             86            26                 36               60
# 9             86            26                 36               60
# 10            86            26                 36               59
# 11            86            26                 36               59
# 12            86            26                 36               59
# 13            86            26                 36               59
# 14            86            26                 36               59
# 15            86            26                 36               59
# 16            86            25                 36               61
# 17            86            25                 36               61
# 18            86            25                 36               61
# 19            86            25                 36               61
#
#     relative_size_sg  relative_size_complement  coverage_sg  \
# 0           0.441860                  0.558140     0.944444
# 1           0.441860                  0.558140     0.944444
# 2           0.430233                  0.569767     0.916667
# 3           0.430233                  0.569767     0.916667
# 4           0.302326                  0.697674     0.722222
# 5           0.302326                  0.697674     0.722222
# 6           0.302326                  0.697674     0.722222
# 7           0.302326                  0.697674     0.722222
# 8           0.302326                  0.697674     0.722222
# 9           0.302326                  0.697674     0.722222
# 10          0.313953                  0.686047     0.722222
# 11          0.313953                  0.686047     0.722222
# 12          0.313953                  0.686047     0.722222
# 13          0.313953                  0.686047     0.722222
# 14          0.313953                  0.686047     0.722222
# 15          0.313953                  0.686047     0.722222
# 16          0.290698                  0.709302     0.694444
# 17          0.290698                  0.709302     0.694444
# 18          0.290698                  0.709302     0.694444
# 19          0.290698                  0.709302     0.694444
#
#     coverage_complement  target_share_sg  target_share_complement  \
# 0              0.055556         0.894737                 0.041667
# 1              0.055556         0.894737                 0.041667
# 2              0.083333         0.891892                 0.061224
# 3              0.083333         0.891892                 0.061224
# 4              0.277778         1.000000                 0.166667
# 5              0.277778         1.000000                 0.166667
# 6              0.277778         1.000000                 0.166667
# 7              0.277778         1.000000                 0.166667
# 8              0.277778         1.000000                 0.166667
# 9              0.277778         1.000000                 0.166667
# 10             0.277778         0.962963                 0.169492
# 11             0.277778         0.962963                 0.169492
# 12             0.277778         0.962963                 0.169492
# 13             0.277778         0.962963                 0.169492
# 14             0.277778         0.962963                 0.169492
# 15             0.277778         0.962963                 0.169492
# 16             0.305556         1.000000                 0.180328
# 17             0.305556         1.000000                 0.180328
# 18             0.305556         1.000000                 0.180328
# 19             0.305556         1.000000                 0.180328
#
#     target_share_dataset      lift
# 0               0.418605  2.137427
# 1               0.418605  2.137427
# 2               0.418605  2.130631
# 3               0.418605  2.130631
# 4               0.418605  2.388889
# 5               0.418605  2.388889
# 6               0.418605  2.388889
# 7               0.418605  2.388889
# 8               0.418605  2.388889
# 9               0.418605  2.388889
# 10              0.418605  2.300412
# 11              0.418605  2.300412
# 12              0.418605  2.300412
# 13              0.418605  2.300412
# 14              0.418605  2.300412
# 15              0.418605  2.300412
# 16              0.418605  2.388889
# 17              0.418605  2.388889
# 18              0.418605  2.388889
# 19              0.418605  2.388889
#
# ---------------------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# ### Análise Ignorando Regiões

# %%
df_all = df[(df['year_tournament'] == ANO_ANALISAR)]

# verifica se tem torneios
if len(df_all) == 0:
    print(f'Sem torneios no ano {ANO_ANALISAR}')
    print("-------------------------------------------"*3)
    exit()

# verifica se tem a carta POKEMON_ALVO
if POKEMON_ALVO not in df_all['name_card'].unique():
    print(f'Sem a carta {POKEMON_ALVO} no ano {ANO_ANALISAR}')
    print("-------------------------------------------"*3)
    exit()

# calcula subgrupo
df_all = elimina_cards_menos_usados(df_all)
dataset = subgrupo_dataset_region(df_all)
result = calcula_subgrupo(dataset)

# imprime resultados
for row in result.to_dataframe().itertuples():
    print(f"Subgrupo: {row.subgroup}")
print()
print(result.to_dataframe(), "\n")
print("-------------------------------------------"*3)
# Out:
# Subgrupo: Escape Board==True AND Green's Exploration==False
# Subgrupo: Escape Board==True AND Green's Exploration==False AND Zorua==False
# Subgrupo: Escape Board==True AND Green's Exploration==False AND Zoroark-GX==False
# Subgrupo: Escape Board==True AND Green's Exploration==False AND Zoroark-GX==False AND Zorua==False
# Subgrupo: Escape Board==True AND Green's Exploration==False AND Multi Switch==False
# Subgrupo: Escape Board==True AND Green's Exploration==False AND Multi Switch==False AND Zorua==False
# Subgrupo: Escape Board==True AND Green's Exploration==False AND Multi Switch==False AND Zoroark-GX==False
# Subgrupo: Escape Board==True AND Green's Exploration==False AND Multi Switch==False AND Zoroark-GX==False AND Zorua==False
# Subgrupo: Chaotic Swell==False AND Escape Board==True AND Green's Exploration==False
# Subgrupo: Chaotic Swell==False AND Escape Board==True AND Green's Exploration==False AND Zorua==False
# Subgrupo: Chaotic Swell==False AND Escape Board==True AND Green's Exploration==False AND Zoroark-GX==False
# Subgrupo: Chaotic Swell==False AND Escape Board==True AND Green's Exploration==False AND Zoroark-GX==False AND Zorua==False
# Subgrupo: Chaotic Swell==False AND Escape Board==True AND Green's Exploration==False AND Multi Switch==False
# Subgrupo: Chaotic Swell==False AND Escape Board==True AND Green's Exploration==False AND Multi Switch==False AND Zorua==False
# Subgrupo: Chaotic Swell==False AND Escape Board==True AND Green's Exploration==False AND Multi Switch==False AND Zoroark-GX==False
# Subgrupo: Escape Board==True AND Green's Exploration==False AND Heat Factory ♢==False
# Subgrupo: Escape Board==True AND Green's Exploration==False AND Heat Factory ♢==False AND Zorua==False
# Subgrupo: Escape Board==True AND Green's Exploration==False AND Heat Factory ♢==False AND Zoroark-GX==False
# Subgrupo: Escape Board==True AND Green's Exploration==False AND Heat Factory ♢==False AND Multi Switch==False
# Subgrupo: Chaotic Swell==False AND Escape Board==True AND Green's Exploration==False AND Heat Factory ♢==False
#
#      quality                                           subgroup  size_sg  \
# 0   0.236581  Escape Board==True AND Green's Exploration==False      202
# 1   0.236581  Escape Board==True AND Green's Exploration==Fa...      202
# 2   0.236581  Escape Board==True AND Green's Exploration==Fa...      202
# 3   0.236581  Escape Board==True AND Green's Exploration==Fa...      202
# 4   0.236581  Escape Board==True AND Green's Exploration==Fa...      202
# 5   0.236581  Escape Board==True AND Green's Exploration==Fa...      202
# 6   0.236581  Escape Board==True AND Green's Exploration==Fa...      202
# 7   0.236581  Escape Board==True AND Green's Exploration==Fa...      202
# 8   0.236581  Chaotic Swell==False AND Escape Board==True AN...      202
# 9   0.236581  Chaotic Swell==False AND Escape Board==True AN...      202
# 10  0.236581  Chaotic Swell==False AND Escape Board==True AN...      202
# 11  0.236581  Chaotic Swell==False AND Escape Board==True AN...      202
# 12  0.236581  Chaotic Swell==False AND Escape Board==True AN...      202
# 13  0.236581  Chaotic Swell==False AND Escape Board==True AN...      202
# 14  0.236581  Chaotic Swell==False AND Escape Board==True AN...      202
# 15  0.235383  Escape Board==True AND Green's Exploration==Fa...      201
# 16  0.235383  Escape Board==True AND Green's Exploration==Fa...      201
# 17  0.235383  Escape Board==True AND Green's Exploration==Fa...      201
# 18  0.235383  Escape Board==True AND Green's Exploration==Fa...      201
# 19  0.235383  Chaotic Swell==False AND Escape Board==True AN...      201
#
#     size_dataset  positives_sg  positives_dataset  size_complement  \
# 0            370           200                206              168
# 1            370           200                206              168
# 2            370           200                206              168
# 3            370           200                206              168
# 4            370           200                206              168
# 5            370           200                206              168
# 6            370           200                206              168
# 7            370           200                206              168
# 8            370           200                206              168
# 9            370           200                206              168
# 10           370           200                206              168
# 11           370           200                206              168
# 12           370           200                206              168
# 13           370           200                206              168
# 14           370           200                206              168
# 15           370           199                206              169
# 16           370           199                206              169
# 17           370           199                206              169
# 18           370           199                206              169
# 19           370           199                206              169
#
#     relative_size_sg  relative_size_complement  coverage_sg  \
# 0           0.545946                  0.454054     0.970874
# 1           0.545946                  0.454054     0.970874
# 2           0.545946                  0.454054     0.970874
# 3           0.545946                  0.454054     0.970874
# 4           0.545946                  0.454054     0.970874
# 5           0.545946                  0.454054     0.970874
# 6           0.545946                  0.454054     0.970874
# 7           0.545946                  0.454054     0.970874
# 8           0.545946                  0.454054     0.970874
# 9           0.545946                  0.454054     0.970874
# 10          0.545946                  0.454054     0.970874
# 11          0.545946                  0.454054     0.970874
# 12          0.545946                  0.454054     0.970874
# 13          0.545946                  0.454054     0.970874
# 14          0.545946                  0.454054     0.970874
# 15          0.543243                  0.456757     0.966019
# 16          0.543243                  0.456757     0.966019
# 17          0.543243                  0.456757     0.966019
# 18          0.543243                  0.456757     0.966019
# 19          0.543243                  0.456757     0.966019
#
#     coverage_complement  target_share_sg  target_share_complement  \
# 0              0.029126         0.990099                 0.035714
# 1              0.029126         0.990099                 0.035714
# 2              0.029126         0.990099                 0.035714
# 3              0.029126         0.990099                 0.035714
# 4              0.029126         0.990099                 0.035714
# 5              0.029126         0.990099                 0.035714
# 6              0.029126         0.990099                 0.035714
# 7              0.029126         0.990099                 0.035714
# 8              0.029126         0.990099                 0.035714
# 9              0.029126         0.990099                 0.035714
# 10             0.029126         0.990099                 0.035714
# 11             0.029126         0.990099                 0.035714
# 12             0.029126         0.990099                 0.035714
# 13             0.029126         0.990099                 0.035714
# 14             0.029126         0.990099                 0.035714
# 15             0.033981         0.990050                 0.041420
# 16             0.033981         0.990050                 0.041420
# 17             0.033981         0.990050                 0.041420
# 18             0.033981         0.990050                 0.041420
# 19             0.033981         0.990050                 0.041420
#
#     target_share_dataset      lift
# 0               0.556757  1.778333
# 1               0.556757  1.778333
# 2               0.556757  1.778333
# 3               0.556757  1.778333
# 4               0.556757  1.778333
# 5               0.556757  1.778333
# 6               0.556757  1.778333
# 7               0.556757  1.778333
# 8               0.556757  1.778333
# 9               0.556757  1.778333
# 10              0.556757  1.778333
# 11              0.556757  1.778333
# 12              0.556757  1.778333
# 13              0.556757  1.778333
# 14              0.556757  1.778333
# 15              0.556757  1.778245
# 16              0.556757  1.778245
# 17              0.556757  1.778245
# 18              0.556757  1.778245
# 19              0.556757  1.778245
#
# ---------------------------------------------------------------------------------------------------------------------------------
