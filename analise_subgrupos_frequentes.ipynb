# %% [markdown]
# ## Bibliotecas Utilizadas e Carregamento do Dataset

# %%
import numpy as np
import pandas as pd
import pysubgroup as ps
from mlxtend.frequent_patterns import apriori, association_rules

# %% [markdown]
# ## Tratando o Dataframe
#
# O dataset é carregado a partir do arquivo csv. São realizados alguns tratamentos, como a substituição dos valores nulos por 0 e eliminar cartas do tipo treinador. Após isso, o dataset é checado para identificar as regiões de torneio presentes.

# %%
df_original = pd.read_csv('./Data/tournaments.csv')
df = df_original.copy()

df.replace(np.nan, 0, inplace=True)

df = df[df['region_tournament'] != 0]
df = df[df['type_card'] != 'Trainer']
regions = df['region_tournament'].unique()

# %% [markdown]
# ### Agrupamento de Cartas por Jogador e Região
#
# O dataset é agrupado em cartas por jogador e é aplicado o algoritmo Apriori para encontrar padrões frequentes de cartas utilizadas pelos jogadores.
#
# O algoritmo Apriori é uma abordagem clássica feita para mineração de regras de associação. Ele é útil geralmente para recomendações de produtos e, nesse caso, analisar itemsets frequentes de cartas.

# %%
def agrupa_jogador_cartas(df):
    dict_jogador_cartas = {}
    for _, row in df.iterrows():
        if row['name_player'] not in dict_jogador_cartas:
            dict_jogador_cartas[row['name_player']] = []
        dict_jogador_cartas[row['name_player']].append(row['name_card'])
    return len(dict_jogador_cartas), dict_jogador_cartas

info_por_regiao = {}
for region in regions:
    df_region = df[(df['region_tournament'] == region) & (df['year_tournament'] == 2019)]
    jogadores = df_region['name_player'].unique()
    cartas = df_region['name_card'].unique()

    quantidade_jogadores, dict_jogador_cartas = agrupa_jogador_cartas(df_region)

    df_jogadores_cartas = pd.DataFrame(columns=cartas)

    for jogador in jogadores:
        cartas_jogador = dict_jogador_cartas[jogador]
        linha = [True if carta in cartas_jogador else False for carta in cartas]
        df_jogadores_cartas.loc[len(df_jogadores_cartas)] = linha

    frequent_itemsets = apriori(df_jogadores_cartas, min_support=0.22, use_colnames=True)
    frequent_itemsets.sort_values(by='support', ascending=False, inplace=True)

    rules = association_rules(frequent_itemsets, metric="confidence", min_threshold=0.4)
    rules = rules.sort_values(by='lift', ascending=False).drop(['antecedent support', 'consequent support', 'leverage', 'conviction', 'zhangs_metric'], axis=1)
    
    info_por_regiao[region] = {'itemsets': frequent_itemsets[:3], 'rules': rules[:3]}

    print(f"Total de jogadores: {quantidade_jogadores}")
    print("Itemsets frequentes")
    print(frequent_itemsets)
    print("Regras")
    print(rules)
    print("\n\n")
# Out:
# Total de jogadores: 73
# Itemsets frequentes
#     support                                    itemsets
# 0  0.589041                                   (Jirachi)
# 1  0.493151                                (Dedenne-GX)
# 2  0.410959              (Mega Lopunny & Jigglypuff-GX)
# 6  0.342466                       (Jirachi, Dedenne-GX)
# 3  0.301370               (Arceus & Dialga & Palkia-GX)
# 7  0.287671  (Mega Lopunny & Jigglypuff-GX, Dedenne-GX)
# 4  0.246575                                 (Keldeo-GX)
# 5  0.246575                                 (Cryogonal)
# 8  0.246575    (Arceus & Dialga & Palkia-GX, Cryogonal)
# Regras
#                       antecedents                     consequents   support  \
# 4   (Arceus & Dialga & Palkia-GX)                     (Cryogonal)  0.246575
# 5                     (Cryogonal)   (Arceus & Dialga & Palkia-GX)  0.246575
# 3                    (Dedenne-GX)  (Mega Lopunny & Jigglypuff-GX)  0.287671
# 2  (Mega Lopunny & Jigglypuff-GX)                    (Dedenne-GX)  0.287671
# 1                    (Dedenne-GX)                       (Jirachi)  0.342466
# 0                       (Jirachi)                    (Dedenne-GX)  0.342466
#
#    confidence      lift
# 4    0.818182  3.318182
# 5    1.000000  3.318182
# 3    0.583333  1.419444
# 2    0.700000  1.419444
# 1    0.694444  1.178941
# 0    0.581395  1.178941
#
#
#
# Total de jogadores: 83
# Itemsets frequentes
#      support                                           itemsets
# 5   0.650602                                      (Tapu Koko ♢)
# 0   0.590361                                          (Jirachi)
# 7   0.590361                                        (Marshadow)
# 1   0.530120                                           (Zapdos)
# 18  0.493976                              (Tapu Koko ♢, Zapdos)
# ..       ...                                                ...
# 43  0.228916                 (Zapdos, Tapu Koko-GX, Zeraora-GX)
# 65  0.228916    (Tapu Koko ♢, Zapdos, Tapu Koko-GX, Zeraora-GX)
# 66  0.228916      (Zapdos, Marshadow, Tapu Koko-GX, Zeraora-GX)
# 69  0.228916  (Pikachu & Zekrom-GX, Marshadow, Tapu Koko ♢, ...
# 73  0.228916  (Zapdos, Marshadow, Tapu Koko ♢, Zeraora-GX, T...
#
# [74 rows x 2 columns]
# Regras
#                                         antecedents  \
# 334                     (Tapu Koko ♢, Tapu Lele-GX)
# 337                         (Marshadow, Zeraora-GX)
# 329          (Tapu Koko ♢, Marshadow, Tapu Lele-GX)
# 341                                    (Zeraora-GX)
# 296                     (Tapu Koko ♢, Tapu Lele-GX)
# ..                                              ...
# 171                                    (Zeraora-GX)
# 165                       (Tapu Koko ♢, Zeraora-GX)
# 399  (Pikachu & Zekrom-GX, Tapu Koko ♢, Zeraora-GX)
# 361               (Pikachu & Zekrom-GX, Zeraora-GX)
# 301                                  (Tapu Lele-GX)
#
#                                 consequents   support  confidence      lift
# 334                 (Marshadow, Zeraora-GX)  0.240964    0.952381  3.040293
# 337             (Tapu Koko ♢, Tapu Lele-GX)  0.240964    0.769231  3.040293
# 329                            (Zeraora-GX)  0.240964    1.000000  2.371429
# 341  (Tapu Koko ♢, Marshadow, Tapu Lele-GX)  0.240964    0.571429  2.371429
# 296                            (Zeraora-GX)  0.253012    1.000000  2.371429
# ..                                      ...       ...         ...       ...
# 171                               (Jirachi)  0.289157    0.685714  1.161516
# 165                               (Jirachi)  0.289157    0.685714  1.161516
# 399                             (Marshadow)  0.228916    0.678571  1.149417
# 361                             (Marshadow)  0.228916    0.678571  1.149417
# 301                           (Tapu Koko ♢)  0.253012    0.636364  0.978114
#
# [437 rows x 5 columns]
#
#
#
# Total de jogadores: 110
# Itemsets frequentes
#      support                                           itemsets
# 0   0.609091                                          (Jirachi)
# 5   0.590909                                     (Tapu Lele-GX)
# 6   0.527273                                        (Marshadow)
# 2   0.381818                                      (Tapu Koko ♢)
# 4   0.372727                                            (Absol)
# 1   0.372727                                           (Zapdos)
# 3   0.363636                                     (Tapu Koko-GX)
# 13  0.363636                              (Tapu Koko ♢, Zapdos)
# 21  0.363636                          (Marshadow, Tapu Lele-GX)
# 16  0.363636                        (Tapu Koko ♢, Tapu Koko-GX)
# 14  0.345455                             (Zapdos, Tapu Koko-GX)
# 28  0.345455                (Tapu Koko ♢, Zapdos, Tapu Koko-GX)
# 11  0.318182                            (Jirachi, Tapu Lele-GX)
# 17  0.309091                               (Tapu Koko ♢, Absol)
# 7   0.309091                                  (Jirachi, Zapdos)
# 8   0.300000                             (Tapu Koko ♢, Jirachi)
# 10  0.300000                                   (Jirachi, Absol)
# 12  0.300000                               (Jirachi, Marshadow)
# 22  0.300000                     (Tapu Koko ♢, Jirachi, Zapdos)
# 29  0.290909                       (Tapu Koko ♢, Zapdos, Absol)
# 19  0.290909                              (Absol, Tapu Koko-GX)
# 15  0.290909                                    (Zapdos, Absol)
# 31  0.290909                 (Tapu Koko ♢, Absol, Tapu Koko-GX)
# 25  0.281818               (Tapu Koko ♢, Jirachi, Tapu Koko-GX)
# 9   0.281818                            (Jirachi, Tapu Koko-GX)
# 23  0.281818                    (Jirachi, Zapdos, Tapu Koko-GX)
# 32  0.281818       (Tapu Koko ♢, Jirachi, Zapdos, Tapu Koko-GX)
# 30  0.272727                      (Zapdos, Absol, Tapu Koko-GX)
# 36  0.272727         (Tapu Koko ♢, Zapdos, Absol, Tapu Koko-GX)
# 33  0.254545              (Tapu Koko ♢, Jirachi, Zapdos, Absol)
# 24  0.254545                           (Jirachi, Zapdos, Absol)
# 26  0.254545                      (Tapu Koko ♢, Jirachi, Absol)
# 27  0.236364                     (Jirachi, Absol, Tapu Koko-GX)
# 34  0.236364             (Jirachi, Zapdos, Absol, Tapu Koko-GX)
# 35  0.236364        (Tapu Koko ♢, Jirachi, Absol, Tapu Koko-GX)
# 37  0.236364  (Jirachi, Zapdos, Absol, Tapu Koko ♢, Tapu Kok...
# 20  0.227273                                 (Marshadow, Absol)
# 18  0.227273                           (Tapu Koko ♢, Marshadow)
# Regras
#                        antecedents                    consequents   support  \
# 105                (Zapdos, Absol)         (Tapu Koko ♢, Jirachi)  0.254545
# 100         (Tapu Koko ♢, Jirachi)                (Zapdos, Absol)  0.254545
# 165  (Zapdos, Absol, Tapu Koko-GX)         (Tapu Koko ♢, Jirachi)  0.236364
# 170         (Tapu Koko ♢, Jirachi)  (Zapdos, Absol, Tapu Koko-GX)  0.236364
# 134                (Zapdos, Absol)        (Jirachi, Tapu Koko-GX)  0.236364
# ..                             ...                            ...       ...
# 185                    (Marshadow)                  (Tapu Koko ♢)  0.227273
# 24                       (Jirachi)                    (Marshadow)  0.300000
# 25                     (Marshadow)                      (Jirachi)  0.300000
# 14                       (Jirachi)                 (Tapu Lele-GX)  0.318182
# 15                  (Tapu Lele-GX)                      (Jirachi)  0.318182
#
#      confidence      lift
# 105    0.875000  2.916667
# 100    0.848485  2.916667
# 165    0.866667  2.888889
# 170    0.787879  2.888889
# 134    0.812500  2.883065
# ..          ...       ...
# 185    0.431034  1.128900
# 24     0.492537  0.934122
# 25     0.568966  0.934122
# 14     0.522388  0.884041
# 15     0.538462  0.884041
#
# [186 rows x 5 columns]
#
#
#
# Total de jogadores: 85
# Itemsets frequentes
#     support                    itemsets
# 0  0.423529                   (Jirachi)
# 2  0.423529                (Dedenne-GX)
# 3  0.411765                 (Marshadow)
# 5  0.341176              (Tapu Lele-GX)
# 7  0.282353     (Marshadow, Dedenne-GX)
# 4  0.282353                     (Absol)
# 1  0.270588               (Tapu Koko ♢)
# 8  0.235294  (Tapu Lele-GX, Dedenne-GX)
# 9  0.235294   (Tapu Lele-GX, Marshadow)
# 6  0.223529    (Tapu Koko ♢, Marshadow)
# Regras
#       antecedents     consequents   support  confidence      lift
# 6   (Tapu Koko ♢)     (Marshadow)  0.223529    0.826087  2.006211
# 7     (Marshadow)   (Tapu Koko ♢)  0.223529    0.542857  2.006211
# 4  (Tapu Lele-GX)     (Marshadow)  0.235294    0.689655  1.674877
# 5     (Marshadow)  (Tapu Lele-GX)  0.235294    0.571429  1.674877
# 2  (Tapu Lele-GX)    (Dedenne-GX)  0.235294    0.689655  1.628352
# 3    (Dedenne-GX)  (Tapu Lele-GX)  0.235294    0.555556  1.628352
# 0     (Marshadow)    (Dedenne-GX)  0.282353    0.685714  1.619048
# 1    (Dedenne-GX)     (Marshadow)  0.282353    0.666667  1.619048

# %% [markdown]
# ### Análise por região

# %%
for region in regions:
    print(f"Região: {region}")
    print("Itemsets frequentes")
    print(info_por_regiao[region]['itemsets'])
    print("Regras")
    print(info_por_regiao[region]['rules'])
    print("\n\n")
# Out:
# Região: SA
# Itemsets frequentes
#     support                        itemsets
# 0  0.589041                       (Jirachi)
# 1  0.493151                    (Dedenne-GX)
# 2  0.410959  (Mega Lopunny & Jigglypuff-GX)
# Regras
#                      antecedents                     consequents   support  \
# 4  (Arceus & Dialga & Palkia-GX)                     (Cryogonal)  0.246575
# 5                    (Cryogonal)   (Arceus & Dialga & Palkia-GX)  0.246575
# 3                   (Dedenne-GX)  (Mega Lopunny & Jigglypuff-GX)  0.287671
#
#    confidence      lift
# 4    0.818182  3.318182
# 5    1.000000  3.318182
# 3    0.583333  1.419444
#
#
#
# Região: EU
# Itemsets frequentes
#     support       itemsets
# 5  0.650602  (Tapu Koko ♢)
# 0  0.590361      (Jirachi)
# 7  0.590361    (Marshadow)
# Regras
#                                 antecedents                  consequents  \
# 334             (Tapu Koko ♢, Tapu Lele-GX)      (Marshadow, Zeraora-GX)
# 337                 (Marshadow, Zeraora-GX)  (Tapu Koko ♢, Tapu Lele-GX)
# 329  (Tapu Koko ♢, Marshadow, Tapu Lele-GX)                 (Zeraora-GX)
#
#       support  confidence      lift
# 334  0.240964    0.952381  3.040293
# 337  0.240964    0.769231  3.040293
# 329  0.240964    1.000000  2.371429
#
#
#
# Região: AS-OC
# Itemsets frequentes
#     support        itemsets
# 0  0.609091       (Jirachi)
# 5  0.590909  (Tapu Lele-GX)
# 6  0.527273     (Marshadow)
# Regras
#                        antecedents             consequents   support  \
# 105                (Zapdos, Absol)  (Tapu Koko ♢, Jirachi)  0.254545
# 100         (Tapu Koko ♢, Jirachi)         (Zapdos, Absol)  0.254545
# 165  (Zapdos, Absol, Tapu Koko-GX)  (Tapu Koko ♢, Jirachi)  0.236364
#
#      confidence      lift
# 105    0.875000  2.916667
# 100    0.848485  2.916667
# 165    0.866667  2.888889
#
#
#
# Região: JP
# Itemsets frequentes
#     support      itemsets
# 0  0.423529     (Jirachi)
# 2  0.423529  (Dedenne-GX)
# 3  0.411765   (Marshadow)
# Regras
#       antecedents    consequents   support  confidence      lift
# 6   (Tapu Koko ♢)    (Marshadow)  0.223529    0.826087  2.006211
# 7     (Marshadow)  (Tapu Koko ♢)  0.223529    0.542857  2.006211
# 4  (Tapu Lele-GX)    (Marshadow)  0.235294    0.689655  1.674877

# %% [markdown]
# ### Descoberta de Subgrupos

# %%
df = df_original.copy()
df = df[(df['ranking_player_tournament'] != np.nan)]

df = df[['name_card', 'energy_type_card', 'ranking_player_tournament', 'combo_type_name']]
df = df.dropna(subset=['name_card', 'combo_type_name', 'ranking_player_tournament'])

df['top_position'] = (df['ranking_player_tournament'] <= 15).astype(int)

target = ps.BinaryTarget('top_position', 1)

name_selectors = [ps.EqualitySelector('name_card', value) for value in df['name_card'].unique()]
energy_selectors = [ps.EqualitySelector('energy_type_card', value) for value in df['energy_type_card'].unique()]
combo_type_selector = [ps.EqualitySelector('combo_type_name', value) for value in df['combo_type_name'].unique()]

search_space = name_selectors + energy_selectors + combo_type_selector

task = ps.SubgroupDiscoveryTask(
    df, 
    target, 
    search_space, 
    result_set_size=6, 
    depth=4, 
    qf=ps.WRAccQF()
)

result = ps.BeamSearch().execute(task)

df_result = result.to_dataframe()
df_result
# Out:
#     quality                            subgroup  size_sg  size_dataset  \
# 0  0.004040              energy_type_card=='GX'     3137        114244
# 1  0.002537              energy_type_card=='EX'      926        114244
# 2  0.002396     combo_type_name=='Mewtwo & Mew'      862        114244
# 3  0.002195           energy_type_card.isnull()    71811        114244
# 4  0.002125  combo_type_name=='Palkia Inteleon'     2343        114244
# 5  0.002096       combo_type_name=='Zacian ADP'      995        114244
#
#    positives_sg  positives_dataset  size_complement  relative_size_sg  \
# 0          1387              33702           111107          0.027459
# 1           563              33702           113318          0.008105
# 2           528              33702           113382          0.007545
# 3         21435              33702            42433          0.628576
# 4           934              33702           111901          0.020509
# 5           533              33702           113249          0.008709
#
#    relative_size_complement  coverage_sg  coverage_complement  \
# 0                  0.972541     0.041155             0.958845
# 1                  0.991895     0.016705             0.983295
# 2                  0.992455     0.015667             0.984333
# 3                  0.371424     0.636016             0.363984
# 4                  0.979491     0.027713             0.972287
# 5                  0.991291     0.015815             0.984185
#
#    target_share_sg  target_share_complement  target_share_dataset      lift
# 0         0.442142                 0.290846                 0.295  1.498786
# 1         0.607991                 0.292443                 0.295  2.060986
# 2         0.612529                 0.292586                 0.295  2.076368
# 3         0.298492                 0.289091                 0.295  1.011836
# 4         0.398634                 0.292830                 0.295  1.351302
# 5         0.535678                 0.292886                 0.295  1.815858

# %% [markdown]
# ### Análise de resultado por região

# %%
for region in regions:
    print(f"Região: {region}")
    print("Itemsets frequentes")
    print(info_por_regiao[region]['itemsets'])
    print("Regras")
    print(info_por_regiao[region]['rules'])
    print("\n\n")
# Out:
# Região: SA
# Itemsets frequentes
#     support                        itemsets
# 0  0.589041                       (Jirachi)
# 1  0.493151                    (Dedenne-GX)
# 2  0.410959  (Mega Lopunny & Jigglypuff-GX)
# Regras
#                      antecedents                     consequents   support  \
# 4  (Arceus & Dialga & Palkia-GX)                     (Cryogonal)  0.246575
# 5                    (Cryogonal)   (Arceus & Dialga & Palkia-GX)  0.246575
# 3                   (Dedenne-GX)  (Mega Lopunny & Jigglypuff-GX)  0.287671
#
#    confidence      lift
# 4    0.818182  3.318182
# 5    1.000000  3.318182
# 3    0.583333  1.419444
#
#
#
# Região: EU
# Itemsets frequentes
#     support       itemsets
# 5  0.650602  (Tapu Koko ♢)
# 0  0.590361      (Jirachi)
# 7  0.590361    (Marshadow)
# Regras
#                                 antecedents                  consequents  \
# 334             (Tapu Koko ♢, Tapu Lele-GX)      (Marshadow, Zeraora-GX)
# 337                 (Marshadow, Zeraora-GX)  (Tapu Koko ♢, Tapu Lele-GX)
# 329  (Tapu Koko ♢, Marshadow, Tapu Lele-GX)                 (Zeraora-GX)
#
#       support  confidence      lift
# 334  0.240964    0.952381  3.040293
# 337  0.240964    0.769231  3.040293
# 329  0.240964    1.000000  2.371429
#
#
#
# Região: AS-OC
# Itemsets frequentes
#     support        itemsets
# 0  0.609091       (Jirachi)
# 5  0.590909  (Tapu Lele-GX)
# 6  0.527273     (Marshadow)
# Regras
#                        antecedents             consequents   support  \
# 105                (Zapdos, Absol)  (Tapu Koko ♢, Jirachi)  0.254545
# 100         (Tapu Koko ♢, Jirachi)         (Zapdos, Absol)  0.254545
# 165  (Zapdos, Absol, Tapu Koko-GX)  (Tapu Koko ♢, Jirachi)  0.236364
#
#      confidence      lift
# 105    0.875000  2.916667
# 100    0.848485  2.916667
# 165    0.866667  2.888889
#
#
#
# Região: JP
# Itemsets frequentes
#     support      itemsets
# 0  0.423529     (Jirachi)
# 2  0.423529  (Dedenne-GX)
# 3  0.411765   (Marshadow)
# Regras
#       antecedents    consequents   support  confidence      lift
# 6   (Tapu Koko ♢)    (Marshadow)  0.223529    0.826087  2.006211
# 7     (Marshadow)  (Tapu Koko ♢)  0.223529    0.542857  2.006211
# 4  (Tapu Lele-GX)    (Marshadow)  0.235294    0.689655  1.674877

# %%
df['top_position'] = (df['ranking_player_tournament'] <= 15).astype(int)
target = ps.BinaryTarget('top_position', 1)

name_selectors = [ps.EqualitySelector('name_card', value) for value in df['name_card'].unique()]
energy_selectors = [ps.EqualitySelector('energy_type_card', value) for value in df['energy_type_card'].unique()]
combo_type_selectors = [ps.EqualitySelector('combo_type_name', value) for value in df['combo_type_name'].unique()]

search_space = name_selectors + energy_selectors + combo_type_selectors

task = ps.SubgroupDiscoveryTask(
    df,
    target,
    search_space,
    result_set_size=10,
    depth=4,
    qf=ps.WRAccQF()
)

result = ps.BeamSearch().execute(task)

df_result = result.to_dataframe()

print("Results with WRAccQF:")
print(df_result)

# %%
task_with_standard = ps.SubgroupDiscoveryTask(
    df,
    target,
    search_space,
    result_set_size=10,
    depth=4,
    qf=ps.StandardQF(1.0)
)

result_standard = ps.BeamSearch().execute(task_with_standard)
df_result_standard = result_standard.to_dataframe()

print("Results with StandardQF:")
print(df_result_standard)
# Out:
# Results with StandardQF:
#     quality                                           subgroup  size_sg  \
# 0  0.004040                             energy_type_card=='GX'     3137
# 1  0.002537                             energy_type_card=='EX'      926
# 2  0.002396                    combo_type_name=='Mewtwo & Mew'      862
# 3  0.002195                          energy_type_card.isnull()    71811
# 4  0.002125                 combo_type_name=='Palkia Inteleon'     2343
# 5  0.002096                      combo_type_name=='Zacian ADP'      995
# 6  0.001888                          combo_type_name=='Zapdos'     1184
# 7  0.001708                     combo_type_name=='Night March'      637
# 8  0.001527  combo_type_name=='Palkia Inteleon' AND energy_...     1534
# 9  0.001476            combo_type_name=='Reshiram & Charizard'      398
#
#    size_dataset  positives_sg  positives_dataset  size_complement  \
# 0        114244          1387              33702           111107
# 1        114244           563              33702           113318
# 2        114244           528              33702           113382
# 3        114244         21435              33702            42433
# 4        114244           934              33702           111901
# 5        114244           533              33702           113249
# 6        114244           565              33702           113060
# 7        114244           383              33702           113607
# 8        114244           627              33702           112710
# 9        114244           286              33702           113846
#
#    relative_size_sg  relative_size_complement  coverage_sg  \
# 0          0.027459                  0.972541     0.041155
# 1          0.008105                  0.991895     0.016705
# 2          0.007545                  0.992455     0.015667
# 3          0.628576                  0.371424     0.636016
# 4          0.020509                  0.979491     0.027713
# 5          0.008709                  0.991291     0.015815
# 6          0.010364                  0.989636     0.016765
# 7          0.005576                  0.994424     0.011364
# 8          0.013427                  0.986573     0.018604
# 9          0.003484                  0.996516     0.008486
#
#    coverage_complement  target_share_sg  target_share_complement  \
# 0             0.958845         0.442142                 0.290846
# 1             0.983295         0.607991                 0.292443
# 2             0.984333         0.612529                 0.292586
# 3             0.363984         0.298492                 0.289091
# 4             0.972287         0.398634                 0.292830
# 5             0.984185         0.535678                 0.292886
# 6             0.983235         0.477196                 0.293092
# 7             0.988636         0.601256                 0.293283
# 8             0.981396         0.408735                 0.293452
# 9             0.991514         0.718593                 0.293519
#
#    target_share_dataset      lift
# 0                 0.295  1.498786
# 1                 0.295  2.060986
# 2                 0.295  2.076368
# 3                 0.295  1.011836
# 4                 0.295  1.351302
# 5                 0.295  1.815858
# 6                 0.295  1.617612
# 7                 0.295  2.038154
# 8                 0.295  1.385543
# 9                 0.295  2.435907
