# %% [markdown]
# Com o Resultado do `fpgrowth`, descobrimos que a carta `jirachi` é uma carta amplamante utilizadas entre os jogadores nos torneios de 2019.
# Iremos utilizar um algoritmo SD como alvo o ranking dos jogadores variando de 0 para ranks piores que `RANK_ANALISAR` e 1 o contrario, nos torneios do ano de 2019 para encontrar informacoes do que precisamos para criar um deck ideal e ver se o algoritmo recomendara a carta `jirachi`.

# %% [markdown]
# ## Variaveis para definir

# %%
CONSIDERAR_TREINADORES = True
ANO_ANALISAR = 2019
RANK_ANALISAR = 5

# quantidade de cartas de 1 tipo que deve exitir no dataset para ser considerado evitando outliers 
CARTAS_MINIMAS = 10

# %% [markdown]
# ## Bibliotecas utilizadas e carregando dataset

# %%
import numpy as np
import pandas as pd
import pysubgroup as ps

df_original = pd.read_csv('./Data/tournaments.csv')
df = df_original.copy()

# %% [markdown]
# ## Eliminar cartas de treinador se quiser

# %%
if not CONSIDERAR_TREINADORES:
    df = df[df['type_card'] != 'Trainer']

# %% [markdown]
# ## Filtragem de colunas no dataset e limpeza de linhas com coluna regiao do torneio vazias

# %%
columns_to_remove = [
    'id_card', 'amount_card', 'price_card', 'combo_type_id', 'name_tournament',
    'combo_type_name', 'name_player', 'category_tournament', 'type_card',
    'month_tournament', 'day_tournament', 'valid_rotation_at_tournament', 
    'rotation_name', 'year_begin', 'all_time_score', 'country_tournament', 'country_player',
    'month_begin', 'day_begin',
]
df.drop(columns=columns_to_remove, inplace=True)
df = df[df['region_tournament'].notna()]

df.head(1)
# Out:
#        name_card energy_type_card  id_player  ranking_player_tournament
# 7462  Charmander             Fire        649                          1  \
#
#       id_tournament region_tournament  year_tournament
# 7462            385                SA             2023

# %% [markdown]
# ## Adaptando dados para pordermos usar SD
#
# Como somente `ranking_player` do tipo numerico, vamos transformalo em binario em que menor que `RANK_ANALISAR` seria 1, estamos buscando cartas que aumentem a probabilidade de um jogador subir de rank acima de `RANK_ANALISAR`

# %%
# todos os ranking players acima de 15 sao 1
df['ranking_player_tournament'] = df['ranking_player_tournament'].apply(lambda x: 1 if x < RANK_ANALISAR else 0)

df.head(1)
# Out:
#        name_card energy_type_card  id_player  ranking_player_tournament
# 7462  Charmander             Fire        649                          1  \
#
#       id_tournament region_tournament  year_tournament
# 7462            385                SA             2023

# %% [markdown]
# ## Separando por regiao e verificando a qualidade dos subgrupos de cartas que aumentem a probabilidade de um jogador subir no rank

# %%
def elimina_cards_menos_usados(df):
    cartas = df['name_card'].unique()
    for carta in cartas:
        if len(df[df['name_card'] == carta]) < CARTAS_MINIMAS:
            df = df[df['name_card'] != carta]
    return df

def agrupa_deck_rank(df_region):
    #filtra torneios da regiao
    torneios = df_region['id_tournament'].unique()

    lista_decks_rank = []
    for torneio in torneios:
        df_torneio = df_region[df_region['id_tournament'] == torneio]
        jogadores = df_torneio['id_player'].unique()
        for jogador in jogadores:
            df_jogador = df_torneio[df_torneio['id_player'] == jogador]
            cartas_jogador_rank = df_jogador['name_card'].unique().tolist()
            cartas_jogador_rank.append(df_jogador['ranking_player_tournament'].iloc[0])
            lista_decks_rank.append(cartas_jogador_rank)
    return lista_decks_rank

def subgrupo_dataset_region(df_region):
    lista_decks_rank = agrupa_deck_rank(df_region)
    cartas = df_region['name_card'].unique()
    data = []
    for deck_rank in lista_decks_rank:
        pokemons_no_deck_rank = {carta: (carta in deck_rank[:len(deck_rank)-1]) for carta in cartas}
        pokemons_no_deck_rank['ranking_player_tournament'] = deck_rank[-1]
        data.append(pokemons_no_deck_rank)
    # Converte a lista de dicionários em um DataFrame
    df_decks_cartas = pd.DataFrame(data)

    return df_decks_cartas

def calcula_subgrupo(df):
    target = ps.BinaryTarget('ranking_player_tournament',1)
    search_space = ps.create_selectors(df, ignore=['ranking_player_tournament'])
    task = ps.SubgroupDiscoveryTask(
        df,
        target, 
        search_space, 
        result_set_size=20, 
        depth=5, 
        qf=ps.WRAccQF()  # Quality function to evaluate subgroups
    )
    result = ps.BeamSearch().execute(task)
    return result

# %% [markdown]
# ### Por regiao

# %%
regions = df['region_tournament'].unique()
for region in regions:
    print(f"Região: {region}\n")
    df_region = df[(df['region_tournament'] == region) & (df['year_tournament'] == ANO_ANALISAR)]

    # verifica se tem torneios na regiao
    if len(df_region) == 0:
        print(f'Sem torneios na região {region} no ano {ANO_ANALISAR}\n')
        print("-------------------------------------------"*3)
        continue

    # calcula subgrupo
    df_region = elimina_cards_menos_usados(df_region)
    dataset = subgrupo_dataset_region(df_region)
    result = calcula_subgrupo(dataset)

    # imprime resultados
    for row in result.to_dataframe().itertuples():
        print(f"Subgrupo: {row.subgroup}")
    print()
    print(result.to_dataframe(), "\n")
    print("-------------------------------------------"*3)
# Out:
# Região: SA
#
# Subgrupo: Acro Bike==False AND Cryogonal==False AND Custom Catcher==False AND Mew==False AND Professor Elm's Lecture==False
# Subgrupo: Acro Bike==False AND Cryogonal==False AND Custom Catcher==False AND Mew==False AND Pidgey==False
# Subgrupo: Cryogonal==False AND Custom Catcher==False AND Latios-GX==False AND Mew==False AND Professor Elm's Lecture==False
# Subgrupo: Cryogonal==False AND Custom Catcher==False AND Latios-GX==False AND Mew==False AND Pidgey==False
# Subgrupo: Acro Bike==False AND Cryogonal==False AND Custom Catcher==False AND Latios-GX==False AND Professor Elm's Lecture==False
# Subgrupo: Acro Bike==False AND Cryogonal==False AND Custom Catcher==False AND Latios-GX==False AND Pidgey==False
# Subgrupo: Acro Bike==False AND Cryogonal==False AND Custom Catcher==False AND Latios-GX==False AND Mew==False
# Subgrupo: Acro Bike==False AND Cryogonal==False AND Custom Catcher==False AND Latios-GX==False AND Mallow & Lana==True
# Subgrupo: Acro Bike==False AND Cryogonal==False AND Custom Catcher==False AND Mallow & Lana==True AND Reset Stamp==True
# Subgrupo: Acro Bike==False AND Cryogonal==False AND Custom Catcher==False AND Mallow & Lana==True AND Mew==False
# Subgrupo: Acro Bike==False AND Cryogonal==False AND Custom Catcher==False AND Ditto ♢==False AND Mallow & Lana==True
# Subgrupo: Acro Bike==False AND Cryogonal==False AND Custom Catcher==False AND Mew==False
# Subgrupo: Cryogonal==False AND Custom Catcher==False AND Latios-GX==False AND Mallow & Lana==True AND Mew==False
# Subgrupo: Cryogonal==False AND Custom Catcher==False AND Ditto ♢==False AND Latios-GX==False AND Mallow & Lana==True
# Subgrupo: Acro Bike==False AND Cryogonal==False AND Custom Catcher==False AND Mallow & Lana==True
# Subgrupo: Acro Bike==False AND Cryogonal==False AND Custom Catcher==False AND Mallow & Lana==True AND Victini ♢==False
# Subgrupo: Acro Bike==False AND Cryogonal==False AND Custom Catcher==False AND Mallow & Lana==True AND Professor Elm's Lecture==False
# Subgrupo: Acro Bike==False AND Cryogonal==False AND Custom Catcher==False AND Mallow & Lana==True AND Pidgey==False
# Subgrupo: Acro Bike==False AND Cryogonal==False AND Custom Catcher==False AND Great Catcher==True AND Mallow & Lana==True
# Subgrupo: Acro Bike==False AND Cryogonal==False AND Custom Catcher==False AND Fiery Flint==False AND Mallow & Lana==True
#
#      quality                                           subgroup  size_sg
# 0   0.072246  Acro Bike==False AND Cryogonal==False AND Cust...       18  \
# 1   0.072246  Acro Bike==False AND Cryogonal==False AND Cust...       18
# 2   0.070933  Cryogonal==False AND Custom Catcher==False AND...       19
# 3   0.070933  Cryogonal==False AND Custom Catcher==False AND...       19
# 4   0.070933  Acro Bike==False AND Cryogonal==False AND Cust...       19
# 5   0.069619  Acro Bike==False AND Cryogonal==False AND Cust...       20
# 6   0.069619  Acro Bike==False AND Cryogonal==False AND Cust...       20
# 7   0.069056  Acro Bike==False AND Cryogonal==False AND Cust...       10
# 8   0.067743  Acro Bike==False AND Cryogonal==False AND Cust...       11
# 9   0.067743  Acro Bike==False AND Cryogonal==False AND Cust...       11
# 10  0.067743  Acro Bike==False AND Cryogonal==False AND Cust...       11
# 11  0.066992  Acro Bike==False AND Cryogonal==False AND Cust...       22
# 12  0.066429  Cryogonal==False AND Custom Catcher==False AND...       12
# 13  0.066429  Cryogonal==False AND Custom Catcher==False AND...       12
# 14  0.066429  Acro Bike==False AND Cryogonal==False AND Cust...       12
# 15  0.066429  Acro Bike==False AND Cryogonal==False AND Cust...       12
# 16  0.066429  Acro Bike==False AND Cryogonal==False AND Cust...       12
# 17  0.066429  Acro Bike==False AND Cryogonal==False AND Cust...       12
# 18  0.066429  Acro Bike==False AND Cryogonal==False AND Cust...       12
# 19  0.066429  Acro Bike==False AND Cryogonal==False AND Cust...       12
#
#     size_dataset  positives_sg  positives_dataset  size_complement
# 0             73             7                  7               55  \
# 1             73             7                  7               55
# 2             73             7                  7               54
# 3             73             7                  7               54
# 4             73             7                  7               54
# 5             73             7                  7               53
# 6             73             7                  7               53
# 7             73             6                  7               63
# 8             73             6                  7               62
# 9             73             6                  7               62
# 10            73             6                  7               62
# 11            73             7                  7               51
# 12            73             6                  7               61
# 13            73             6                  7               61
# 14            73             6                  7               61
# 15            73             6                  7               61
# 16            73             6                  7               61
# 17            73             6                  7               61
# 18            73             6                  7               61
# 19            73             6                  7               61
#
#     relative_size_sg  relative_size_complement  coverage_sg
# 0           0.246575                  0.753425     1.000000  \
# 1           0.246575                  0.753425     1.000000
# 2           0.260274                  0.739726     1.000000
# 3           0.260274                  0.739726     1.000000
# 4           0.260274                  0.739726     1.000000
# 5           0.273973                  0.726027     1.000000
# 6           0.273973                  0.726027     1.000000
# 7           0.136986                  0.863014     0.857143
# 8           0.150685                  0.849315     0.857143
# 9           0.150685                  0.849315     0.857143
# 10          0.150685                  0.849315     0.857143
# 11          0.301370                  0.698630     1.000000
# 12          0.164384                  0.835616     0.857143
# 13          0.164384                  0.835616     0.857143
# 14          0.164384                  0.835616     0.857143
# 15          0.164384                  0.835616     0.857143
# 16          0.164384                  0.835616     0.857143
# 17          0.164384                  0.835616     0.857143
# 18          0.164384                  0.835616     0.857143
# 19          0.164384                  0.835616     0.857143
#
#     coverage_complement  target_share_sg  target_share_complement
# 0              0.000000         0.388889                 0.000000  \
# 1              0.000000         0.388889                 0.000000
# 2              0.000000         0.368421                 0.000000
# 3              0.000000         0.368421                 0.000000
# 4              0.000000         0.368421                 0.000000
# 5              0.000000         0.350000                 0.000000
# 6              0.000000         0.350000                 0.000000
# 7              0.142857         0.600000                 0.015873
# 8              0.142857         0.545455                 0.016129
# 9              0.142857         0.545455                 0.016129
# 10             0.142857         0.545455                 0.016129
# 11             0.000000         0.318182                 0.000000
# 12             0.142857         0.500000                 0.016393
# 13             0.142857         0.500000                 0.016393
# 14             0.142857         0.500000                 0.016393
# 15             0.142857         0.500000                 0.016393
# 16             0.142857         0.500000                 0.016393
# 17             0.142857         0.500000                 0.016393
# 18             0.142857         0.500000                 0.016393
# 19             0.142857         0.500000                 0.016393
#
#     target_share_dataset      lift
# 0                0.09589  4.055556
# 1                0.09589  4.055556
# 2                0.09589  3.842105
# 3                0.09589  3.842105
# 4                0.09589  3.842105
# 5                0.09589  3.650000
# 6                0.09589  3.650000
# 7                0.09589  6.257143
# 8                0.09589  5.688312
# 9                0.09589  5.688312
# 10               0.09589  5.688312
# 11               0.09589  3.318182
# 12               0.09589  5.214286
# 13               0.09589  5.214286
# 14               0.09589  5.214286
# 15               0.09589  5.214286
# 16               0.09589  5.214286
# 17               0.09589  5.214286
# 18               0.09589  5.214286
# 19               0.09589  5.214286
#
# ---------------------------------------------------------------------------------------------------------------------------------
# Região: EU
#
# Subgrupo: Ditto ♢==False AND Jolteon-GX==False AND Judge==False AND Poipole==False AND Rescue Stretcher==False
# Subgrupo: Ditto ♢==False AND Eevee==False AND Judge==False AND Poipole==False AND Rescue Stretcher==False
# Subgrupo: Absol==False AND Ditto ♢==False AND Judge==False AND Poipole==False AND Rescue Stretcher==False
# Subgrupo: Absol==False AND Ditto ♢==False AND Jolteon-GX==False AND Poipole==False AND Rescue Stretcher==False
# Subgrupo: Absol==False AND Ditto ♢==False AND Jolteon-GX==False AND Judge==False AND Rescue Stretcher==False
# Subgrupo: Absol==False AND Ditto ♢==False AND Eevee==False AND Poipole==False AND Rescue Stretcher==False
# Subgrupo: Absol==False AND Ditto ♢==False AND Eevee==False AND Judge==False AND Rescue Stretcher==False
# Subgrupo: Absol==False AND Jirachi==True AND Rescue Stretcher==False AND Zeraora-GX==True
# Subgrupo: Absol==False AND Jirachi==True AND Rescue Stretcher==False AND Zebstrika==False
# Subgrupo: Absol==False AND Jirachi==True AND Rescue Stretcher==False AND Thunder Mountain ♢==True
# Subgrupo: Absol==False AND Jirachi==True AND Rescue Stretcher==False AND Tapu Koko ♢==True
# Subgrupo: Absol==False AND Jirachi==True AND Pikachu & Zekrom-GX==True AND Rescue Stretcher==False
# Subgrupo: Absol==False AND Jirachi==True AND Pal Pad==False AND Rescue Stretcher==False
# Subgrupo: Absol==False AND Escape Board==True AND Rescue Stretcher==False AND Zeraora-GX==True
# Subgrupo: Absol==False AND Escape Board==True AND Rescue Stretcher==False AND Thunder Mountain ♢==True
# Subgrupo: Absol==False AND Escape Board==True AND Rescue Stretcher==False AND Tapu Koko ♢==True
# Subgrupo: Absol==False AND Escape Board==True AND Pikachu & Zekrom-GX==True AND Rescue Stretcher==False
# Subgrupo: Absol==False AND Energy Switch==True AND Jirachi==True AND Rescue Stretcher==False
# Subgrupo: Absol==False AND Energy Switch==True AND Escape Board==True AND Rescue Stretcher==False
# Subgrupo: Absol==False AND Electropower==True AND Jirachi==True AND Rescue Stretcher==False
#
#      quality                                           subgroup  size_sg
# 0   0.044421  Ditto ♢==False AND Jolteon-GX==False AND Judge...       23  \
# 1   0.044421  Ditto ♢==False AND Eevee==False AND Judge==Fal...       23
# 2   0.044421  Absol==False AND Ditto ♢==False AND Judge==Fal...       23
# 3   0.044421  Absol==False AND Ditto ♢==False AND Jolteon-GX...       23
# 4   0.044421  Absol==False AND Ditto ♢==False AND Jolteon-GX...       23
# 5   0.044421  Absol==False AND Ditto ♢==False AND Eevee==Fal...       23
# 6   0.044421  Absol==False AND Ditto ♢==False AND Eevee==Fal...       23
# 7   0.043388  Absol==False AND Jirachi==True AND Rescue Stre...       13
# 8   0.043388  Absol==False AND Jirachi==True AND Rescue Stre...       13
# 9   0.043388  Absol==False AND Jirachi==True AND Rescue Stre...       13
# 10  0.043388  Absol==False AND Jirachi==True AND Rescue Stre...       13
# 11  0.043388  Absol==False AND Jirachi==True AND Pikachu & Z...       13
# 12  0.043388  Absol==False AND Jirachi==True AND Pal Pad==Fa...       13
# 13  0.043388  Absol==False AND Escape Board==True AND Rescue...       13
# 14  0.043388  Absol==False AND Escape Board==True AND Rescue...       13
# 15  0.043388  Absol==False AND Escape Board==True AND Rescue...       13
# 16  0.043388  Absol==False AND Escape Board==True AND Pikach...       13
# 17  0.043388  Absol==False AND Energy Switch==True AND Jirac...       13
# 18  0.043388  Absol==False AND Energy Switch==True AND Escap...       13
# 19  0.043388  Absol==False AND Electropower==True AND Jirach...       13
#
#     size_dataset  positives_sg  positives_dataset  size_complement
# 0             88             6                  8               65  \
# 1             88             6                  8               65
# 2             88             6                  8               65
# 3             88             6                  8               65
# 4             88             6                  8               65
# 5             88             6                  8               65
# 6             88             6                  8               65
# 7             88             5                  8               75
# 8             88             5                  8               75
# 9             88             5                  8               75
# 10            88             5                  8               75
# 11            88             5                  8               75
# 12            88             5                  8               75
# 13            88             5                  8               75
# 14            88             5                  8               75
# 15            88             5                  8               75
# 16            88             5                  8               75
# 17            88             5                  8               75
# 18            88             5                  8               75
# 19            88             5                  8               75
#
#     relative_size_sg  relative_size_complement  coverage_sg
# 0           0.261364                  0.738636        0.750  \
# 1           0.261364                  0.738636        0.750
# 2           0.261364                  0.738636        0.750
# 3           0.261364                  0.738636        0.750
# 4           0.261364                  0.738636        0.750
# 5           0.261364                  0.738636        0.750
# 6           0.261364                  0.738636        0.750
# 7           0.147727                  0.852273        0.625
# 8           0.147727                  0.852273        0.625
# 9           0.147727                  0.852273        0.625
# 10          0.147727                  0.852273        0.625
# 11          0.147727                  0.852273        0.625
# 12          0.147727                  0.852273        0.625
# 13          0.147727                  0.852273        0.625
# 14          0.147727                  0.852273        0.625
# 15          0.147727                  0.852273        0.625
# 16          0.147727                  0.852273        0.625
# 17          0.147727                  0.852273        0.625
# 18          0.147727                  0.852273        0.625
# 19          0.147727                  0.852273        0.625
#
#     coverage_complement  target_share_sg  target_share_complement
# 0                 0.250         0.260870                 0.030769  \
# 1                 0.250         0.260870                 0.030769
# 2                 0.250         0.260870                 0.030769
# 3                 0.250         0.260870                 0.030769
# 4                 0.250         0.260870                 0.030769
# 5                 0.250         0.260870                 0.030769
# 6                 0.250         0.260870                 0.030769
# 7                 0.375         0.384615                 0.040000
# 8                 0.375         0.384615                 0.040000
# 9                 0.375         0.384615                 0.040000
# 10                0.375         0.384615                 0.040000
# 11                0.375         0.384615                 0.040000
# 12                0.375         0.384615                 0.040000
# 13                0.375         0.384615                 0.040000
# 14                0.375         0.384615                 0.040000
# 15                0.375         0.384615                 0.040000
# 16                0.375         0.384615                 0.040000
# 17                0.375         0.384615                 0.040000
# 18                0.375         0.384615                 0.040000
# 19                0.375         0.384615                 0.040000
#
#     target_share_dataset      lift
# 0               0.090909  2.869565
# 1               0.090909  2.869565
# 2               0.090909  2.869565
# 3               0.090909  2.869565
# 4               0.090909  2.869565
# 5               0.090909  2.869565
# 6               0.090909  2.869565
# 7               0.090909  4.230769
# 8               0.090909  4.230769
# 9               0.090909  4.230769
# 10              0.090909  4.230769
# 11              0.090909  4.230769
# 12              0.090909  4.230769
# 13              0.090909  4.230769
# 14              0.090909  4.230769
# 15              0.090909  4.230769
# 16              0.090909  4.230769
# 17              0.090909  4.230769
# 18              0.090909  4.230769
# 19              0.090909  4.230769
#
# ---------------------------------------------------------------------------------------------------------------------------------
# Região: AS-OC
#
# Subgrupo: Marshadow-GX==False AND Marshadow==True AND Pokémon Communication==False AND Rockruff==False AND Zeraora-GX==False
# Subgrupo: Marshadow-GX==False AND Marshadow==True AND Pokémon Communication==False AND Professor Kukui==False AND Zeraora-GX==False
# Subgrupo: Lycanroc-GX==False AND Marshadow-GX==False AND Marshadow==True AND Pokémon Communication==False AND Zeraora-GX==False
# Subgrupo: Alolan Grimer==False AND Marshadow-GX==False AND Marshadow==True AND Rockruff==False AND Zeraora-GX==False
# Subgrupo: Alolan Grimer==False AND Marshadow-GX==False AND Marshadow==True AND Professor Kukui==False AND Zeraora-GX==False
# Subgrupo: Alolan Grimer==False AND Lycanroc-GX==False AND Marshadow-GX==False AND Marshadow==True AND Zeraora-GX==False
# Subgrupo: Acerola==False AND Marshadow-GX==False AND Marshadow==True AND Professor Kukui==False AND Zeraora-GX==False
# Subgrupo: Acerola==False AND Marshadow-GX==False AND Marshadow==True AND Pokémon Communication==False AND Zeraora-GX==False
# Subgrupo: Marshadow-GX==False AND Marshadow==True AND Pokémon Communication==False AND Professor Kukui==False AND Rockruff==False
# Subgrupo: Lycanroc-GX==False AND Marshadow-GX==False AND Marshadow==True AND Pokémon Communication==False AND Professor Kukui==False
# Subgrupo: Marshadow-GX==False AND Marshadow==True AND Professor Elm's Lecture==False AND Professor Kukui==False AND Zeraora-GX==False
# Subgrupo: Marshadow-GX==False AND Marshadow==True AND Professor Kukui==False AND Zeraora-GX==False AND Zorua==False
# Subgrupo: Marshadow-GX==False AND Marshadow==True AND Professor Kukui==False AND Rockruff==False AND Zeraora-GX==False
# Subgrupo: Marshadow-GX==False AND Marshadow==True AND Pokémon Communication==False AND Zeraora-GX==False AND Zorua==False
# Subgrupo: Marshadow-GX==False AND Marshadow==True AND Pokémon Communication==False AND Zeraora-GX==False AND Zoroark-GX==False
# Subgrupo: Marshadow-GX==False AND Marshadow==True AND Pal Pad==False AND Pokémon Communication==False AND Zeraora-GX==False
# Subgrupo: Lycanroc-GX==False AND Marshadow-GX==False AND Marshadow==True AND Professor Kukui==False AND Zeraora-GX==False
# Subgrupo: Alolan Grimer==False AND Marshadow-GX==False AND Marshadow==True AND Pokémon Communication==False AND Zeraora-GX==False
# Subgrupo: Acerola==False AND Marshadow-GX==False AND Marshadow==True AND Rockruff==False AND Zeraora-GX==False
# Subgrupo: Acerola==False AND Lycanroc-GX==False AND Marshadow-GX==False AND Marshadow==True AND Zeraora-GX==False
#
#      quality                                           subgroup  size_sg
# 0   0.063124  Marshadow-GX==False AND Marshadow==True AND Po...       28  \
# 1   0.063124  Marshadow-GX==False AND Marshadow==True AND Po...       28
# 2   0.063124  Lycanroc-GX==False AND Marshadow-GX==False AND...       28
# 3   0.061604  Alolan Grimer==False AND Marshadow-GX==False A...       29
# 4   0.061604  Alolan Grimer==False AND Marshadow-GX==False A...       29
# 5   0.061604  Alolan Grimer==False AND Lycanroc-GX==False AN...       29
# 6   0.061604  Acerola==False AND Marshadow-GX==False AND Mar...       29
# 7   0.061604  Acerola==False AND Marshadow-GX==False AND Mar...       29
# 8   0.061141  Marshadow-GX==False AND Marshadow==True AND Po...       40
# 9   0.061141  Lycanroc-GX==False AND Marshadow-GX==False AND...       40
# 10  0.060612  Marshadow-GX==False AND Marshadow==True AND Pr...       35
# 11  0.060083  Marshadow-GX==False AND Marshadow==True AND Pr...       30
# 12  0.060083  Marshadow-GX==False AND Marshadow==True AND Pr...       30
# 13  0.060083  Marshadow-GX==False AND Marshadow==True AND Po...       30
# 14  0.060083  Marshadow-GX==False AND Marshadow==True AND Po...       30
# 15  0.060083  Marshadow-GX==False AND Marshadow==True AND Pa...       30
# 16  0.060083  Lycanroc-GX==False AND Marshadow-GX==False AND...       30
# 17  0.060083  Alolan Grimer==False AND Marshadow-GX==False A...       30
# 18  0.060083  Acerola==False AND Marshadow-GX==False AND Mar...       30
# 19  0.060083  Acerola==False AND Lycanroc-GX==False AND Mars...       30
#
#     size_dataset  positives_sg  positives_dataset  size_complement
# 0            123            13                 23               95  \
# 1            123            13                 23               95
# 2            123            13                 23               95
# 3            123            13                 23               94
# 4            123            13                 23               94
# 5            123            13                 23               94
# 6            123            13                 23               94
# 7            123            13                 23               94
# 8            123            15                 23               83
# 9            123            15                 23               83
# 10           123            14                 23               88
# 11           123            13                 23               93
# 12           123            13                 23               93
# 13           123            13                 23               93
# 14           123            13                 23               93
# 15           123            13                 23               93
# 16           123            13                 23               93
# 17           123            13                 23               93
# 18           123            13                 23               93
# 19           123            13                 23               93
#
#     relative_size_sg  relative_size_complement  coverage_sg
# 0           0.227642                  0.772358     0.565217  \
# 1           0.227642                  0.772358     0.565217
# 2           0.227642                  0.772358     0.565217
# 3           0.235772                  0.764228     0.565217
# 4           0.235772                  0.764228     0.565217
# 5           0.235772                  0.764228     0.565217
# 6           0.235772                  0.764228     0.565217
# 7           0.235772                  0.764228     0.565217
# 8           0.325203                  0.674797     0.652174
# 9           0.325203                  0.674797     0.652174
# 10          0.284553                  0.715447     0.608696
# 11          0.243902                  0.756098     0.565217
# 12          0.243902                  0.756098     0.565217
# 13          0.243902                  0.756098     0.565217
# 14          0.243902                  0.756098     0.565217
# 15          0.243902                  0.756098     0.565217
# 16          0.243902                  0.756098     0.565217
# 17          0.243902                  0.756098     0.565217
# 18          0.243902                  0.756098     0.565217
# 19          0.243902                  0.756098     0.565217
#
#     coverage_complement  target_share_sg  target_share_complement
# 0              0.434783         0.464286                 0.105263  \
# 1              0.434783         0.464286                 0.105263
# 2              0.434783         0.464286                 0.105263
# 3              0.434783         0.448276                 0.106383
# 4              0.434783         0.448276                 0.106383
# 5              0.434783         0.448276                 0.106383
# 6              0.434783         0.448276                 0.106383
# 7              0.434783         0.448276                 0.106383
# 8              0.347826         0.375000                 0.096386
# 9              0.347826         0.375000                 0.096386
# 10             0.391304         0.400000                 0.102273
# 11             0.434783         0.433333                 0.107527
# 12             0.434783         0.433333                 0.107527
# 13             0.434783         0.433333                 0.107527
# 14             0.434783         0.433333                 0.107527
# 15             0.434783         0.433333                 0.107527
# 16             0.434783         0.433333                 0.107527
# 17             0.434783         0.433333                 0.107527
# 18             0.434783         0.433333                 0.107527
# 19             0.434783         0.433333                 0.107527
#
#     target_share_dataset      lift
# 0               0.186992  2.482919
# 1               0.186992  2.482919
# 2               0.186992  2.482919
# 3               0.186992  2.397301
# 4               0.186992  2.397301
# 5               0.186992  2.397301
# 6               0.186992  2.397301
# 7               0.186992  2.397301
# 8               0.186992  2.005435
# 9               0.186992  2.005435
# 10              0.186992  2.139130
# 11              0.186992  2.317391
# 12              0.186992  2.317391
# 13              0.186992  2.317391
# 14              0.186992  2.317391
# 15              0.186992  2.317391
# 16              0.186992  2.317391
# 17              0.186992  2.317391
# 18              0.186992  2.317391
# 19              0.186992  2.317391
#
# ---------------------------------------------------------------------------------------------------------------------------------
# Região: JP
#
# Subgrupo: Green's Exploration==False AND Lillie==False AND Shrine of Punishment==False AND Viridian Forest==False
# Subgrupo: Green's Exploration==False AND Lillie==False AND Shrine of Punishment==False AND Tapu Koko-GX==False AND Viridian Forest==False
# Subgrupo: Green's Exploration==False AND Lillie==False AND Marshadow-GX==False AND Shrine of Punishment==False AND Viridian Forest==False
# Subgrupo: Green's Exploration==False AND Judge==False AND Lillie==False AND Shrine of Punishment==False AND Viridian Forest==False
# Subgrupo: Beast Ring==False AND Green's Exploration==False AND Lillie==False AND Shrine of Punishment==False AND Viridian Forest==False
# Subgrupo: Green's Exploration==False AND Lillie==False AND Mysterious Treasure==False AND Shrine of Punishment==False AND Viridian Forest==False
# Subgrupo: Cynthia==False AND Lt. Surge's Strategy==False AND Shrine of Punishment==False AND Switch==True AND Tapu Koko-GX==False
# Subgrupo: Beast Ring==False AND Cynthia==False AND Shrine of Punishment==False AND Switch==True AND Tapu Koko-GX==False
# Subgrupo: Beast Ring==False AND Cynthia==False AND Lt. Surge's Strategy==False AND Switch==True AND Tapu Koko-GX==False
# Subgrupo: Ditto ♢==False AND Green's Exploration==False AND Lillie==False AND Mysterious Treasure==False AND Shrine of Punishment==False
# Subgrupo: Green's Exploration==False AND Lillie==False AND Marnie==False AND Mysterious Treasure==False AND Shrine of Punishment==False
# Subgrupo: Cynthia==False AND Lt. Surge's Strategy==False AND Reset Stamp==True AND Switch==True AND Tapu Koko-GX==False
# Subgrupo: Cynthia==False AND Lillie==False AND Lt. Surge's Strategy==False AND Reset Stamp==True
# Subgrupo: Cynthia==False AND Lillie==False AND Lt. Surge's Strategy==False AND Reset Stamp==True AND Tapu Koko-GX==False
# Subgrupo: Cynthia==False AND Lillie==False AND Lt. Surge's Strategy==False AND Reset Stamp==True AND Switch==True
# Subgrupo: Cynthia==False AND Lillie==False AND Lt. Surge's Strategy==False AND Reset Stamp==True AND Shrine of Punishment==False
# Subgrupo: Cynthia==False AND Lillie==False AND Lt. Surge's Strategy==False AND Pheromosa & Buzzwole-GX==False AND Reset Stamp==True
# Subgrupo: Cynthia==False AND Lillie==False AND Lt. Surge's Strategy==False AND Marshadow-GX==False AND Reset Stamp==True
# Subgrupo: Cynthia==False AND Erika's Hospitality==False AND Lillie==False AND Lt. Surge's Strategy==False AND Reset Stamp==True
# Subgrupo: Beast Ring==False AND Cynthia==False AND Lillie==False AND Lt. Surge's Strategy==False AND Reset Stamp==True
#
#      quality                                           subgroup  size_sg
# 0   0.084640  Green's Exploration==False AND Lillie==False A...       20  \
# 1   0.084640  Green's Exploration==False AND Lillie==False A...       20
# 2   0.084640  Green's Exploration==False AND Lillie==False A...       20
# 3   0.084640  Green's Exploration==False AND Judge==False AN...       20
# 4   0.084640  Beast Ring==False AND Green's Exploration==Fal...       20
# 5   0.083829  Green's Exploration==False AND Lillie==False A...       15
# 6   0.082477  Cynthia==False AND Lt. Surge's Strategy==False...       21
# 7   0.082477  Beast Ring==False AND Cynthia==False AND Shrin...       21
# 8   0.082477  Beast Ring==False AND Cynthia==False AND Lt. S...       21
# 9   0.081666  Ditto ♢==False AND Green's Exploration==False ...       16
# 10  0.080855  Green's Exploration==False AND Lillie==False A...       11
# 11  0.080855  Cynthia==False AND Lt. Surge's Strategy==False...       11
# 12  0.080855  Cynthia==False AND Lillie==False AND Lt. Surge...       11
# 13  0.080855  Cynthia==False AND Lillie==False AND Lt. Surge...       11
# 14  0.080855  Cynthia==False AND Lillie==False AND Lt. Surge...       11
# 15  0.080855  Cynthia==False AND Lillie==False AND Lt. Surge...       11
# 16  0.080855  Cynthia==False AND Lillie==False AND Lt. Surge...       11
# 17  0.080855  Cynthia==False AND Lillie==False AND Lt. Surge...       11
# 18  0.080855  Cynthia==False AND Erika's Hospitality==False ...       11
# 19  0.080855  Beast Ring==False AND Cynthia==False AND Lilli...       11
#
#     size_dataset  positives_sg  positives_dataset  size_complement
# 0             86            11                 16               66  \
# 1             86            11                 16               66
# 2             86            11                 16               66
# 3             86            11                 16               66
# 4             86            11                 16               66
# 5             86            10                 16               71
# 6             86            11                 16               65
# 7             86            11                 16               65
# 8             86            11                 16               65
# 9             86            10                 16               70
# 10            86             9                 16               75
# 11            86             9                 16               75
# 12            86             9                 16               75
# 13            86             9                 16               75
# 14            86             9                 16               75
# 15            86             9                 16               75
# 16            86             9                 16               75
# 17            86             9                 16               75
# 18            86             9                 16               75
# 19            86             9                 16               75
#
#     relative_size_sg  relative_size_complement  coverage_sg
# 0           0.232558                  0.767442       0.6875  \
# 1           0.232558                  0.767442       0.6875
# 2           0.232558                  0.767442       0.6875
# 3           0.232558                  0.767442       0.6875
# 4           0.232558                  0.767442       0.6875
# 5           0.174419                  0.825581       0.6250
# 6           0.244186                  0.755814       0.6875
# 7           0.244186                  0.755814       0.6875
# 8           0.244186                  0.755814       0.6875
# 9           0.186047                  0.813953       0.6250
# 10          0.127907                  0.872093       0.5625
# 11          0.127907                  0.872093       0.5625
# 12          0.127907                  0.872093       0.5625
# 13          0.127907                  0.872093       0.5625
# 14          0.127907                  0.872093       0.5625
# 15          0.127907                  0.872093       0.5625
# 16          0.127907                  0.872093       0.5625
# 17          0.127907                  0.872093       0.5625
# 18          0.127907                  0.872093       0.5625
# 19          0.127907                  0.872093       0.5625
#
#     coverage_complement  target_share_sg  target_share_complement
# 0                0.3125         0.550000                 0.075758  \
# 1                0.3125         0.550000                 0.075758
# 2                0.3125         0.550000                 0.075758
# 3                0.3125         0.550000                 0.075758
# 4                0.3125         0.550000                 0.075758
# 5                0.3750         0.666667                 0.084507
# 6                0.3125         0.523810                 0.076923
# 7                0.3125         0.523810                 0.076923
# 8                0.3125         0.523810                 0.076923
# 9                0.3750         0.625000                 0.085714
# 10               0.4375         0.818182                 0.093333
# 11               0.4375         0.818182                 0.093333
# 12               0.4375         0.818182                 0.093333
# 13               0.4375         0.818182                 0.093333
# 14               0.4375         0.818182                 0.093333
# 15               0.4375         0.818182                 0.093333
# 16               0.4375         0.818182                 0.093333
# 17               0.4375         0.818182                 0.093333
# 18               0.4375         0.818182                 0.093333
# 19               0.4375         0.818182                 0.093333
#
#     target_share_dataset      lift
# 0               0.186047  2.956250
# 1               0.186047  2.956250
# 2               0.186047  2.956250
# 3               0.186047  2.956250
# 4               0.186047  2.956250
# 5               0.186047  3.583333
# 6               0.186047  2.815476
# 7               0.186047  2.815476
# 8               0.186047  2.815476
# 9               0.186047  3.359375
# 10              0.186047  4.397727
# 11              0.186047  4.397727
# 12              0.186047  4.397727
# 13              0.186047  4.397727
# 14              0.186047  4.397727
# 15              0.186047  4.397727
# 16              0.186047  4.397727
# 17              0.186047  4.397727
# 18              0.186047  4.397727
# 19              0.186047  4.397727
#
# ---------------------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# ### Ignorando Regioes

# %%
df_all = df[(df['year_tournament'] == ANO_ANALISAR)]

# verifica se tem torneios
if len(df_all) == 0:
    print(f'Sem torneios no ano {ANO_ANALISAR}')
    print("-------------------------------------------"*3)
    exit()

# calcula subgrupo
df_all = elimina_cards_menos_usados(df_all)
dataset = subgrupo_dataset_region(df_all)
result = calcula_subgrupo(dataset)

# imprime resultados
for row in result.to_dataframe().itertuples():
    print(f"Subgrupo: {row.subgroup}")
print()
print(result.to_dataframe(), "\n")
print("-------------------------------------------"*3)
# Out:
# Subgrupo: Acro Bike==False AND Cryogonal==False AND Energy Spinner==False AND Rescue Stretcher==False AND Switch==True
# Subgrupo: Acro Bike==False AND Energy Spinner==False AND Malamar==False AND Rescue Stretcher==False AND Switch==True
# Subgrupo: Acro Bike==False AND Energy Spinner==False AND Inkay==False AND Rescue Stretcher==False AND Switch==True
# Subgrupo: Acro Bike==False AND Energy Spinner==False AND Keldeo-GX==False AND Rescue Stretcher==False AND Switch==True
# Subgrupo: Acro Bike==False AND Ditto ♢==False AND Energy Spinner==False AND Rescue Stretcher==False AND Switch==True
# Subgrupo: Acro Bike==False AND Energy Spinner==False AND Phione==False AND Rescue Stretcher==False AND Switch==True
# Subgrupo: Acro Bike==False AND Energy Spinner==False AND Rescue Stretcher==False AND Switch==True AND Tate & Liza==False
# Subgrupo: Acro Bike==False AND Energy Spinner==False AND Giratina==False AND Rescue Stretcher==False AND Switch==True
# Subgrupo: Acro Bike==False AND Energy Spinner==False AND Gengar & Mimikyu-GX==False AND Rescue Stretcher==False AND Switch==True
# Subgrupo: Acro Bike==False AND Blacephalon==False AND Energy Spinner==False AND Rescue Stretcher==False AND Switch==True
# Subgrupo: Acro Bike==False AND Arceus & Dialga & Palkia-GX==False AND Beast Ring==False AND Rescue Stretcher==False AND Switch==True
# Subgrupo: Cryogonal==False AND Energy Spinner==False AND Malamar==False AND Rescue Stretcher==False AND Switch==True
# Subgrupo: Cryogonal==False AND Energy Spinner==False AND Inkay==False AND Rescue Stretcher==False AND Switch==True
# Subgrupo: Acro Bike==False AND Beast Ring==False AND Cryogonal==False AND Rescue Stretcher==False AND Switch==True
# Subgrupo: Acro Bike==False AND Energy Spinner==False AND Nihilego==False AND Rescue Stretcher==False AND Switch==True
# Subgrupo: Acro Bike==False AND Beast Ring==False AND Energy Spinner==False AND Rescue Stretcher==False AND Switch==True
# Subgrupo: Acro Bike==False AND Arceus & Dialga & Palkia-GX==False AND Rescue Stretcher==False AND Switch==True AND Tate & Liza==False
# Subgrupo: Acro Bike==False AND Arceus & Dialga & Palkia-GX==False AND Giratina==False AND Rescue Stretcher==False AND Switch==True
# Subgrupo: Acro Bike==False AND Alolan Vulpix==False AND Energy Spinner==False AND Rescue Stretcher==False AND Switch==True
# Subgrupo: Acro Bike==False AND Alolan Ninetales-GX==False AND Energy Spinner==False AND Rescue Stretcher==False AND Switch==True
#
#      quality                                           subgroup  size_sg
# 0   0.041812  Acro Bike==False AND Cryogonal==False AND Ener...       79  \
# 1   0.040628  Acro Bike==False AND Energy Spinner==False AND...       82
# 2   0.040628  Acro Bike==False AND Energy Spinner==False AND...       82
# 3   0.040292  Acro Bike==False AND Energy Spinner==False AND...       76
# 4   0.040292  Acro Bike==False AND Ditto ♢==False AND Energy...       76
# 5   0.039898  Acro Bike==False AND Energy Spinner==False AND...       77
# 6   0.039839  Acro Bike==False AND Energy Spinner==False AND...       84
# 7   0.039839  Acro Bike==False AND Energy Spinner==False AND...       84
# 8   0.039839  Acro Bike==False AND Energy Spinner==False AND...       84
# 9   0.039839  Acro Bike==False AND Blacephalon==False AND En...       84
# 10  0.039839  Acro Bike==False AND Arceus & Dialga & Palkia-...       84
# 11  0.039781  Cryogonal==False AND Energy Spinner==False AND...       91
# 12  0.039781  Cryogonal==False AND Energy Spinner==False AND...       91
# 13  0.039722  Acro Bike==False AND Beast Ring==False AND Cry...       98
# 14  0.039445  Acro Bike==False AND Energy Spinner==False AND...       85
# 15  0.039445  Acro Bike==False AND Beast Ring==False AND Ene...       85
# 16  0.039445  Acro Bike==False AND Arceus & Dialga & Palkia-...       85
# 17  0.039445  Acro Bike==False AND Arceus & Dialga & Palkia-...       85
# 18  0.039445  Acro Bike==False AND Alolan Vulpix==False AND ...       85
# 19  0.039445  Acro Bike==False AND Alolan Ninetales-GX==Fals...       85
#
#     size_dataset  positives_sg  positives_dataset  size_complement
# 0            370            27                 54              291  \
# 1            370            27                 54              288
# 2            370            27                 54              288
# 3            370            26                 54              294
# 4            370            26                 54              294
# 5            370            26                 54              293
# 6            370            27                 54              286
# 7            370            27                 54              286
# 8            370            27                 54              286
# 9            370            27                 54              286
# 10           370            27                 54              286
# 11           370            28                 54              279
# 12           370            28                 54              279
# 13           370            29                 54              272
# 14           370            27                 54              285
# 15           370            27                 54              285
# 16           370            27                 54              285
# 17           370            27                 54              285
# 18           370            27                 54              285
# 19           370            27                 54              285
#
#     relative_size_sg  relative_size_complement  coverage_sg
# 0           0.213514                  0.786486     0.500000  \
# 1           0.221622                  0.778378     0.500000
# 2           0.221622                  0.778378     0.500000
# 3           0.205405                  0.794595     0.481481
# 4           0.205405                  0.794595     0.481481
# 5           0.208108                  0.791892     0.481481
# 6           0.227027                  0.772973     0.500000
# 7           0.227027                  0.772973     0.500000
# 8           0.227027                  0.772973     0.500000
# 9           0.227027                  0.772973     0.500000
# 10          0.227027                  0.772973     0.500000
# 11          0.245946                  0.754054     0.518519
# 12          0.245946                  0.754054     0.518519
# 13          0.264865                  0.735135     0.537037
# 14          0.229730                  0.770270     0.500000
# 15          0.229730                  0.770270     0.500000
# 16          0.229730                  0.770270     0.500000
# 17          0.229730                  0.770270     0.500000
# 18          0.229730                  0.770270     0.500000
# 19          0.229730                  0.770270     0.500000
#
#     coverage_complement  target_share_sg  target_share_complement
# 0              0.500000         0.341772                 0.092784  \
# 1              0.500000         0.329268                 0.093750
# 2              0.500000         0.329268                 0.093750
# 3              0.518519         0.342105                 0.095238
# 4              0.518519         0.342105                 0.095238
# 5              0.518519         0.337662                 0.095563
# 6              0.500000         0.321429                 0.094406
# 7              0.500000         0.321429                 0.094406
# 8              0.500000         0.321429                 0.094406
# 9              0.500000         0.321429                 0.094406
# 10             0.500000         0.321429                 0.094406
# 11             0.481481         0.307692                 0.093190
# 12             0.481481         0.307692                 0.093190
# 13             0.462963         0.295918                 0.091912
# 14             0.500000         0.317647                 0.094737
# 15             0.500000         0.317647                 0.094737
# 16             0.500000         0.317647                 0.094737
# 17             0.500000         0.317647                 0.094737
# 18             0.500000         0.317647                 0.094737
# 19             0.500000         0.317647                 0.094737
#
#     target_share_dataset      lift
# 0               0.145946  2.341772
# 1               0.145946  2.256098
# 2               0.145946  2.256098
# 3               0.145946  2.344055
# 4               0.145946  2.344055
# 5               0.145946  2.313612
# 6               0.145946  2.202381
# 7               0.145946  2.202381
# 8               0.145946  2.202381
# 9               0.145946  2.202381
# 10              0.145946  2.202381
# 11              0.145946  2.108262
# 12              0.145946  2.108262
# 13              0.145946  2.027589
# 14              0.145946  2.176471
# 15              0.145946  2.176471
# 16              0.145946  2.176471
# 17              0.145946  2.176471
# 18              0.145946  2.176471
# 19              0.145946  2.176471
#
# ---------------------------------------------------------------------------------------------------------------------------------
